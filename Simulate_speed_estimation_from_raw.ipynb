# %%
# %matplotlib notebook

# %%
import numpy
import matplotlib.pyplot as plt

import struct
import can

# %% [markdown]
# ## Case 1 ##

# %%
buf = [0.1548650562763214,6,67,68,5.2675933837890625,1,127,65,6.738722324371338,2,177,127,7.957428455352783,3,163,163,9.121930122375488,4,126,154,9.234545707702637,5,104,129,9.589720726013184,6,107,108,10.388864517211914,1,126,108,10.535186767578125,2,144,126,9.973310470581055,3,140,140,10.999974250793457,4,127,140,10.999974250793457,5,114,127,10.388864517211914,6,116,114,11.164153099060059,1,127,116,11.333307266235352,2,139,126,10.535186767578125,3,138,137,11.333307266235352,4,128,137,11.333307266235352,5,119,128,10.685688972473145,6,118,118,11.507664680480957,1,127,119,11.333307266235352,2,137,127,10.535186767578125,3,138,135,11.872987747192383,4,126,132,11.507664680480957,5,119,128,10.535186767578125,6,117,118,11.872987747192383,1,127,120,11.333307266235352,2,135,126,10.535186767578125,3,136,134,11.872987747192383,4,127,134,11.507664680480957,5,118,128,10.388864517211914,6,120,118,12.064488410949707,1,126,119,11.872987747192383,2,132,127,10.535186767578125,3,134,134,11.872987747192383,4,127,135,11.872987747192383,5,122,129,10.108084678649902,6,120,119,11.872987747192383,1,126,117,11.872987747192383,2,135,129,10.388864517211914,3,136,133,11.687472343444824,4,127,134,11.872987747192383,5,118,127,10.685688972473145,6,121,119,11.507664680480957,1,128,118,11.872987747192383,2,135,126,10.685688972473145,3,134,135,11.333307266235352,4,128,136,11.872987747192383,5,117,127,10.840554237365723,6,118,117,11.333307266235352,1,126,118,11.687472343444824,2,137,127,11.164153099060059,3,136,136,11.333307266235352,4,127,135,11.507664680480957,5,121,127,11.164153099060059,6,116,117,11.333307266235352,1,126,117,11.164153099060059,2,137,127,11.333307266235352,3,136,135,11.333307266235352,4,128,134,11.333307266235352,5,121,128,11.333307266235352,6,119,119,11.507664680480957,1,127,119,11.164153099060059,2,134,127,11.164153099060059,3,135,134,11.507664680480957,4,127,138,11.164153099060059,5,120,129,11.164153099060059,6,118,119,11.507664680480957,1,125,118,11.164153099060059,2,135,126,11.333307266235352,3,134,132,11.507664680480957,4,127,135,11.333307266235352,5,117,126,10.999974250793457,6,119,121,11.164153099060059,1,127,119,11.507664680480957,2,134,128,10.999974250793457,3,135,133,11.333307266235352,4,127,136,11.164153099060059,5,120,129,11.333307266235352,6,122,120,11.164153099060059,1,126,121,11.333307266235352,2,135,128,11.164153099060059,3,137,136,11.333307266235352,4,127,135,11.333307266235352,5,119,127,11.164153099060059,6,119,118,11.333307266235352,1,126,120,11.333307266235352,2,134,127,10.999974250793457,3,136,135,11.687472343444824,4,127,132,11.164153099060059,5,118,126,10.999974250793457,6,119,119,11.507664680480957,1,126,120,11.333307266235352,2,135,126,10.999974250793457,3,135,134,11.687472343444824,4,127,134,11.164153099060059,5,120,127,10.999974250793457,6,120,120,11.507664680480957,1,126,119,11.507664680480957,2,134,128,10.840554237365723,3,135,134,11.687472343444824,4,126,134,11.507664680480957,5,120,127,10.840554237365723,6,121,124,11.507664680480957,1,127,119,11.507664680480957,2,134,128,10.840554237365723,3,134,136,11.507664680480957,4,128,134,11.507664680480957,5,123,127,10.840554237365723,6,119,119,11.507664680480957,1,127,119,11.687472343444824,2,136,128,10.685688972473145,3,136,135,11.872987747192383,4,127,133,11.507664680480957,5,119,127,10.685688972473145,6,117,118,11.872987747192383,1,127,120,11.507664680480957,2,133,128,10.535186767578125,3,136,135,11.872987747192383,4,127,136,11.687472343444824,5,123,128,10.388864517211914,6,118,118,11.872987747192383,1,126,120,11.872987747192383,2,135,127,10.388864517211914,3,135,137,11.872987747192383,4,129,135,11.872987747192383,5,122,128,10.108084678649902,6,119,120,11.872987747192383,1,127,117,12.064488410949707,2,134,127,10.388864517211914,3,135,134,11.507664680480957,4,127,133,11.872987747192383,5,121,129,10.685688972473145,6,118,117,11.507664680480957,1,127,119,11.872987747192383,2,135,127,10.685688972473145,3,135,134,11.333307266235352,4,127,135,11.872987747192383,5,119,129,10.685688972473145,6,120,119,11.507664680480957,1,128,117,11.507664680480957,2,133,126,11.164153099060059,3,137,135,11.333307266235352,4,127,134,11.507664680480957,5,118,127,11.164153099060059,6,119,120,11.164153099060059,1,126,119,11.164153099060059,2,135,127,11.333307266235352,3,136,136,11.333307266235352,4,127,135,11.333307266235352,5,120,129,11.333307266235352,6,118,119,11.507664680480957,1,126,119,11.164153099060059,2,135,126,11.164153099060059,3,135,134,11.507664680480957,4,127,135,11.164153099060059,5,119,126,11.164153099060059,6,120,119,11.333307266235352,1,127,117,11.164153099060059,2,136,128,11.333307266235352,3,135,135,11.333307266235352,4,127,136,11.333307266235352,5,119,129,10.999974250793457,6,121,120,11.164153099060059,1,128,118,11.507664680480957,2,136,127,10.999974250793457,3,135,135,11.333307266235352,4,128,134,11.333307266235352,5,116,126,11.333307266235352,6,117,117,11.333307266235352,1,125,120,11.333307266235352,2,136,127,11.164153099060059,3,134,133,11.164153099060059,4,127,132,11.333307266235352,5,122,128,11.333307266235352,6,118,119,11.164153099060059,1,126,120,11.333307266235352,2,135,127,11.164153099060059,3,135,133,11.507664680480957,4,127,133,11.164153099060059,5,122,129,10.999974250793457,6,117,118,11.687472343444824,1,126,120,11.164153099060059,2,133,127,10.999974250793457,3,135,134,11.687472343444824,4,128,136,11.164153099060059,5,119,127,10.999974250793457,6,122,121,11.687472343444824,1,127,119,11.507664680480957,2,134,126,10.685688972473145,3,136,136,11.687472343444824,4,127,134,11.507664680480957,5,119,127,10.840554237365723,6,122,124,11.507664680480957,1,127,120,11.687472343444824,2,133,127,10.685688972473145,3,135,134,11.507664680480957,4,127,134,11.507664680480957,5,118,127,10.840554237365723,6,119,121,11.687472343444824,1,126,120,11.687472343444824,2,135,126,10.685688972473145,3,136,135,11.687472343444824,4,127,134,11.687472343444824,5,120,127,10.840554237365723,6,118,118,12.064488410949707,1,128,119,11.507664680480957,2,134,127,10.535186767578125,3,136,134,12.064488410949707,4,126,132,11.507664680480957,5,121,127,10.388864517211914,6,119,119,12.064488410949707,1,126,119,11.687472343444824,2,131,128,10.535186767578125,3,136,135,11.872987747192383,4,128,133,11.687472343444824,5,121,128,10.246551513671875,6,117,117,11.872987747192383,1,126,119,12.064488410949707,2,133,127,10.246551513671875,3,135,135,11.687472343444824,4,128,133,11.872987747192383,5,120,128,10.685688972473145,6,118,119,11.507664680480957,1,127,117,11.872987747192383,2,136,126,10.535186767578125,3,136,135,11.333307266235352,4,128,133,11.872987747192383,5,119,129,10.685688972473145,6,119,118,11.507664680480957,1,126,118,11.507664680480957,2,136,128,11.333307266235352,3,135,135,11.333307266235352,4,128,134,11.333307266235352,5,121,129,11.164153099060059,6,118,119,11.333307266235352,1,127,119,11.164153099060059,2,134,127,11.333307266235352,3,136,135,11.333307266235352,4,126,134,11.333307266235352,5,120,129,11.507664680480957,6,121,120,11.333307266235352,1,127,118,11.333307266235352,2,133,127,10.999974250793457,3,135,133,11.507664680480957,4,127,136,11.333307266235352,5,117,127,11.164153099060059,6,119,120,11.333307266235352,1,126,119,11.164153099060059,2,135,127,11.333307266235352,3,134,133,11.333307266235352,4,128,135,11.333307266235352,5,119,126,10.999974250793457,6,121,122,11.333307266235352,1,126,118,11.507664680480957,2,135,127,10.840554237365723,3,136,133,11.507664680480957,4,128,134,11.164153099060059,5,117,128,11.333307266235352,6,119,119,11.164153099060059,1,125,120,11.333307266235352,2,136,127,11.164153099060059,3,134,134,11.333307266235352,4,126,132,11.164153099060059,5,121,129,11.333307266235352,6,120,120,11.164153099060059,1,127,117,11.333307266235352,2,135,126,11.164153099060059,3,135,134,11.507664680480957,4,127,135,11.164153099060059,5,118,128,10.999974250793457,6,120,120,11.687472343444824,1,128,119,11.164153099060059,2,134,127,10.999974250793457,3,137,137,11.687472343444824,4,127,133,11.164153099060059,5,123,128,10.999974250793457,6,122,120,11.507664680480957,1,127,118,11.507664680480957,2,134,126,10.840554237365723,3,136,133,11.687472343444824,4,127,134,11.687472343444824,5,121,128,10.840554237365723,6,120,119,11.687472343444824,1,125,121,11.507664680480957,2,136,127,10.840554237365723,3,133,132,11.507664680480957,4,128,133,11.507664680480957,5,122,128,10.840554237365723,6,121,120,11.507664680480957,1,126,121,11.507664680480957,2,134,127,10.685688972473145,3,134,133,11.872987747192383,4,126,132,11.507664680480957,5,121,129,10.685688972473145,6,119,119,11.872987747192383,1,126,123,11.333307266235352,2,134,127,10.535186767578125,3,136,135,12.064488410949707,4,127,134,11.507664680480957,5,121,128,10.388864517211914,6,121,120,12.064488410949707,1,126,121,11.687472343444824,2,133,128,10.388864517211914,3,136,135,11.872987747192383,4,127,133,11.872987747192383,5,120,128,10.108084678649902,6,117,116,12.064488410949707,1,127,120,11.872987747192383,2,133,127,10.388864517211914,3,136,134,11.687472343444824,4,127,135,11.687472343444824,5,119,128,10.535186767578125,6,119,117,11.507664680480957,1,126,115,11.687472343444824,2,135,127,10.388864517211914,3,138,137,10.999974250793457,4,128,136,11.507664680480957,5,114,127,10.535186767578125,6,115,114,11.164153099060059,1,126,117,11.164153099060059,2,138,127,10.840554237365723,3,139,138,10.840554237365723,4,126,139,11.164153099060059,5,115,128,10.840554237365723,6,114,114,10.840554237365723,1,125,117,10.840554237365723,2,139,128,10.999974250793457,3,139,138,10.840554237365723,4,127,140,11.164153099060059,5,117,129,10.999974250793457,6,116,116,11.164153099060059,1,127,114,10.840554237365723,2,137,127,10.685688972473145,3,140,139,11.164153099060059,4,127,140,10.840554237365723,5,113,126,10.840554237365723,6,117,117,10.840554237365723,1,126,114,10.685688972473145,2,139,126,10.685688972473145,3,138,139,10.840554237365723,4,128,140,10.840554237365723,5,113,127,10.535186767578125,6,115,115,10.535186767578125,1,126,114,10.840554237365723,2,142,127,10.388864517211914,3,140,139,10.685688972473145,4,127,138,10.535186767578125,5,115,128,10.535186767578125,6,111,112,10.535186767578125,1,127,113,10.535186767578125,2,144,127,10.246551513671875,3,144,142,10.246551513671875,4,127,142,10.108084678649902,5,109,128,9.842082023620605,6,106,105,9.714262962341309,1,126,106,9.589720726013184,2,149,128,9.468331336975098,3,149,149,9.842082023620605,4,127,148,9.589720726013184,5,106,129,9.349977493286133,6,106,105,9.842082023620605,1,127,103,9.468331336975098,2,148,126,9.234545707702637,3,148,147,9.842082023620605,4,127,149,9.234545707702637,5,103,128,8.904741287231445,6,100,100,9.349977493286133,1,127,99,9.121930122375488,2,155,127,8.311092376708984,3,160,160,8.904741287231445,4,128,160,8.499979972839355,5,91,127,7.632635116577148,6,88,87,7.873665809631348,1,126,82,7.479982852935791,2,176,127,6.738722324371338,3,180,180,6.862370014190674,4,127,182,6.619453430175781,5,71,129,5.983985900878906,6,69,68,6.285699844360352,1,127,67,6.081286430358887,2,189,126,5.4999871253967285,3,189,188,6.131133079528809,4,127,190,6.0322442054748535,5,65,127,5.666653633117676,6,68,66,6.3931474685668945,1,127,68,6.285699844360352,2,186,128,5.798436164855957,3,186,188,6.504332542419434,4,128,188,6.0322442054748535,5,65,128,5.342844486236572,6,64,64,6.131133079528809,1,128,63,6.1818037033081055,2,190,126,5.459841251373291,3,189,188,6.1818037033081055,4,127,192,5.798436164855957,5,58,127,4.560965061187744,6,50,51,5.1232757568359375,1,128,53,4.953630447387695,2,202,127,4.202237606048584,3,206,206,4.764320373535156,4,127,204,4.794860363006592,5,51,129,4.0652079582214355,6,46,46,4.374258518218994,1,128,47,4.3236894607543945,2,212,127,3.875638723373413,3,207,206,4.426025390625,4,127,207,5.088423252105713,5,57,128,5.020122528076172,6,60,60,5.4999871253967285,1,126,60,5.7099103927612305,2,193,126,5.7538323402404785,3,190,189,5.936493873596191,4,128,190,6.0322442054748535,5,63,126,5.843736171722412,6,63,63,5.843736171722412,1,128,63,5.7538323402404785,2,189,126,5.7099103927612305,3,193,194,5.582076549530029,4,127,192,5.459841251373291,5,61,128,5.342844486236572,6,61,60,5.342844486236572,1,128,58,5.1232757568359375,2,195,127,4.8888773918151855,3,198,198,4.764320373535156,4,127,205,4.533322811126709,5,50,129,4.298840522766113,6,47,45,4.374258518218994,1,127,45,4.399989604949951,2,206,126,4.426025390625,3,207,206,4.348826885223389,4,127,209,4.348826885223389,5,45,128,3.9787142276763916,6,46,46,4.0874223709106445,1,127,44,3.95766282081604,2,213,127,3.5789389610290527,3,211,211,3.7587852478027344,4,127,213,3.6487717628479004,5,41,129,3.5117290019989014,6,42,40,3.4790616035461426,1,127,39,3.354252338409424,2,217,128,3.354252338409424,3,213,212,3.7029614448547363,4,128,212,3.4790616035461426,5,38,128,3.182971477508545,6,35,35,2.921868085861206,1,127,30,2.7703638076782227,2,221,127,2.9682469367980957,3,221,221,3.0161221027374268,4,127,222,2.812023639678955,5,33,128,2.6153786182403564,6,33,34,2.6524760723114014,1,127,33,2.7199935913085938,2,221,126,2.5972161293029785,3,224,226,2.187129259109497,4,126,229,2.239515542984009,5,27,127,2.25300669670105,6,29,29,2.6153786182403564,1,127,31,2.5793044567108154,2,223,127,2.0835604667663574,3,227,227,2.308636426925659,4,127,227,2.4444386959075928,5,30,128,2.131049156188965,6,30,30,2.2666614055633545,1,127,27,2.0161678791046143,2,229,126,1.677126169204712,3,229,229,2.0893807411193848,4,127,227,2.1494202613830566,5,26,128,1.806758999824524,6,27,25,2.1681108474731445,1,127,27,2.060601234436035,2,230,126,1.984080195426941,3,224,226,2.337494373321533,4,126,228,1.9946619272232056,5,25,127,1.776718020439148,6,28,27,2.2130126953125,1,128,24,1.9581104516983032,2,228,126,1.968416452407837,3,226,228,2.072017192840576,4,128,231,1.8560750484466553,5,26,128,1.8699957132339478,6,26,25,2.1618447303771973,1,128,25,2.1371378898620605,2,226,127,2.0326039791107178,3,224,226,2.315784215927124,4,127,227,2.6337966918945312,5,33,128,2.2874562740325928,6,29,28,2.910498857498169,1,127,31,2.865893602371216,2,222,127,2.389770746231079,3,223,225,2.8014914989471436,4,127,222,3.053054094314575,5,32,127,2.70035457611084,6,35,36,3.0161221027374268,1,127,32,3.0040090084075928,2,222,126,2.7910382747650146,3,217,218,3.252166271209717,4,127,217,3.6487717628479004,5,43,129,3.5961453914642334,6,45,42,4.109880447387695,1,128,42,4.274275779724121,2,210,127,4.298840522766113,3,205,206,4.645951747894287,4,127,203,5.194432258605957,5,59,128,5.459841251373291,6,64,65,6.0322442054748535,1,128,67,6.5613884925842285,2,182,128,7.056586742401123,3,177,179,7.479982852935791,4,127,174,8.130415916442871,5,86,128,8.404475212097168,6,92,92,9.0120267868042,1,126,94,9.121930122375488,2,154,127,9.349977493286133,3,149,149,10.108084678649902,4,127,149,10.108084678649902,5,112,128,10.246551513671875,6,111,111,10.535186767578125,1,125,112,10.535186767578125,2,142,127,10.840554237365723,3,140,139,10.999974250793457,4,127,141,10.999974250793457,5,117,127,10.840554237365723,6,116,117,10.999974250793457,1,127,115,11.333307266235352,2,135,127,10.840554237365723,3,135,134,11.333307266235352,4,126,137,11.164153099060059,5,121,128,11.333307266235352,6,120,120,11.333307266235352,1,127,117,11.333307266235352,2,135,127,11.164153099060059,3,136,136,11.164153099060059,4,129,136,11.164153099060059,5,117,127,11.333307266235352,6,121,119,11.333307266235352,1,126,119,11.333307266235352,2,136,127,11.164153099060059,3,134,135,11.507664680480957,4,128,132,11.164153099060059,5,122,128,10.999974250793457,6,120,119,11.687472343444824,1,127,119,11.333307266235352,2,133,127,10.999974250793457,3,136,137,11.687472343444824,4,128,134,11.164153099060059,5,120,127,10.999974250793457,6,119,121,11.507664680480957,1,126,120,11.507664680480957,2,134,128,10.840554237365723,3,135,134,11.687472343444824,4,126,135,11.507664680480957,5,121,128,10.840554237365723,6,122,122,11.687472343444824,1,128,118,11.507664680480957,2,133,126,10.840554237365723,3,135,135,11.687472343444824,4,128,134,11.507664680480957,5,120,129,10.840554237365723,6,120,120,11.507664680480957,1,128,119,11.687472343444824,2,134,128,10.685688972473145,3,135,134,11.872987747192383,4,128,135,11.507664680480957,5,121,129,10.685688972473145,6,121,120,11.872987747192383,1,126,121,11.507664680480957,2,131,129,10.535186767578125,3,136,136,11.872987747192383,4,126,133,11.687472343444824,5,120,128,10.388864517211914,6,117,116,11.872987747192383,1,126,120,11.872987747192383,2,134,128,10.388864517211914,3,137,137,12.064488410949707,4,127,135,11.872987747192383,5,123,128,10.246551513671875,6,117,118,11.872987747192383,1,125,119,12.064488410949707,2,134,127,10.388864517211914,3,135,136,11.687472343444824,4,127,137,12.064488410949707,5,120,128,10.685688972473145,6,121,120,11.507664680480957,1,126,120,11.872987747192383,2,133,127,10.685688972473145,3,134,133,11.333307266235352,4,127,135,11.872987747192383,5,120,126,10.840554237365723,6,122,120,11.507664680480957,1,128,120,11.687472343444824,2,135,128,11.164153099060059,3,136,134,11.333307266235352,4,127,134,11.507664680480957,5,121,128,11.164153099060059,6,119,121,11.333307266235352,1,126,121,11.164153099060059,2,135,126,11.333307266235352,3,137,136,11.333307266235352,4,129,136,11.333307266235352,5,117,128,11.333307266235352,6,119,119,11.507664680480957,1,127,119,11.164153099060059,2,134,127,11.164153099060059,3,135,134,11.507664680480957,4,127,135,11.333307266235352,5,120,129,11.164153099060059,6,118,120,11.333307266235352,1,126,119,11.164153099060059,2,137,127,11.507664680480957,3,136,134,11.333307266235352,4,127,133,11.507664680480957,5,120,128,10.999974250793457,6,122,120,11.333307266235352,1,126,120,11.507664680480957,2,134,127,10.999974250793457,3,133,133,11.507664680480957,4,128,134,11.164153099060059,5,120,127,11.333307266235352,6,120,121,11.333307266235352,1,127,121,11.333307266235352,2,136,126,11.164153099060059,3,136,135,11.333307266235352,4,127,135,11.164153099060059,5,120,128,11.333307266235352,6,120,120,11.333307266235352,1,126,120,11.333307266235352,2,135,129,11.164153099060059,3,135,133,11.507664680480957,4,128,134,11.164153099060059,5,121,128,10.999974250793457,6,119,120,11.687472343444824,1,126,119,11.164153099060059,2,134,128,11.164153099060059,3,135,133,11.507664680480957,4,127,135,11.333307266235352,5,120,127,10.999974250793457,6,118,119,11.507664680480957,1,125,119,11.507664680480957,2,133,127,10.840554237365723,3,135,132,11.687472343444824,4,128,133,11.507664680480957,5,121,127,10.840554237365723,6,122,122,11.507664680480957,1,128,118,11.687472343444824,2,137,127,10.840554237365723,3,133,134,11.507664680480957,4,126,134,11.507664680480957,5,122,127,10.840554237365723,6,123,121,11.687472343444824,1,126,122,11.687472343444824,2,133,128,10.685688972473145,3,135,135,11.872987747192383,4,127,134,11.507664680480957,5,119,127,10.685688972473145,6,119,117,11.872987747192383,1,127,122,11.507664680480957,2,134,127,10.388864517211914,3,137,136,12.064488410949707,4,127,132,11.507664680480957,5,121,129,10.535186767578125,6,118,118,12.064488410949707,1,126,118,11.872987747192383,2,132,129,10.388864517211914,3,136,136,11.872987747192383,4,127,135,11.872987747192383,5,122,128,10.246551513671875,6,119,120,12.064488410949707,1,126,121,11.872987747192383,2,133,127,10.388864517211914,3,137,136,11.687472343444824,4,126,134,11.872987747192383,5,119,128,10.685688972473145,6,120,120,11.507664680480957,1,127,117,11.872987747192383,2,133,127,10.685688972473145,3,137,137,11.333307266235352,4,128,134,11.872987747192383,5,120,128,10.685688972473145,6,118,117,11.507664680480957,1,127,119,11.687472343444824,2,134,126,11.164153099060059,3,136,137,11.333307266235352,4,127,135,11.507664680480957,5,119,128,11.164153099060059,6,119,119,11.333307266235352,1,125,119,11.164153099060059,2,135,127,11.333307266235352,3,137,136,11.164153099060059,4,127,136,11.507664680480957,5,118,127,11.333307266235352,6,119,120,11.507664680480957,1,125,119,11.164153099060059,2,134,127,11.164153099060059,3,135,135,11.507664680480957,4,127,133,11.164153099060059,5,120,128,11.164153099060059,6,119,120,11.507664680480957,1,127,117,11.164153099060059,2,135,126,11.333307266235352,3,133,133,11.507664680480957,4,127,136,11.333307266235352,5,119,128,10.999974250793457,6,119,119,11.333307266235352,1,126,117,11.507664680480957,2,137,126,10.999974250793457,3,136,134,11.333307266235352,4,127,134,11.333307266235352,5,120,127,11.333307266235352,6,121,121,11.164153099060059,1,126,120,11.333307266235352,2,134,127,11.164153099060059,3,136,135,11.333307266235352,4,127,135,11.164153099060059,5,117,128,11.333307266235352,6,121,120,11.164153099060059,1,127,120,11.333307266235352,2,136,128,11.164153099060059,3,135,135,11.507664680480957,4,126,135,11.164153099060059,5,119,128,11.164153099060059,6,120,119,11.507664680480957,1,127,120,11.333307266235352,2,133,127,10.999974250793457,3,136,134,11.687472343444824,4,126,133,11.164153099060059,5,120,128,10.999974250793457,6,120,120,11.687472343444824,1,126,120,11.507664680480957,2,135,127,10.840554237365723,3,136,136,11.507664680480957,4,127,135,11.687472343444824,5,121,129,10.840554237365723,6,120,118,11.507664680480957,1,126,119,11.687472343444824,2,134,127,10.840554237365723,3,134,132,11.507664680480957,4,127,133,11.507664680480957,5,119,127,10.685688972473145,6,119,120,11.687472343444824,1,126,120,11.507664680480957,2,134,127,10.685688972473145,3,136,136,11.872987747192383,4,127,131,11.507664680480957,5,121,128,10.685688972473145,6,120,121,11.872987747192383,1,126,122,11.507664680480957,2,136,128,10.535186767578125,3,138,138,12.064488410949707,4,126,133,11.507664680480957,5,121,128,10.388864517211914,6,118,119,11.872987747192383,1,127,119,11.872987747192383,2,133,127,10.388864517211914,3,137,137,12.064488410949707,4,127,136,11.872987747192383,5,122,128,10.108084678649902,6,119,118,11.872987747192383,1,127,117,12.064488410949707,2,135,128,10.388864517211914,3,136,137,11.687472343444824,4,128,134,11.872987747192383,5,119,128,10.685688972473145,6,120,120,11.507664680480957,1,128,118,11.872987747192383,2,134,127,10.685688972473145,3,136,134,11.333307266235352,4,127,133,11.872987747192383,5,120,129,10.840554237365723,6,119,118,11.507664680480957,1,125,119,11.507664680480957,2,137,128,11.333307266235352,3,135,135,11.333307266235352,4,127,135,11.507664680480957,5,120,128,11.164153099060059,6,120,120,11.333307266235352,1,126,119,11.333307266235352,2,134,127,11.507664680480957,3,135,135,11.164153099060059,4,127,137,11.507664680480957,5,118,126,11.333307266235352,6,119,119,11.507664680480957,1,125,120,11.164153099060059,2,134,126,10.999974250793457,3,136,136,11.687472343444824,4,128,134,11.164153099060059,5,119,128,11.164153099060059,6,121,121,11.333307266235352,1,127,118,11.164153099060059,2,136,128,11.333307266235352,3,135,137,11.507664680480957,4,127,134,11.333307266235352,5,118,128,10.999974250793457,6,118,119,11.164153099060059,1,127,119,11.507664680480957,2,135,127,10.999974250793457,3,135,134,11.333307266235352,4,127,137,11.333307266235352,5,119,128,11.164153099060059,6,120,121,11.333307266235352,1,127,121,11.507664680480957,2,135,128,11.164153099060059,3,137,136,11.333307266235352,4,126,135,11.164153099060059,5,119,128,11.333307266235352,6,121,120,11.333307266235352,1,126,119,11.333307266235352,2,132,127,11.164153099060059,3,136,136,11.507664680480957,4,128,135,11.164153099060059,5,121,128,11.164153099060059,6,121,121,11.507664680480957,1,127,119,11.333307266235352,2,134,128,10.999974250793457,3,134,134,11.687472343444824,4,127,135,11.164153099060059,5,121,128,10.999974250793457,6,121,119,11.687472343444824,1,126,119,11.507664680480957,2,136,128,10.840554237365723,3,135,135,11.507664680480957,4,127,133,11.687472343444824,5,121,128,10.840554237365723,6,119,120,11.507664680480957,1,126,119,11.687472343444824,2,134,127,10.840554237365723,3,133,133,11.507664680480957,4,127,132,11.507664680480957,5,120,128,10.685688972473145,6,120,119,11.687472343444824,1,128,120,11.507664680480957,2,135,127,10.685688972473145,3,136,135,11.872987747192383,4,126,131,11.507664680480957,5,122,128,10.685688972473145,6,119,121,11.872987747192383,1,126,122,11.507664680480957,2,133,127,10.535186767578125,3,134,136,12.064488410949707,4,127,134,11.507664680480957,5,119,128,10.388864517211914,6,116,118,12.064488410949707,1,126,121,11.687472343444824,2,134,127,10.535186767578125,3,135,134,12.064488410949707,4,128,136,11.872987747192383,5,121,127,10.246551513671875,6,117,118,11.872987747192383,1,126,120,12.064488410949707,2,134,127,10.388864517211914,3,135,133,11.507664680480957,4,127,134,11.872987747192383,5,119,128,10.685688972473145,6,121,121,11.507664680480957,1,125,120,11.872987747192383,2,135,127,10.685688972473145,3,134,134,11.333307266235352,4,127,132,11.687472343444824,5,119,128,10.840554237365723,6,119,119,11.507664680480957,1,126,119,11.507664680480957,2,137,128,11.333307266235352,3,135,134,11.164153099060059,4,127,135,11.507664680480957,5,120,128,11.164153099060059,6,121,120,11.333307266235352,1,124,119,11.164153099060059,2,134,127,11.333307266235352,3,136,136,11.333307266235352,4,127,137,11.333307266235352,5,117,128,11.507664680480957,6,120,119,11.333307266235352,1,126,120,11.333307266235352,2,135,127,10.999974250793457,3,138,136,11.687472343444824,4,127,135,11.164153099060059,5,120,129,11.164153099060059,6,118,118,11.507664680480957,1,127,117,11.164153099060059,2,136,127,11.333307266235352,3,134,133,11.333307266235352,4,127,137,11.507664680480957,5,118,127,10.999974250793457,6,120,121,11.333307266235352,1,125,120,11.507664680480957,2,133,126,10.999974250793457,3,134,134,11.333307266235352,4,127,133,11.164153099060059,5,116,128,11.333307266235352,6,121,121,11.333307266235352,1,126,119,11.333307266235352,2,134,128,11.164153099060059,3,136,137,11.333307266235352,4,127,134,11.164153099060059,5,121,129,11.333307266235352,6,120,119,11.164153099060059,1,126,120,11.333307266235352,2,135,127,11.164153099060059,3,134,133,11.507664680480957,4,127,134,11.333307266235352,5,122,128,11.164153099060059,6,121,120,11.507664680480957,1,125,120,11.333307266235352,2,134,127,10.999974250793457,3,134,133,11.687472343444824,4,127,134,11.164153099060059,5,120,129,10.999974250793457,6,119,119,11.687472343444824,1,127,118,11.507664680480957,2,137,126,10.685688972473145,3,135,136,11.687472343444824,4,127,135,11.507664680480957,5,123,128,10.840554237365723,6,120,120,11.507664680480957,1,127,121,11.687472343444824,2,133,127,10.840554237365723,3,134,134,11.507664680480957,4,127,134,11.507664680480957,5,120,128,10.840554237365723,6,122,120,11.507664680480957,1,125,121,11.687472343444824,2,134,127,10.685688972473145,3,135,135,11.872987747192383,4,127,133,11.507664680480957,5,117,127,10.685688972473145,6,120,119,11.872987747192383,1,126,121,11.507664680480957,2,132,127,10.535186767578125,3,135,133,11.872987747192383,4,128,136,11.687472343444824,5,123,128,10.388864517211914,6,119,118,12.064488410949707,1,126,119,11.872987747192383,2,132,127,10.388864517211914,3,135,134,12.064488410949707,4,128,133,11.687472343444824,5,121,128,10.108084678649902,6,119,119,11.872987747192383,1,128,117,11.872987747192383,2,135,126,10.246551513671875,3,137,136,11.507664680480957,4,128,136,11.687472343444824,5,118,128,10.388864517211914,6,117,118,11.164153099060059,1,127,117,11.687472343444824,2,139,127,10.246551513671875,3,139,139,10.999974250793457,4,127,139,11.333307266235352,5,116,127,10.388864517211914,6,114,114,10.999974250793457,1,126,114,10.999974250793457,2,139,128,10.685688972473145,3,142,143,10.685688972473145,4,126,140,10.685688972473145,5,113,129,10.388864517211914,6,113,112,10.535186767578125,1,126,114,10.535186767578125,2,142,128,10.388864517211914,3,142,141,10.388864517211914,4,127,142,10.535186767578125,5,112,127,10.246551513671875,6,111,111,10.388864517211914,1,126,110,10.108084678649902,2,146,127,9.842082023620605,3,147,146,10.246551513671875,4,128,146,9.842082023620605,5,107,128,9.589720726013184,6,104,104,9.589720726013184,1,127,103,9.234545707702637,2,153,128,9.121930122375488,3,155,155,8.799979209899902,4,127,160,8.499979972839355,5,93,129,7.957428455352783,6,89,87,7.957428455352783,1,126,84,7.873665809631348,2,172,128,7.479982852935791,3,172,171,7.479982852935791,4,127,176,7.262118816375732,5,78,128,7.056586742401123,6,77,77,6.799983978271484,1,128,72,6.619453430175781,2,186,127,6.23331880569458,3,186,185,6.131133079528809,4,127,188,5.936493873596191,5,65,128,5.843736171722412,6,65,64,5.7099103927612305,1,127,62,5.62404727935791,2,193,127,5.381282329559326,3,194,196,5.420277118682861,4,127,194,5.088423252105713,5,58,127,4.857131481170654,6,57,57,4.857131481170654,1,128,52,4.426025390625,2,205,127,4.1787614822387695,3,207,209,4.225978374481201,4,127,213,3.855661392211914,5,46,127,3.666658401489258,6,44,43,3.7587852478027344,1,128,39,3.631059408187866,2,213,126,3.339277982711792,3,213,213,3.4629547595977783,4,127,216,3.431185007095337,5,41,127,3.182971477508545,6,39,38,3.1694839000701904,1,128,35,3.11665940284729,2,219,126,2.921868085861206,3,219,219,3.0909018516540527,4,127,220,3.1965737342834473,5,38,128,2.7910382747650146,6,34,34,3.0161221027374268,1,127,33,2.7399206161499023,2,224,126,2.382160186767578,3,224,224,2.6153786182403564,4,128,223,2.5355873107910156,5,31,128,2.0835604667663574,6,31,31,2.3448221683502197,1,127,27,2.131049156188965,2,229,127,1.8560750484466553,3,230,230,2.180752992630005,4,128,228,2.107037305831909,5,26,128,1.7683173418045044,6,24,24,1.8984726667404175,1,128,23,1.8841265439987183,2,230,126,1.5747331380844116,3,231,233,1.811133861541748,4,127,231,1.7234982252120972,5,24,127,1.35017728805542,6,21,21,1.6733741760253906,1,128,23,1.665920376777649,2,232,127,1.387751817703247,3,231,232,1.601709246635437,4,127,233,1.5390911102294922,5,19,128,-249.33273315429688,4,62,66,31.16659164428711,5,40,127,-373.9991149902344,4,68,80,49.86655044555664,5,56,127,1.1816718578338623,6,20,20,1.4870741367340088,1,128,20,1.6439522504806519,2,231,127,1.73549485206604,3,227,229,1.8841265439987183,4,127,232,1.97883141040802,5,25,129,1.7517523765563965,6,25,23,1.8288464546203613,1,128,22,1.811133861541748,2,231,126,1.677126169204712,3,229,228,1.5327832698822021,4,127,234,1.6733741760253906,5,24,128,-186.9995574951172,4,67,65,49.86655044555664,5,55,128,-373.9991149902344,4,81,79,35.61896514892578,5,47,128,1.4060118198394775,6,23,21,1.73549485206604,1,128,24,1.811133861541748,2,230,127,1.8841265439987183,3,230,230,1.8984726667404175,4,127,230,1.984080195426941,5,24,128,-186.9995574951172,4,66,66,62.33318328857422,5,58,128,1.5265270471572876,6,23,22,1.7558645009994507,1,128,24,1.7234982252120972,2,229,127,1.7517523765563965,3,231,231,1.7980726957321167,4,127,231,1.7517523765563965,5,25,129,1.6622182130813599,6,23,23,1.665920376777649,1,128,22,1.5914857387542725,2,233,126,1.588106632232666,3,232,232,1.460934042930603,4,127,235,1.5111075639724731,5,22,128,-249.33273315429688,4,64,66,33.99991989135742,5,41,127,-249.33273315429688,4,71,76,46.7498893737793,5,54,128,1.189186453819275,6,22,21,1.4695446491241455,1,128,23,1.5454509258270264,2,233,127,1.5422643423080444,3,231,233,1.564849853515625,4,127,233,1.4524238109588623,5,22,128,-249.33273315429688,4,64,67,26.714223861694336,5,34,128,-249.33273315429688,4,71,71,67.99983978271484,5,67,127,1.1742515563964844,6,21,21,1.4753416776657104,1,127,21,1.4930105209350586,2,231,127,1.5111075639724731,3,231,232,1.5847419500350952,4,126,233,1.4524238109588623,5,20,129,-186.9995574951172,4,66,69,27.703638076782227,5,34,128,-249.33273315429688,4,75,73,67.99983978271484,5,66,128,1.255030632019043,6,22,21,1.4247586727142334,1,128,21,1.478257417678833,2,232,127,1.340498685836792,3,233,234,1.3526188135147095,4,127,233,1.387751817703247,5,21,127,-249.33273315429688,4,64,66,33.99991989135742,5,43,128,-249.33273315429688,4,74,75,53.42844772338867,5,60,127,1.1437281370162964,6,20,20,1.335711121559143,1,128,19,1.3929203748703003,2,233,127,1.35017728805542,3,234,235,1.340498685836792,4,127,235,1.4384580850601196,5,23,127,-249.33273315429688,4,63,68,29.919931411743164,5,36,129,-186.9995574951172,4,75,75,67.99983978271484,5,66,126,1.196797251701355,6,20,19,1.5615829229354858,1,128,21,1.73549485206604,2,230,127,1.7314773797988892,3,228,228,1.9736101627349854,4,127,227,2.143261432647705,5,29,127,2.0216169357299805,6,29,30,2.337494373321533,1,128,28,2.2462410926818848,2,226,127,2.1935431957244873,3,224,224,2.518512725830078,4,127,223,2.64310359954834,5,34,128,2.50166654586792,6,36,36,2.865893602371216,1,128,34,2.991992950439453,2,220,127,3.053054094314575,3,215,216,3.721384048461914,4,127,212,3.631059408187866,5,43,129,3.495319128036499,6,44,43,3.999990701675415,1,128,42,3.936832904815674,2,210,127,3.721384048461914,3,207,208,4.479031085968018,4,127,209,4.5060133934021,5,48,129,4.0874223709106445,6,50,49,4.986655235290527,1,129,52,5.020122528076172,2,197,126,4.452370643615723,3,201,200,5.342844486236572,4,127,195,5.540727615356445,5,62,129,5.054042339324951,6,65,66,6.285699844360352,1,127,63,6.738722324371338,2,182,127,5.936493873596191,3,183,182,6.678555965423584,4,127,185,6.990638256072998,5,72,128,6.23331880569458,6,76,75,6.990638256072998,1,127,72,7.262118816375732,2,178,126,6.925909519195557,3,173,172,7.555537700653076,4,127,176,8.311092376708984,5,85,128,7.632635116577148,6,88,88,8.499979972839355,1,127,89,8.499979972839355,2,165,127,8.404475212097168,3,164,162,8.404475212097168,4,127,164,8.597681045532227,5,89,129,8.21976089477539,6,89,88,8.21976089477539,1,125,88,8.042991638183594,2,167,128,8.130415916442871,3,167,167,8.21976089477539,4,126,166,8.499979972839355,5,91,128,8.597681045532227,6,91,93,8.799979209899902,1,127,92,8.697653770446777,2,162,126,8.697653770446777,3,160,159,9.234545707702637,4,127,158,8.904741287231445,5,96,127,8.904741287231445,6,96,96,9.0120267868042,1,127,96,8.799979209899902,2,161,128,8.799979209899902,3,160,160,8.799979209899902,4,127,162,8.597681045532227,5,89,128,8.21976089477539,6,91,91,8.499979972839355,1,127,90,8.799979209899902,2,164,126,8.597681045532227,3,161,161,8.904741287231445,4,126,160,9.0120267868042,5,97,128,9.0120267868042,6,99,98,9.121930122375488,1,125,99,9.349977493286133,2,156,126,9.234545707702637,3,156,156,9.234545707702637,4,126,154,9.234545707702637,5,100,129,9.468331336975098,6,102,103,9.349977493286133,1,128,101,9.349977493286133,2,154,127,9.234545707702637,3,153,152,9.468331336975098,4,127,153,9.121930122375488,5,98,128,8.904741287231445,6,96,97,9.349977493286133,1,127,97,8.904741287231445,2,158,126,8.597681045532227,3,160,160,9.0120267868042,4,127,161,8.499979972839355,5,91,127,8.21976089477539,6,89,89,8.597681045532227,1,127,89,8.311092376708984,2,166,127,7.632635116577148,3,167,168,7.957428455352783,4,128,173,7.555537700653076,5,79,128,6.678555965423584,6,73,74,6.678555965423584,1,128,70,6.131133079528809,2,190,128,4.986655235290527,3,198,199,4.5060133934021,4,127,210,3.855661392211914,5,42,128,2.8769161701202393,6,33,31,2.2130126953125,1,127,24,1.4989943504333496,2,235,128,0.7632635235786438,3,238,239,-373.9991149902344,2,154,204,17.80948257446289,3,232,233,0.22564050555229187,4,126,238,-43.99989700317383,3,43,133,15.583295822143555,4,127,234,-25.793041229248047,3,24,127,16.62218475341797,4,127,232,-26.714223861694336,3,27,126,15.914856910705566,4,127,233,-28.769163131713867,3,29,129,14.666633605957031,4,126,234,-31.16659164428711,3,30,127,14.384581565856934,4,127,233,-33.99991989135742,3,32,129,13.599967956542969,4,127,234,-35.61896514892578,3,32,126,13.357111930847168,4,127,234,-37.39990997314453,3,34,127,12.896520614624023,4,127,234,-39.36832809448242,3,36,128,12.677935600280762,4,126,235,-41.555458068847656,3,38,129,12.677935600280762,4,127,233,-41.555458068847656,3,39,126,12.677935600280762,4,128,233,-39.36832809448242,3,37,127,12.677935600280762,4,128,232,-37.39990997314453,3,34,129,13.122776985168457,4,128,233,-33.99991989135742,3,33,126,13.599967956542969,4,127,233,-32.521663665771484,3,31,126,14.384581565856934,4,127,232,-28.769163131713867,3,28,126,14.959965705871582,4,126,232,-26.714223861694336,3,27,128,15.914856910705566,4,126,233,-24.128976821899414,3,23,127,17.395307540893555,4,127,231,-22.666614532470703,3,20,128,19.179441452026367,4,127,231,-20.777729034423828,3,19,127,21.37137794494629,4,128,229,-18.699954986572266,3,17,127,24.93327522277832,4,126,227,-17.395307540893555,3,17,129,32.521663665771484,4,126,222,-21.37137794494629,3,22,128,24.93327522277832,4,127,228,0.5675252676010132,5,17,128,-249.33273315429688,4,52,76,21.37137794494629,5,25,129,-186.9995574951172,4,66,66,74.79981994628906,5,66,128,1.3031327724456787,6,33,32,2.88802433013916,1,127,31,2.780662775039673,2,221,126,2.6337966918945312,3,219,218,3.2380876541137695,4,127,218,3.4155170917510986,5,44,128,3.5282933712005615,6,46,47,4.8888773918151855,1,127,55,5.4999871253967285,2,189,126,5.62404727935791,3,184,184,7.262118816375732,4,127,177,7.873665809631348,5,83,127,7.192290782928467,6,87,89,9.121930122375488,1,126,95,9.468331336975098,2,154,127,8.597681045532227,3,153,152,9.973310470581055,4,127,149,10.388864517211914,5,109,128,9.589720726013184,6,109,111,10.685688972473145,1,126,109,10.999974250793457,2,142,127,10.108084678649902,3,140,140,10.840554237365723,4,127,139,11.333307266235352,5,118,128,10.535186767578125,6,115,115,11.164153099060059,1,126,117,11.333307266235352,2,138,127,11.164153099060059,3,137,135,11.164153099060059,4,127,136,11.507664680480957,5,118,129,10.999974250793457,6,117,117,11.333307266235352,1,126,118,11.164153099060059,2,137,128,11.333307266235352,3,136,135,11.333307266235352,4,127,134,11.333307266235352,5,118,128,11.507664680480957,6,120,121,11.507664680480957,1,126,120,11.333307266235352,2,134,128,11.164153099060059,3,136,135,11.507664680480957,4,127,135,11.333307266235352,5,119,127,11.164153099060059,6,119,118,11.333307266235352,1,127,117,11.333307266235352,2,133,127,11.333307266235352,3,134,133,11.507664680480957,4,127,136,11.333307266235352,5,120,127,11.164153099060059,6,119,119,11.333307266235352,1,127,119,11.507664680480957,2,135,129,10.999974250793457,3,134,134,11.507664680480957,4,128,134,11.333307266235352,5,119,128,11.333307266235352,6,120,121,11.333307266235352,1,126,120,11.333307266235352,2,134,128,11.164153099060059,3,135,134,11.333307266235352,4,126,135,11.164153099060059,5,122,128,11.507664680480957,6,120,119,11.164153099060059,1,127,119,11.507664680480957,2,134,127,11.164153099060059,3,136,136,11.507664680480957,4,128,133,11.164153099060059,5,120,128,11.164153099060059,6,120,120,11.687472343444824,1,127,119,11.333307266235352,2,134,126,11.164153099060059,3,134,134,11.687472343444824,4,128,134,11.164153099060059,5,120,128,10.999974250793457,6,121,120,11.687472343444824,1,127,120,11.687472343444824,2,133,127,10.685688972473145,3,136,133,11.687472343444824,4,126,137,11.687472343444824,5,121,128,10.840554237365723,6,120,120,11.687472343444824,1,126,119,11.687472343444824,2,133,127,10.840554237365723,3,133,132,11.507664680480957,4,127,134,11.687472343444824,5,119,128,10.840554237365723,6,121,119,11.687472343444824,1,126,121,11.687472343444824,2,134,128,10.685688972473145,3,136,136,11.872987747192383,4,126,132,11.687472343444824,5,120,127,10.685688972473145,6,118,117,11.872987747192383,1,126,120,11.507664680480957,2,133,127,10.535186767578125,3,136,134,12.064488410949707,4,127,133,11.507664680480957,5,118,127,10.388864517211914,6,120,118,12.064488410949707,1,126,119,11.872987747192383,2,132,127,10.388864517211914,3,137,137,12.064488410949707,4,127,135,11.872987747192383,5,120,128,10.108084678649902,6,120,120,12.064488410949707,1,125,119,11.872987747192383,2,133,127,10.535186767578125,3,135,134,11.507664680480957,4,127,135,12.064488410949707,5,119,127,10.685688972473145,6,119,117,11.507664680480957,1,127,117,12.064488410949707,2,133,127,10.685688972473145,3,135,133,11.333307266235352,4,126,137,11.687472343444824,5,120,127,10.840554237365723,6,119,118,11.507664680480957,1,125,120,11.687472343444824,2,137,127,11.333307266235352,3,138,137,11.333307266235352,4,127,134,11.507664680480957,5,121,128,11.333307266235352,6,122,120,11.333307266235352,1,126,120,11.164153099060059,2,136,127,11.333307266235352,3,136,135,11.333307266235352,4,128,136,11.333307266235352,5,117,126,11.507664680480957,6,120,119,11.507664680480957,1,127,119,11.164153099060059,2,133,128,11.164153099060059,3,137,135,11.507664680480957,4,127,135,11.333307266235352,5,122,129,11.164153099060059,6,119,120,11.507664680480957,1,126,119,11.164153099060059,2,137,127,11.333307266235352,3,135,134,11.507664680480957,4,126,134,11.507664680480957,5,120,129,11.164153099060059,6,121,120,11.333307266235352,1,126,118,11.507664680480957,2,138,126,10.999974250793457,3,135,133,11.507664680480957,4,127,136,11.333307266235352,5,117,127,11.507664680480957,6,121,121,11.164153099060059,1,125,120,11.507664680480957,2,134,128,11.164153099060059,3,133,132,11.333307266235352,4,127,134,11.164153099060059,5,120,128,11.333307266235352,6,120,121,11.164153099060059,1,126,118,11.507664680480957,2,134,125,11.164153099060059,3,134,134,11.507664680480957,4,126,136,11.164153099060059,5,121,129,10.999974250793457,6,119,120,11.687472343444824,1,126,120,11.333307266235352,2,132,127,10.999974250793457,3,136,135,11.687472343444824,4,128,134,11.164153099060059,5,119,129,10.999974250793457,6,120,121,11.687472343444824,1,126,120,11.507664680480957,2,135,128,10.840554237365723,3,133,132,11.687472343444824,4,128,134,11.507664680480957,5,121,127,10.840554237365723,6,120,119,11.687472343444824,1,128,117,11.687472343444824,2,133,128,10.840554237365723,3,134,134,11.507664680480957,4,127,135,11.687472343444824,5,121,128,10.840554237365723,6,120,120,11.507664680480957,1,127,118,11.687472343444824,2,134,126,10.685688972473145,3,136,135,11.872987747192383,4,127,132,11.507664680480957,5,121,128,10.685688972473145,6,118,118,12.064488410949707,1,126,121,11.333307266235352,2,132,127,10.535186767578125,3,135,135,12.064488410949707,4,127,133,11.687472343444824,5,122,128,10.388864517211914,6,117,117,12.064488410949707,1,126,119,11.872987747192383,2,131,127,10.388864517211914,3,137,136,12.064488410949707,4,126,137,11.872987747192383,5,120,129,10.246551513671875,6,119,119,12.064488410949707,1,126,119,11.872987747192383,2,136,127,10.535186767578125,3,134,132,11.687472343444824,4,127,135,11.872987747192383,5,121,128,10.685688972473145,6,119,119,11.687472343444824,1,126,119,12.064488410949707,2,133,128,10.685688972473145,3,134,133,11.333307266235352,4,127,135,11.872987747192383,5,120,128,10.840554237365723,6,121,122,11.507664680480957,1,126,120,11.507664680480957,2,134,126,11.333307266235352,3,134,133,11.333307266235352,4,127,134,11.507664680480957,5,118,127,11.164153099060059,6,119,119,11.333307266235352,1,127,119,11.333307266235352,2,135,128,11.333307266235352,3,135,134,11.333307266235352,4,127,135,11.333307266235352,5,121,128,11.507664680480957,6,121,120,11.507664680480957,1,127,120,11.164153099060059,2,136,127,11.164153099060059,3,134,135,11.687472343444824,4,127,135,11.333307266235352,5,120,127,11.164153099060059,6,119,119,11.333307266235352,1,126,119,11.333307266235352,2,134,127,11.333307266235352,3,132,133,11.507664680480957,4,128,135,11.333307266235352,5,122,129,11.164153099060059,6,118,118,11.333307266235352,1,127,118,11.507664680480957,2,135,127,10.999974250793457,3,135,134,11.333307266235352,4,128,135,11.333307266235352,5,117,127,11.333307266235352,6,120,119,11.333307266235352,1,125,119,11.333307266235352,2,137,126,11.164153099060059,3,136,135,11.333307266235352,4,127,134,11.164153099060059,5,121,128,11.333307266235352,6,118,117,11.333307266235352,1,127,120,11.333307266235352,2,133,127,11.164153099060059,3,133,135,11.507664680480957,4,126,134,11.333307266235352,5,120,127,10.999974250793457,6,118,117,11.687472343444824,1,127,118,11.164153099060059,2,135,127,11.164153099060059,3,135,134,11.687472343444824,4,128,135,11.164153099060059,5,118,127,11.164153099060059,6,120,121,11.507664680480957,1,128,118,11.687472343444824,2,132,127,10.685688972473145,3,134,133,11.687472343444824,4,128,135,11.687472343444824,5,121,127,10.840554237365723,6,121,121,11.507664680480957,1,126,121,11.687472343444824,2,133,127,10.840554237365723,3,133,132,11.507664680480957,4,127,134,11.687472343444824,5,118,126,10.685688972473145,6,121,122,11.687472343444824,1,125,121,11.507664680480957,2,135,127,10.685688972473145,3,136,137,12.064488410949707,4,127,132,11.687472343444824,5,121,127,10.685688972473145,6,120,119,11.872987747192383,1,127,120,11.507664680480957,2,135,127,10.535186767578125,3,135,133,12.064488410949707,4,127,134,11.507664680480957,5,121,127,10.388864517211914,6,119,116,12.064488410949707,1,126,119,11.872987747192383,2,132,127,10.388864517211914,3,137,135,12.064488410949707,4,127,137,11.872987747192383,5,119,128,10.246551513671875,6,118,119,11.872987747192383,1,126,117,12.064488410949707,2,134,127,10.388864517211914,3,135,133,11.687472343444824,4,127,135,11.872987747192383,5,121,129,10.685688972473145,6,121,120,11.687472343444824,1,128,119,11.872987747192383,2,134,127,10.685688972473145,3,134,133,11.333307266235352,4,127,135,11.687472343444824,5,121,128,10.840554237365723,6,119,120,11.507664680480957,1,126,118,11.507664680480957,2,134,127,11.333307266235352,3,135,133,11.333307266235352,4,127,135,11.507664680480957,5,121,128,11.164153099060059,6,120,121,11.333307266235352,1,127,118,11.164153099060059,2,136,127,11.507664680480957,3,135,135,11.164153099060059,4,127,136,11.507664680480957,5,122,130,11.333307266235352,6,119,118,11.507664680480957,1,128,119,11.333307266235352,2,134,127,11.164153099060059,3,134,134,11.507664680480957,4,127,134,11.333307266235352,5,118,128,11.164153099060059,6,121,120,11.507664680480957,1,126,119,11.164153099060059,2,135,127,11.333307266235352,3,135,134,11.507664680480957,4,127,134,11.507664680480957,5,120,128,10.999974250793457,6,120,120,11.333307266235352,1,126,118,11.507664680480957,2,135,126,10.999974250793457,3,134,134,11.507664680480957,4,127,136,11.333307266235352,5,120,128,11.507664680480957,6,121,122,11.164153099060059,1,127,118,11.333307266235352,2,135,127,11.333307266235352,3,136,136,11.333307266235352,4,127,133,11.164153099060059,5,119,128,11.333307266235352,6,119,120,11.333307266235352,1,126,120,11.333307266235352,2,134,127,11.164153099060059,3,135,135,11.507664680480957,4,127,134,11.333307266235352,5,120,129,10.999974250793457,6,119,120,11.687472343444824,1,127,118,11.333307266235352,2,134,127,10.999974250793457,3,136,134,11.687472343444824,4,128,133,11.164153099060059,5,120,128,11.164153099060059,6,121,122,11.507664680480957,1,125,120,11.687472343444824,2,134,128,10.840554237365723,3,133,132,11.687472343444824,4,127,134,11.687472343444824,5,118,127,10.840554237365723,6,120,120,11.507664680480957,1,126,119,11.687472343444824,2,135,127,10.840554237365723,3,134,133,11.507664680480957,4,127,135,11.687472343444824,5,121,129,10.685688972473145,6,120,121,11.687472343444824,1,127,119,11.687472343444824,2,134,128,10.840554237365723,3,136,135,11.872987747192383,4,127,134,11.507664680480957,5,120,128,10.685688972473145,6,120,118,11.872987747192383,1,127,121,11.507664680480957,2,132,128,10.535186767578125,3,136,135,12.064488410949707,4,127,133,11.687472343444824,5,118,127,10.388864517211914,6,119,119,12.064488410949707,1,126,119,11.687472343444824,2,133,127,10.535186767578125,3,135,134,12.064488410949707,4,127,133,11.872987747192383,5,122,130,10.246551513671875,6,118,117,11.872987747192383,1,126,118,12.064488410949707,2,135,128,10.388864517211914,3,135,135,11.687472343444824,4,126,134,11.872987747192383,5,120,129,10.685688972473145,6,120,119,11.687472343444824,1,126,120,11.872987747192383,2,133,126,10.685688972473145,3,137,136,11.333307266235352,4,127,135,11.872987747192383,5,121,129,10.840554237365723,6,119,120,11.507664680480957,1,127,118,11.687472343444824,2,134,128,11.333307266235352,3,135,134,11.333307266235352,4,127,135,11.507664680480957,5,120,128,11.333307266235352,6,119,119,11.333307266235352,1,127,118,11.164153099060059,2,134,127,11.333307266235352,3,135,135,11.333307266235352,4,128,136,11.507664680480957,5,119,127,11.333307266235352,6,118,117,11.507664680480957,1,126,118,11.333307266235352,2,132,128,10.999974250793457,3,136,137,11.687472343444824,4,127,135,11.164153099060059,5,122,129,11.333307266235352,6,120,119,11.507664680480957,1,126,120,11.164153099060059,2,134,128,11.333307266235352,3,136,136,11.507664680480957,4,128,135,11.333307266235352,5,122,129,10.999974250793457,6,120,119,11.333307266235352,1,127,119,11.507664680480957,2,136,128,10.999974250793457,3,133,134,11.333307266235352,4,127,134,11.333307266235352,5,121,128,11.333307266235352,6,121,121,11.333307266235352,1,128,120,11.333307266235352,2,135,127,11.164153099060059,3,136,137,11.333307266235352,4,126,134,11.164153099060059,5,119,128,11.507664680480957,6,119,120,11.164153099060059,1,126,121,11.333307266235352,2,135,127,11.333307266235352,3,136,133,11.507664680480957,4,127,136,11.164153099060059,5,121,129,11.164153099060059,6,121,121,11.687472343444824,1,126,121,11.164153099060059,2,132,126,11.164153099060059,3,133,133,11.687472343444824,4,127,135,11.164153099060059,5,120,128,10.999974250793457,6,121,120,11.687472343444824,1,126,119,11.507664680480957,2,133,127,10.840554237365723,3,135,134,11.687472343444824,4,128,135,11.507664680480957,5,119,128,10.840554237365723,6,121,120,11.687472343444824,1,126,120,11.507664680480957,2,135,127,10.840554237365723,3,133,132,11.507664680480957,4,127,133,11.687472343444824,5,120,128,10.840554237365723,6,121,121,11.507664680480957,1,127,120,11.687472343444824,2,132,126,10.685688972473145,3,135,135,11.872987747192383,4,127,135,11.507664680480957,5,120,127,10.685688972473145,6,117,119,12.064488410949707,1,126,120,11.507664680480957,2,131,127,10.535186767578125,3,136,134,12.064488410949707,4,127,132,11.507664680480957,5,122,127,10.388864517211914,6,119,120,12.064488410949707,1,126,119,11.872987747192383,2,133,128,10.388864517211914,3,138,137,12.064488410949707,4,126,136,11.687472343444824,5,120,128,10.246551513671875,6,120,119,11.872987747192383,1,127,119,12.064488410949707,2,133,128,10.388864517211914,3,134,133,11.687472343444824,4,128,134,11.872987747192383,5,118,128,10.685688972473145,6,118,116,11.507664680480957,1,126,119,11.872987747192383,2,135,127,10.685688972473145,3,135,136,11.333307266235352,4,128,134,11.872987747192383,5,117,128,10.840554237365723,6,120,120,11.507664680480957,1,127,120,11.687472343444824,2,134,127,11.164153099060059,3,134,133,11.333307266235352,4,127,134,11.507664680480957,5,119,127,11.333307266235352,6,117,118,11.333307266235352,1,126,119,11.164153099060059,2,137,128,11.333307266235352,3,136,137,11.507664680480957,4,127,134,11.333307266235352,5,119,128,11.333307266235352,6,119,119,11.687472343444824,1,127,116,11.333307266235352,2,134,126,11.164153099060059,3,135,133,11.687472343444824,4,128,133,11.164153099060059,5,118,128,11.164153099060059,6,122,121,11.507664680480957,1,126,119,11.164153099060059,2,136,127,11.507664680480957,3,135,134,11.333307266235352,4,127,133,11.507664680480957,5,120,128,10.999974250793457,6,121,122,11.333307266235352,1,126,119,11.507664680480957,2,136,126,11.164153099060059,3,135,134,11.333307266235352,4,127,134,11.333307266235352,5,118,127,11.333307266235352,6,121,119,11.333307266235352,1,126,119,11.333307266235352,2,135,127,11.164153099060059,3,135,136,11.507664680480957,4,127,134,11.164153099060059,5,118,128,11.333307266235352,6,119,117,11.333307266235352,1,127,119,11.333307266235352,2,134,126,11.333307266235352,3,136,134,11.687472343444824,4,126,133,11.164153099060059,5,119,128,11.164153099060059,6,121,120,11.687472343444824,1,125,120,11.333307266235352,2,132,127,11.164153099060059,3,134,134,11.687472343444824,4,128,135,11.164153099060059,5,117,127,10.999974250793457,6,121,121,11.687472343444824,1,125,120,11.507664680480957,2,135,127,10.840554237365723,3,135,135,11.507664680480957,4,127,136,11.687472343444824,5,121,128,10.840554237365723,6,120,121,11.507664680480957,1,127,119,11.687472343444824,2,134,127,10.840554237365723,3,134,134,11.507664680480957,4,127,134,11.687472343444824,5,120,128,10.685688972473145,6,118,119,11.687472343444824,1,126,121,11.687472343444824,2,135,128,10.685688972473145,3,133,133,11.872987747192383,4,128,132,11.333307266235352,5,119,127,10.685688972473145,6,116,115,11.687472343444824,1,125,118,11.164153099060059,2,136,127,10.108084678649902,3,139,138,11.507664680480957,4,127,139,10.999974250793457,5,114,126,9.714262962341309,6,110,110,10.840554237365723,1,126,108,9.973310470581055,2,149,128,8.311092376708984,3,158,158,8.904741287231445,4,126,162,8.499979972839355,5,90,128,6.990638256072998,6,81,79,8.130415916442871,1,127,81,7.711322784423828,2,176,127,6.081286430358887,3,185,184,5.582076549530029,4,127,202,4.348826885223389,5,44,128,2.991992950439453,6,34,33,2.5528950691223145,1,128,26,0.4770396947860718,6,239,126,1.5747331380844116,5,128,16,-1.5080610513687134,4,17,18,-0.6900352835655212,3,15,129,-0.817484438419342,2,127,240,-1.126503348350525,1,237,239,1.2874324321746826,6,239,128,1.2852202653884888,5,128,14,-1.0793625116348267,4,16,16,-1.0778071880340576,3,15,127,0.711701512336731,4,127,236,2.005357265472412,5,36,127,3.339277982711792,6,52,51,5.381282329559326,1,128,62,6.131133079528809,2,190,127,6.131133079528809,3,180,180,7.479982852935791,4,128,175,8.311092376708984,5,86,130,7.873665809631348,6,93,93,9.234545707702637,1,127,96,9.714262962341309,2,152,127,9.121930122375488,3,150,150,9.973310470581055,4,128,148,10.685688972473145,5,111,128,9.842082023620605,6,112,111,10.685688972473145,1,126,110,10.999974250793457,2,142,127,10.685688972473145,3,138,139,10.999974250793457,4,128,137,10.999974250793457,5,116,127,10.999974250793457,6,115,115,11.164153099060059,1,126,118,10.999974250793457,2,137,126,11.164153099060059,3,137,135,11.333307266235352,4,127,136,11.333307266235352,5,117,128,11.333307266235352,6,117,118,11.507664680480957,1,126,119,11.164153099060059,2,137,127,10.999974250793457,3,137,137,11.687472343444824,4,127,136,11.164153099060059,5,120,129,11.164153099060059,6,120,118,11.507664680480957,1,126,120,11.164153099060059,2,135,128,11.333307266235352,3,134,134,11.507664680480957,4,127,135,11.333307266235352,5,120,128,11.164153099060059,6,121,121,11.164153099060059,1,127,120,11.507664680480957,2,135,127,11.164153099060059,3,134,132,11.333307266235352,4,128,134,11.333307266235352,5,119,128,11.333307266235352,6,119,118,11.333307266235352,1,127,119,11.333307266235352,2,135,127,11.164153099060059,3,137,137,11.333307266235352,4,127,134,11.333307266235352,5,118,128,11.333307266235352,6,119,118,11.333307266235352,1,126,119,11.333307266235352,2,133,127,11.164153099060059,3,135,133,11.507664680480957,4,127,135,11.333307266235352,5,122,130,10.999974250793457,6,121,120,11.687472343444824,1,126,120,11.164153099060059,2,134,128,11.164153099060059,3,135,136,11.687472343444824,4,127,133,11.164153099060059,5,119,128,10.999974250793457,6,118,118,11.687472343444824,1,128,119,11.507664680480957,2,133,128,10.840554237365723,3,134,134,11.507664680480957,4,127,134,11.687472343444824,5,121,128,10.840554237365723,6,119,119,11.507664680480957,1,127,118,11.687472343444824,2,134,127,10.840554237365723,3,137,135,11.507664680480957,4,126,132,11.687472343444824,5,122,129,10.840554237365723,6,121,121,11.687472343444824,1,128,119,11.507664680480957,2,134,127,10.685688972473145,3,136,136,12.064488410949707,4,128,134,11.507664680480957,5,119,128,10.685688972473145,6,119,119,11.872987747192383,1,127,119,11.507664680480957,2,136,127,10.535186767578125,3,135,134,12.064488410949707,4,127,132,11.687472343444824,5,120,126,10.388864517211914,6,119,121,12.064488410949707,1,125,120,11.872987747192383,2,133,127,10.388864517211914,3,138,137,12.064488410949707,4,128,137,11.872987747192383,5,122,128,10.246551513671875,6,119,120,11.872987747192383,1,126,120,12.064488410949707,2,132,127,10.388864517211914,3,135,133,11.687472343444824,4,128,135,11.872987747192383,5,121,129,10.685688972473145,6,121,121,11.507664680480957,1,125,118,12.064488410949707,2,133,128,10.685688972473145,3,134,133,11.507664680480957,4,127,136,11.687472343444824,5,120,128,10.840554237365723,6,118,119,11.507664680480957,1,127,120,11.687472343444824,2,135,127,11.333307266235352,3,135,133,11.333307266235352,4,126,133,11.507664680480957,5,119,128,11.164153099060059,6,118,117,11.333307266235352,1,126,120,11.164153099060059,2,136,126,11.507664680480957,3,137,136,11.333307266235352,4,127,135,11.333307266235352,5,120,128,11.507664680480957,6,119,120,11.507664680480957,1,127,120,11.164153099060059,2,136,128,11.164153099060059,3,135,133,11.507664680480957,4,126,136,11.333307266235352,5,120,128,11.164153099060059,6,120,121,11.333307266235352,1,126,119,11.164153099060059,2,134,127,11.333307266235352,3,136,134,11.507664680480957,4,126,137,11.333307266235352,5,118,128,10.999974250793457,6,121,121,11.333307266235352,1,126,120,11.507664680480957,2,133,128,10.999974250793457,3,135,135,11.333307266235352,4,126,135,11.333307266235352,5,119,127,11.333307266235352,6,120,122,11.333307266235352,1,126,119,11.333307266235352,2,136,127,11.164153099060059,3,136,137,11.333307266235352,4,126,132,11.333307266235352,5,120,129,11.333307266235352,6,121,120,11.333307266235352,1,126,120,11.333307266235352,2,133,127,11.164153099060059,3,134,133,11.507664680480957,4,127,134,11.333307266235352,5,121,128,10.999974250793457,6,121,120,11.687472343444824,1,126,120,11.164153099060059,2,134,127,11.164153099060059,3,137,136,11.687472343444824,4,127,134,11.164153099060059,5,120,127,10.999974250793457,6,122,122,11.687472343444824,1,127,119,11.507664680480957,2,135,127,10.840554237365723,3,133,135,11.687472343444824,4,127,134,11.507664680480957,5,119,128,10.840554237365723,6,120,119,11.687472343444824,1,126,120,11.687472343444824,2,134,127,10.840554237365723,3,135,136,11.507664680480957,4,127,134,11.687472343444824,5,122,128,10.840554237365723,6,120,120,11.687472343444824,1,127,122,11.687472343444824,2,135,128,10.685688972473145,3,134,133,11.872987747192383,4,127,133,11.687472343444824,5,122,128,10.685688972473145,6,119,120,11.872987747192383,1,127,119,11.507664680480957,2,136,128,10.535186767578125,3,135,134,12.064488410949707,4,127,134,11.507664680480957,5,121,128,10.388864517211914,6,117,117,12.064488410949707,1,127,120,11.872987747192383,2,134,128,10.388864517211914,3,135,134,12.064488410949707,4,127,134,11.872987747192383,5,123,128,10.108084678649902,6,118,118,12.064488410949707,1,126,118,11.872987747192383,2,136,126,10.388864517211914,3,136,136,11.687472343444824,4,127,135,12.064488410949707,5,122,129,10.685688972473145,6,121,121,11.507664680480957,1,127,117,11.872987747192383,2,134,127,10.685688972473145,3,135,133,11.333307266235352,4,126,137,11.872987747192383,5,118,127,10.840554237365723,6,120,119,11.507664680480957,1,126,119,11.687472343444824,2,134,126,11.333307266235352,3,134,134,11.333307266235352,4,128,134,11.507664680480957,5,119,128,11.333307266235352,6,117,119,11.507664680480957,1,125,120,11.164153099060059,2,135,127,11.333307266235352,3,136,135,11.333307266235352,4,126,134,11.507664680480957,5,118,127,11.333307266235352,6,119,119,11.507664680480957,1,126,119,11.164153099060059,2,136,127,11.164153099060059,3,135,135,11.687472343444824,4,128,136,11.164153099060059,5,119,127,11.164153099060059,6,120,120,11.507664680480957,1,126,119,11.164153099060059,2,135,127,11.333307266235352,3,135,132,11.507664680480957,4,127,137,11.333307266235352,5,118,129,11.164153099060059,6,119,120,11.164153099060059,1,127,118,11.687472343444824,2,132,127,10.999974250793457,3,135,137,11.507664680480957,4,127,133,11.333307266235352,5,120,129,11.507664680480957,6,119,120,11.164153099060059,1,127,120,11.507664680480957,2,136,127,11.164153099060059,3,137,137,11.333307266235352,4,128,134,11.164153099060059,5,119,128,11.333307266235352,6,121,119,11.333307266235352,1,127,118,11.333307266235352,2,133,126,11.164153099060059,3,134,133,11.507664680480957,4,127,134,11.164153099060059,5,119,129,11.164153099060059,6,119,120,11.507664680480957,1,126,119,11.333307266235352,2,135,127,10.999974250793457,3,136,133,11.687472343444824,4,127,133,11.164153099060059,5,121,128,10.999974250793457,6,120,117,11.687472343444824,1,127,119,11.507664680480957,2,133,127,10.840554237365723,3,135,134,11.687472343444824,4,127,136,11.507664680480957,5,120,128,10.840554237365723,6,121,122,11.687472343444824,1,127,120,11.687472343444824,2,137,128,10.840554237365723,3,134,134,11.507664680480957,4,126,133,11.687472343444824,5,120,128,10.840554237365723,6,120,120,11.687472343444824,1,127,119,11.507664680480957,2,134,127,10.685688972473145,3,136,137,11.872987747192383,4,127,134,11.687472343444824,5,119,127,10.685688972473145,6,120,121,11.872987747192383,1,126,120,11.507664680480957,2,133,128,10.535186767578125,3,136,135,12.064488410949707,4,128,134,11.507664680480957,5,120,127,10.388864517211914,6,120,120,12.064488410949707,1,127,121,11.872987747192383,2,131,127,10.388864517211914,3,137,135,12.064488410949707,4,127,135,11.687472343444824,5,122,128,10.246551513671875,6,120,120,12.064488410949707,1,125,118,11.872987747192383,2,133,128,10.388864517211914,3,135,136,11.687472343444824,4,127,134,12.064488410949707,5,119,128,10.685688972473145,6,118,118,11.507664680480957,1,126,119,11.872987747192383,2,134,127,10.840554237365723,3,135,134,11.507664680480957,4,127,136,11.687472343444824,5,119,128,10.840554237365723,6,121,121,11.507664680480957,1,125,119,11.687472343444824,2,135,126,11.333307266235352,3,134,133,11.333307266235352,4,128,135,11.507664680480957,5,120,129,11.164153099060059,6,118,118,11.333307266235352,1,126,119,11.164153099060059,2,135,127,11.333307266235352,3,135,134,11.333307266235352,4,126,135,11.507664680480957,5,117,128,11.333307266235352,6,120,119,11.507664680480957,1,126,118,11.333307266235352,2,134,128,10.999974250793457,3,136,135,11.687472343444824,4,127,135,11.333307266235352,5,119,128,11.164153099060059,6,119,119,11.333307266235352,1,127,119,11.333307266235352,2,135,128,11.333307266235352,3,134,133,11.507664680480957,4,127,133,11.507664680480957,5,119,128,10.999974250793457,6,120,120,11.333307266235352,1,125,118,11.507664680480957,2,134,126,11.164153099060059,3,135,134,11.507664680480957,4,127,136,11.333307266235352,5,119,128,11.333307266235352,6,121,119,11.164153099060059,1,127,118,11.507664680480957,2,134,127,11.164153099060059,3,135,134,11.333307266235352,4,126,134,11.333307266235352,5,118,128,11.507664680480957,6,119,117,11.164153099060059,1,127,119,11.333307266235352,2,133,127,11.333307266235352,3,135,133,11.507664680480957,4,126,135,11.164153099060059,5,121,127,11.164153099060059,6,118,117,11.507664680480957,1,127,119,11.333307266235352,2,134,127,10.999974250793457,3,135,134,11.687472343444824,4,127,134,11.333307266235352,5,120,128,10.999974250793457,6,121,121,11.687472343444824,1,127,120,11.507664680480957,2,134,127,10.840554237365723,3,134,132,11.687472343444824,4,127,134,11.507664680480957,5,122,128,10.840554237365723,6,120,120,11.687472343444824,1,127,119,11.507664680480957,2,133,127,10.999974250793457,3,135,136,11.687472343444824,4,127,133,11.507664680480957,5,120,128,10.840554237365723,6,120,121,11.687472343444824,1,126,120,11.507664680480957,2,135,128,10.685688972473145,3,135,133,11.872987747192383,4,126,134,11.507664680480957,5,119,128,10.685688972473145,6,117,117,12.064488410949707,1,125,121,11.333307266235352,2,132,128,10.535186767578125,3,135,135,12.064488410949707,4,128,133,11.687472343444824,5,122,128,10.388864517211914,6,119,118,12.064488410949707,1,126,119,11.872987747192383,2,134,128,10.535186767578125,3,136,135,11.872987747192383,4,128,134,11.872987747192383,5,122,128,10.246551513671875,6,117,117,11.872987747192383,1,127,119,12.064488410949707,2,135,127,10.388864517211914,3,135,134,11.687472343444824,4,127,135,11.872987747192383,5,121,129,10.685688972473145,6,121,121,11.687472343444824,1,126,118,11.872987747192383,2,134,127,10.685688972473145,3,134,133,11.333307266235352,4,127,136,11.687472343444824,5,121,129,10.840554237365723,6,119,119,11.507664680480957,1,127,118,11.507664680480957,2,134,127,11.333307266235352,3,134,132,11.333307266235352,4,126,134,11.507664680480957,5,121,129,11.164153099060059,6,121,119,11.333307266235352,1,126,119,11.164153099060059,2,134,127,11.333307266235352,3,136,133,11.333307266235352,4,126,135,11.507664680480957,5,117,127,11.333307266235352,6,119,119,11.507664680480957,1,127,119,11.333307266235352,2,134,127,10.999974250793457,3,136,138,11.687472343444824,4,127,137,11.333307266235352,5,119,128,11.333307266235352,6,119,119,11.333307266235352,1,127,117,11.333307266235352,2,135,127,11.333307266235352,3,134,133,11.507664680480957,4,128,135,11.333307266235352,5,120,127,11.164153099060059,6,121,121,11.333307266235352,1,125,119,11.507664680480957,2,135,127,10.999974250793457,3,133,134,11.507664680480957,4,128,135,11.164153099060059,5,120,128,11.507664680480957,6,122,121,11.164153099060059,1,127,119,11.333307266235352,2,137,127,11.333307266235352,3,137,136,11.333307266235352,4,127,132,11.333307266235352,5,119,127,11.333307266235352,6,120,121,11.333307266235352,1,126,121,11.333307266235352,2,134,127,11.164153099060059,3,135,134,11.507664680480957,4,127,134,11.164153099060059,5,121,128,11.164153099060059,6,120,121,11.687472343444824,1,125,121,11.164153099060059,2,133,127,11.164153099060059,3,134,133,11.687472343444824,4,127,135,11.333307266235352,5,119,128,10.999974250793457,6,121,120,11.687472343444824,1,127,119,11.507664680480957,2,134,127,10.840554237365723,3,135,134,11.507664680480957,4,126,134,11.687472343444824,5,120,128,10.840554237365723,6,121,121,11.507664680480957,1,125,120,11.687472343444824,2,132,127,10.840554237365723,3,135,134,11.507664680480957,4,127,133,11.507664680480957,5,119,128,10.840554237365723,6,120,119,11.687472343444824,1,126,119,11.507664680480957,2,134,127,10.685688972473145,3,135,136,11.872987747192383,4,128,134,11.507664680480957,5,122,128,10.840554237365723,6,121,121,11.872987747192383,1,125,120,11.333307266235352,2,133,127,10.535186767578125,3,136,135,12.064488410949707,4,128,134,11.687472343444824,5,119,128,10.388864517211914,6,120,119,12.064488410949707,1,126,119,11.687472343444824,2,132,128,10.535186767578125,3,136,135,11.872987747192383,4,127,135,11.872987747192383,5,121,127,10.246551513671875,6,119,119,11.872987747192383,1,127,119,12.064488410949707,2,133,127,10.388864517211914,3,136,134,11.687472343444824,4,128,135,11.872987747192383,5,118,129,10.685688972473145,6,120,119,11.687472343444824,1,126,118,11.872987747192383,2,135,126,10.685688972473145,3,137,136,11.333307266235352,4,128,136,11.687472343444824,5,122,127,10.840554237365723,6,119,120,11.507664680480957,1,126,118,11.687472343444824,2,133,126,11.164153099060059,3,135,133,11.333307266235352,4,127,135,11.507664680480957,5,121,129,11.164153099060059,6,120,120,11.333307266235352,1,126,119,11.333307266235352,2,136,127,11.507664680480957,3,136,135,11.333307266235352,4,127,136,11.333307266235352,5,117,127,11.333307266235352,6,119,119,11.507664680480957,1,126,118,11.333307266235352,2,134,128,11.164153099060059,3,136,136,11.507664680480957,4,127,135,11.333307266235352,5,119,127,11.164153099060059,6,122,119,11.333307266235352,1,126,118,11.164153099060059,2,134,127,11.333307266235352,3,136,136,11.507664680480957,4,127,134,11.333307266235352,5,122,128,11.164153099060059,6,119,120,11.333307266235352,1,128,119,11.507664680480957,2,134,127,10.999974250793457,3,137,137,11.507664680480957,4,126,135,11.333307266235352,5,120,127,11.333307266235352,6,120,121,11.164153099060059,1,125,122,11.507664680480957,2,136,126,11.164153099060059,3,137,135,11.333307266235352,4,127,136,11.164153099060059,5,122,129,11.333307266235352,6,118,119,11.333307266235352,1,126,120,11.333307266235352,2,134,128,11.164153099060059,3,134,133,11.507664680480957,4,127,135,11.333307266235352,5,122,129,11.164153099060059,6,122,121,11.687472343444824,1,126,121,11.164153099060059,2,132,126,11.164153099060059,3,135,134,11.687472343444824,4,127,135,11.164153099060059,5,122,128,10.999974250793457,6,120,119,11.687472343444824,1,127,117,11.507664680480957,2,133,128,10.840554237365723,3,135,133,11.687472343444824,4,128,134,11.507664680480957,5,121,129,10.840554237365723,6,120,119,11.687472343444824,1,126,118,11.687472343444824,2,137,127,10.999974250793457,3,135,135,11.507664680480957,4,127,135,11.507664680480957,5,121,127,10.840554237365723,6,119,118,11.687472343444824,1,127,121,11.507664680480957,2,134,126,10.685688972473145,3,136,137,11.872987747192383,4,128,132,11.687472343444824,5,120,128,10.685688972473145,6,118,119,11.872987747192383,1,127,121,11.507664680480957,2,134,127,10.535186767578125,3,138,138,12.064488410949707,4,128,135,11.507664680480957,5,121,127,10.535186767578125,6,118,116,12.064488410949707,1,126,119,11.872987747192383,2,133,127,10.535186767578125,3,136,137,12.064488410949707,4,127,134,11.872987747192383,5,119,127,10.246551513671875,6,119,119,11.872987747192383,1,126,119,12.064488410949707,2,134,127,10.388864517211914,3,137,137,11.687472343444824,4,127,135,11.872987747192383,5,120,128,10.685688972473145,6,119,117,11.687472343444824,1,126,120,11.872987747192383,2,136,128,10.685688972473145,3,136,136,11.333307266235352,4,128,135,11.872987747192383,5,118,127,10.840554237365723,6,119,119,11.507664680480957,1,127,120,11.687472343444824,2,137,128,11.164153099060059,3,136,136,11.333307266235352,4,128,133,11.507664680480957,5,119,127,11.333307266235352,6,120,121,11.333307266235352,1,126,119,11.333307266235352,2,137,127,11.333307266235352,3,138,136,11.333307266235352,4,127,133,11.507664680480957,5,120,127,11.333307266235352,6,121,119,11.507664680480957,1,126,118,11.333307266235352,2,133,128,11.164153099060059,3,136,134,11.687472343444824,4,126,136,11.333307266235352,5,121,129,11.164153099060059,6,118,119,11.333307266235352,1,126,118,11.333307266235352,2,134,127,11.333307266235352,3,136,136,11.507664680480957,4,127,136,11.333307266235352,5,120,127,10.999974250793457,6,121,120,11.333307266235352,1,126,118,11.507664680480957,2,136,127,10.999974250793457,3,135,132,11.507664680480957,4,127,134,11.333307266235352,5,119,126,11.333307266235352,6,120,120,11.164153099060059,1,125,121,11.507664680480957,2,133,128,11.164153099060059,3,136,133,11.333307266235352,4,127,134,11.164153099060059,5,119,128,11.333307266235352,6,118,117,11.333307266235352,1,126,119,11.333307266235352,2,133,127,11.164153099060059,3,135,135,11.687472343444824,4,127,133,11.164153099060059,5,120,128,11.164153099060059,6,120,118,11.507664680480957,1,126,118,11.333307266235352,2,135,127,11.164153099060059,3,136,137,11.687472343444824,4,127,134,11.164153099060059,5,120,128,10.999974250793457,6,120,119,11.687472343444824,1,126,119,11.507664680480957,2,133,127,10.840554237365723,3,134,133,11.687472343444824,4,127,134,11.507664680480957,5,122,128,10.840554237365723,6,118,118,11.687472343444824,1,126,118,11.507664680480957,2,137,126,10.840554237365723,3,134,133,11.687472343444824,4,127,136,11.507664680480957,5,119,128,10.840554237365723,6,118,119,11.687472343444824,1,127,121,11.507664680480957,2,136,127,10.685688972473145,3,134,133,11.872987747192383,4,128,133,11.687472343444824,5,119,127,10.685688972473145,6,120,119,11.872987747192383,1,127,120,11.507664680480957,2,133,128,10.535186767578125,3,137,138,12.064488410949707,4,127,135,11.507664680480957,5,121,127,10.535186767578125,6,117,118,11.872987747192383,1,125,120,11.872987747192383,2,131,126,10.535186767578125,3,136,136,11.872987747192383,4,128,135,11.872987747192383,5,122,127,10.246551513671875,6,119,119,11.872987747192383,1,125,119,12.064488410949707,2,132,126,10.388864517211914,3,135,134,11.687472343444824,4,127,133,11.872987747192383,5,120,126,10.685688972473145,6,118,118,11.507664680480957,1,125,119,11.872987747192383,2,134,128,10.685688972473145,3,136,135,11.333307266235352,4,127,136,11.872987747192383,5,119,128,10.840554237365723,6,117,118,11.687472343444824,1,126,121,11.687472343444824,2,136,127,11.333307266235352,3,136,137,11.333307266235352,4,127,133,11.507664680480957,5,122,129,11.164153099060059,6,119,120,11.333307266235352,1,126,118,11.164153099060059,2,134,127,11.507664680480957,3,135,133,11.333307266235352,4,127,134,11.507664680480957,5,118,128,11.333307266235352,6,120,120,11.507664680480957,1,127,120,11.333307266235352,2,135,126,10.999974250793457,3,134,133,11.687472343444824,4,128,137,11.164153099060059,5,119,127,11.164153099060059,6,119,120,11.507664680480957,1,125,118,11.164153099060059,2,135,127,11.333307266235352,3,134,133,11.507664680480957,4,128,136,11.333307266235352,5,119,127,10.999974250793457,6,121,121,11.333307266235352,1,126,119,11.507664680480957,2,134,127,10.999974250793457,3,136,135,11.507664680480957,4,126,135,11.333307266235352,5,118,128,11.333307266235352,6,118,117,11.333307266235352,1,125,120,11.333307266235352,2,134,127,11.164153099060059,3,135,133,11.333307266235352,4,126,135,11.164153099060059,5,116,127,11.333307266235352,6,119,120,11.333307266235352,1,126,120,11.333307266235352,2,136,127,11.164153099060059,3,136,137,11.687472343444824,4,127,135,11.164153099060059,5,120,128,10.999974250793457,6,120,118,11.687472343444824,1,126,119,11.333307266235352,2,134,127,10.999974250793457,3,136,133,11.687472343444824,4,127,133,11.164153099060059,5,121,129,11.164153099060059,6,119,120,11.687472343444824,1,127,120,11.687472343444824,2,133,128,10.840554237365723,3,134,133,11.687472343444824,4,127,133,11.507664680480957,5,118,128,10.840554237365723,6,121,120,11.687472343444824,1,126,120,11.507664680480957,2,133,128,10.840554237365723,3,134,133,11.687472343444824,4,127,133,11.507664680480957,5,121,129,10.840554237365723,6,120,121,11.687472343444824,1,127,120,11.507664680480957,2,135,127,10.685688972473145,3,138,136,11.872987747192383,4,126,133,11.687472343444824,5,119,128,10.685688972473145,6,120,121,11.872987747192383,1,126,119,11.507664680480957,2,133,127,10.535186767578125,3,138,137,12.064488410949707,4,127,134,11.507664680480957,5,122,128,10.535186767578125,6,119,118,11.872987747192383,1,127,121,11.872987747192383,2,134,129,10.535186767578125,3,136,134,11.872987747192383,4,127,134,11.872987747192383,5,121,126,10.108084678649902,6,117,118,12.064488410949707,1,126,119,11.872987747192383,2,133,126,10.388864517211914,3,135,134,11.687472343444824,4,127,136,11.872987747192383,5,118,127,10.685688972473145,6,119,118,11.507664680480957,1,126,120,11.872987747192383,2,135,127,10.685688972473145,3,134,135,11.333307266235352,4,127,136,11.872987747192383,5,120,129,10.840554237365723,6,118,118,11.507664680480957,1,127,116,11.507664680480957,2,136,127,11.333307266235352,3,135,135,11.333307266235352,4,127,136,11.507664680480957,5,118,127,11.164153099060059,6,120,121,11.333307266235352,1,127,119,11.333307266235352,2,134,128,11.333307266235352,3,136,136,11.333307266235352,4,127,134,11.507664680480957,5,119,129,11.333307266235352,6,119,120,11.507664680480957,1,127,118,11.164153099060059,2,133,128,11.164153099060059,3,137,135,11.687472343444824,4,127,135,11.164153099060059,5,121,129,11.164153099060059,6,120,121,11.507664680480957,1,127,119,11.164153099060059,2,135,128,11.333307266235352,3,135,134,11.507664680480957,4,127,136,11.333307266235352,5,118,128,11.164153099060059,6,120,120,11.164153099060059,1,126,118,11.687472343444824,2,136,128,10.999974250793457,3,135,134,11.333307266235352,4,127,135,11.333307266235352,5,118,128,11.333307266235352,6,120,120,11.333307266235352,1,127,121,11.333307266235352,2,133,127,11.164153099060059,3,134,133,11.333307266235352,4,128,134,11.333307266235352,5,117,128,11.333307266235352,6,120,119,11.333307266235352,1,126,120,11.333307266235352,2,133,128,11.164153099060059,3,134,133,11.507664680480957,4,127,135,11.164153099060059,5,120,127,11.164153099060059,6,117,118,11.507664680480957,1,126,116,11.333307266235352,2,134,127,10.999974250793457,3,134,134,11.687472343444824,4,127,136,11.333307266235352,5,122,127,10.999974250793457,6,120,119,11.507664680480957,1,126,120,11.687472343444824,2,134,127,10.685688972473145,3,133,133,11.687472343444824,4,127,133,11.507664680480957,5,120,128,10.840554237365723,6,121,121,11.687472343444824,1,126,119,11.687472343444824,2,134,128,10.840554237365723,3,133,133,11.507664680480957,4,128,132,11.507664680480957,5,121,128,10.840554237365723,6,121,120,11.687472343444824,1,126,120,11.507664680480957,2,133,127,10.685688972473145,3,136,136,12.064488410949707,4,127,135,11.507664680480957,5,122,128,10.685688972473145,6,117,118,11.872987747192383,1,126,121,11.507664680480957,2,133,127,10.535186767578125,3,135,135,12.064488410949707,4,127,133,11.507664680480957,5,121,126,10.535186767578125,6,117,116,12.064488410949707,1,125,120,11.872987747192383,2,134,127,10.388864517211914,3,135,134,12.064488410949707,4,126,133,11.687472343444824,5,119,127,10.246551513671875,6,119,120,11.872987747192383,1,125,120,12.064488410949707,2,133,127,10.388864517211914,3,135,134,11.687472343444824,4,126,134,11.872987747192383,5,121,127,10.685688972473145,6,119,118,11.507664680480957,1,126,118,11.872987747192383,2,135,127,10.685688972473145,3,137,138,11.507664680480957,4,127,135,11.687472343444824,5,120,128,10.840554237365723,6,119,117,11.507664680480957,1,126,119,11.687472343444824,2,136,127,11.333307266235352,3,137,136,11.333307266235352,4,127,134,11.507664680480957,5,120,129,11.164153099060059,6,119,119,11.333307266235352,1,127,118,11.164153099060059,2,134,128,11.333307266235352,3,134,132,11.333307266235352,4,127,134,11.507664680480957,5,120,127,11.333307266235352,6,122,121,11.507664680480957,1,125,120,11.164153099060059,2,135,128,11.164153099060059,3,137,136,11.507664680480957,4,128,135,11.333307266235352,5,122,128,11.164153099060059,6,122,122,11.333307266235352,1,127,120,11.333307266235352,2,135,127,11.333307266235352,3,134,133,11.507664680480957,4,128,135,11.333307266235352,5,118,128,10.999974250793457,6,120,121,11.333307266235352,1,127,120,11.507664680480957,2,136,127,11.164153099060059,3,137,133,11.333307266235352,4,129,134,11.333307266235352,5,119,128,11.333307266235352,6,120,120,11.333307266235352,1,126,121,11.333307266235352,2,132,128,11.164153099060059,3,135,134,11.333307266235352,4,128,134,11.164153099060059,5,120,126,11.507664680480957,6,118,118,11.164153099060059,1,127,120,11.333307266235352,2,133,127,11.164153099060059,3,136,138,11.687472343444824,4,128,135,11.164153099060059,5,120,127,10.999974250793457,6,119,119,11.687472343444824,1,125,119,11.333307266235352,2,133,127,10.999974250793457,3,134,133,11.687472343444824,4,127,134,11.164153099060059,5,121,128,10.999974250793457,6,118,118,11.687472343444824,1,126,120,11.507664680480957,2,133,126,10.840554237365723,3,135,134,11.507664680480957,4,128,135,11.687472343444824,5,120,127,10.840554237365723,6,119,120,11.507664680480957,1,126,119,11.687472343444824,2,136,127,10.840554237365723,3,134,134,11.507664680480957,4,128,132,11.687472343444824,5,119,126,10.840554237365723,6,121,120,11.687472343444824,1,126,121,11.507664680480957,2,134,128,10.685688972473145,3,136,134,11.872987747192383,4,127,135,11.687472343444824,5,121,129,10.840554237365723,6,120,119,11.872987747192383,1,127,120,11.507664680480957,2,134,128,10.388864517211914,3,137,136,12.064488410949707,4,127,133,11.687472343444824,5,122,128,10.388864517211914,6,119,120,12.064488410949707,1,125,119,11.687472343444824,2,131,127,10.535186767578125,3,135,135,11.872987747192383,4,128,134,11.872987747192383,5,121,128,10.108084678649902,6,119,119,12.064488410949707,1,126,118,11.872987747192383,2,133,127,10.388864517211914,3,134,134,11.687472343444824,4,127,137,11.872987747192383,5,121,129,10.685688972473145,6,120,122,11.687472343444824,1,126,119,12.064488410949707,2,132,127,10.685688972473145,3,135,133,11.333307266235352,4,127,135,11.687472343444824,5,119,128,10.840554237365723,6,117,118,11.507664680480957,1,126,119,11.687472343444824,2,137,127,11.333307266235352,3,136,137,11.333307266235352,4,128,133,11.507664680480957,5,121,129,11.164153099060059,6,120,120,11.333307266235352,1,127,119,11.164153099060059,2,136,128,11.333307266235352,3,135,135,11.333307266235352,4,128,134,11.333307266235352,5,120,127,11.507664680480957,6,120,119,11.333307266235352,1,127,119,11.333307266235352,2,133,128,10.999974250793457,3,135,134,11.687472343444824,4,128,137,11.164153099060059,5,121,128,11.164153099060059,6,120,121,11.333307266235352,1,127,116,11.164153099060059,2,135,127,11.333307266235352,3,135,134,11.507664680480957,4,128,134,11.333307266235352,5,121,128,11.164153099060059,6,120,119,11.164153099060059,1,127,118,11.687472343444824,2,137,126,10.999974250793457,3,136,134,11.333307266235352,4,127,135,11.333307266235352,5,117,127,11.333307266235352,6,121,120,11.333307266235352,1,125,120,11.333307266235352,2,135,128,11.164153099060059,3,135,134,11.333307266235352,4,127,133,11.333307266235352,5,119,128,11.507664680480957,6,120,120,11.164153099060059,1,126,119,11.333307266235352,2,134,128,11.164153099060059,3,135,133,11.687472343444824,4,127,134,11.333307266235352,5,119,129,10.999974250793457,6,119,119,11.687472343444824,1,126,119,11.333307266235352,2,132,127,10.999974250793457,3,136,135,11.687472343444824,4,127,133,11.333307266235352,5,120,129,10.999974250793457,6,119,117,11.687472343444824,1,125,121,11.687472343444824,2,133,127,10.685688972473145,3,135,133,11.687472343444824,4,127,134,11.687472343444824,5,121,130,10.999974250793457,6,122,121,11.507664680480957,1,126,122,11.687472343444824,2,134,127,10.840554237365723,3,134,133,11.507664680480957,4,126,133,11.687472343444824,5,117,129,10.840554237365723,6,122,121,11.687472343444824,1,126,119,11.507664680480957,2,135,127,10.840554237365723,3,134,132,11.872987747192383,4,126,132,11.507664680480957,5,118,126,10.685688972473145,6,120,119,11.872987747192383,1,126,121,11.507664680480957,2,133,127,10.535186767578125,3,134,134,12.064488410949707,4,127,133,11.507664680480957,5,123,128,10.388864517211914,6,119,119,12.064488410949707,1,127,117,11.872987747192383,2,133,127,10.388864517211914,3,135,133,11.872987747192383,4,126,134,11.872987747192383,5,118,127,10.246551513671875,6,119,120,11.872987747192383,1,125,120,12.064488410949707,2,133,127,10.388864517211914,3,136,134,11.687472343444824,4,128,134,11.872987747192383,5,117,127,10.685688972473145,6,119,119,11.687472343444824,1,126,118,11.872987747192383,2,133,126,10.685688972473145,3,134,133,11.333307266235352,4,127,136,11.872987747192383,5,119,129,10.840554237365723,6,119,118,11.507664680480957,1,126,121,11.507664680480957,2,136,127,11.333307266235352,3,136,136,11.333307266235352,4,128,133,11.507664680480957,5,121,128,11.164153099060059,6,121,120,11.333307266235352,1,127,119,11.164153099060059,2,138,128,11.333307266235352,3,135,134,11.333307266235352,4,127,135,11.507664680480957,5,118,127,11.333307266235352,6,119,119,11.507664680480957,1,127,118,11.333307266235352,2,134,127,10.999974250793457,3,135,136,11.687472343444824,4,127,134,11.333307266235352,5,122,128,11.333307266235352,6,120,119,11.333307266235352,1,126,118,11.333307266235352,2,133,127,11.333307266235352,3,134,131,11.507664680480957,4,128,136,11.333307266235352,5,122,128,11.164153099060059,6,120,119,11.333307266235352,1,126,120,11.507664680480957,2,135,127,10.999974250793457,3,135,133,11.507664680480957,4,126,134,11.333307266235352,5,122,127,11.333307266235352,6,119,119,11.333307266235352,1,126,120,11.507664680480957,2,136,127,11.164153099060059,3,135,136,11.333307266235352,4,127,134,11.333307266235352,5,119,128,11.333307266235352,6,120,119,11.164153099060059,1,126,121,11.507664680480957,2,136,127,11.333307266235352,3,137,136,11.507664680480957,4,128,134,11.164153099060059,5,121,127,11.164153099060059,6,119,118,11.507664680480957,1,127,120,11.333307266235352,2,134,128,11.164153099060059,3,133,134,11.872987747192383,4,128,134,11.164153099060059,5,121,128,10.999974250793457,6,121,121,11.687472343444824,1,127,120,11.507664680480957,2,133,127,10.840554237365723,3,134,132,11.687472343444824,4,127,135,11.507664680480957,5,121,128,10.840554237365723,6,121,120,11.687472343444824,1,126,123,11.507664680480957,2,130,128,10.685688972473145,3,130,131,11.333307266235352,4,128,130,11.164153099060059,5,126,127,10.388864517211914,6,125,125,11.164153099060059,1,127,125,10.840554237365723,2,128,128,9.842082023620605,3,130,129,10.999974250793457,4,127,128,10.685688972473145,5,126,127,9.714262962341309,6,127,126,10.685688972473145,1,127,126,10.388864517211914,2,127,126,9.234545707702637,3,128,128,10.685688972473145,4,127,128,9.973310470581055,5,126,128,9.0120267868042,6,125,126,10.108084678649902,1,126,125,9.973310470581055,2,128,127,8.697653770446777,3,129,129,9.842082023620605,4,127,127,9.714262962341309,5,125,128,8.130415916442871,6,126,124,9.468331336975098,1,127,125,9.468331336975098,2,128,127,8.042991638183594,3,130,129,8.904741287231445,4,128,128,9.0120267868042,5,127,127,7.873665809631348,6,128,126,8.499979972839355,1,127,126,8.597681045532227,2,127,127,7.555537700653076,3,128,128,7.957428455352783,4,128,128,8.042991638183594,5,127,128,7.262118816375732,6,127,127,7.555537700653076,1,127,128,7.405922889709473,2,127,128,7.123793125152588,3,128,130,6.990638256072998,4,127,127,6.862370014190674,5,126,127,6.5613884925842285,6,125,126,6.448260307312012,1,127,125,6.23331880569458,2,127,126,6.0322442054748535,3,127,126,5.889750003814697,4,128,127,5.7099103927612305,5,127,127,5.420277118682861,6,126,126,5.2675933837890625,1,127,126,4.921041011810303,2,127,127,4.617272853851318,3,127,127,4.5060133934021,4,128,127,4.109880447387695,5,126,128,3.7399914264678955,6,127,127,3.4790616035461426,1,128,127,3.0283329486846924,2,127,127,2.5972161293029785,3,127,126,2.038142442703247,4,128,127,1.1097897291183472,5,127,127]
time=[0.0,0.01423501968383789,0.025252819061279297,0.03474092483520508,0.04283499717712402,0.05098986625671387,0.05889296531677246,0.06598591804504395,0.0731039047241211,0.08054685592651367,0.08754301071166992,0.09434390068054199,0.10151886940002441,0.10822391510009766,0.11482000350952148,0.12180399894714355,0.12842702865600586,0.13500499725341797,0.14216279983520508,0.14867186546325684,0.1551189422607422,0.16228795051574707,0.16864395141601562,0.1751878261566162,0.18224096298217773,0.18854594230651855,0.1951148509979248,0.2021028995513916,0.20837879180908203,0.2148118019104004,0.2220158576965332,0.2282547950744629,0.23460602760314941,0.24178385734558105,0.2480478286743164,0.25436902046203613,0.26184988021850586,0.26822686195373535,0.27440690994262695,0.2816808223724365,0.28812384605407715,0.2944068908691406,0.3014218807220459,0.3079209327697754,0.31412196159362793,0.32125282287597656,0.32788896560668945,0.3342399597167969,0.34116601943969727,0.34754180908203125,0.3540499210357666,0.3608419895172119,0.36727285385131836,0.37381696701049805,0.3805558681488037,0.3872067928314209,0.39383792877197266,0.4004960060119629,0.4070558547973633,0.41367602348327637,0.4202280044555664,0.4267899990081787,0.4334559440612793,0.4401438236236572,0.4466989040374756,0.4534158706665039,0.4602057933807373,0.4667999744415283,0.47336483001708984,0.47998881340026855,0.4866189956665039,0.49318480491638184,0.5000648498535156,0.506742000579834,0.5132699012756348,0.5200469493865967,0.5264849662780762,0.5331869125366211,0.5399689674377441,0.5466728210449219,0.5532510280609131,0.5599689483642578,0.5666148662567139,0.5733158588409424,0.5798239707946777,0.5865929126739502,0.5931990146636963,0.5998950004577637,0.6062808036804199,0.6129238605499268,0.6196877956390381,0.6262078285217285,0.6328558921813965,0.6396279335021973,0.6460399627685547,0.6527259349822998,0.6594970226287842,0.6659529209136963,0.6725399494171143,0.6794509887695312,0.6858949661254883,0.6924989223480225,0.6993780136108398,0.7057440280914307,0.7121868133544922,0.7191429138183594,0.7257499694824219,0.7322208881378174,0.7391748428344727,0.7456469535827637,0.752133846282959,0.7590420246124268,0.7653119564056396,0.7719428539276123,0.778843879699707,0.7851908206939697,0.7917978763580322,0.7989239692687988,0.8049609661102295,0.8115079402923584,0.8186819553375244,0.8248698711395264,0.8312280178070068,0.8384139537811279,0.844653844833374,0.8510057926177979,0.8583459854125977,0.8646478652954102,0.870919942855835,0.878126859664917,0.8845508098602295,0.8909049034118652,0.8979158401489258,0.9044439792633057,0.9108779430389404,0.9179270267486572,0.9245548248291016,0.930905818939209,0.9378578662872314,0.9442708492279053,0.9508769512176514,0.9575848579406738,0.9641950130462646,0.9707498550415039,0.9774429798126221,0.9840748310089111,0.990649938583374,0.9973769187927246,1.0039927959442139,1.0105829238891602,1.0171678066253662,1.0235249996185303,1.0302608013153076,1.0369679927825928,1.0434808731079102,1.0501868724822998,1.0568819046020508,1.0634629726409912,1.0702099800109863,1.0769288539886475,1.0834078788757324,1.0900788307189941,1.096876859664917,1.103550910949707,1.1100518703460693,1.1168529987335205,1.123520851135254,1.1300158500671387,1.136720895767212,1.1432669162750244,1.1498539447784424,1.156554937362671,1.163226842880249,1.1699118614196777,1.1765029430389404,1.183189868927002,1.1898918151855469,1.196465015411377,1.202929973602295,1.209650993347168,1.21657395362854,1.2229537963867188,1.229517936706543,1.2363438606262207,1.2427599430084229,1.2494289875030518,1.256187915802002,1.262657880783081,1.2691638469696045,1.2760908603668213,1.282585859298706,1.2890989780426025,1.296015977859497,1.3025999069213867,1.3090729713439941,1.3157918453216553,1.3224849700927734,1.328794002532959,1.3359229564666748,1.342378854751587,1.3488719463348389,1.3558800220489502,1.3621208667755127,1.368494987487793,1.375499963760376,1.3817908763885498,1.388350009918213,1.3955259323120117,1.4018499851226807,1.408296823501587,1.4153478145599365,1.4216549396514893,1.4280989170074463,1.435135841369629,1.441382884979248,1.4477298259735107,1.4550669193267822,1.4613368511199951,1.4675848484039307,1.4748828411102295,1.4812958240509033,1.4876267910003662,1.494640827178955,1.5011398792266846,1.5075538158416748,1.5145978927612305,1.521216869354248,1.5275750160217285,1.534524917602539,1.5410280227661133,1.5473887920379639,1.554152011871338,1.5607719421386719,1.5672979354858398,1.5740008354187012,1.5806219577789307,1.587332010269165,1.5939018726348877,1.6004858016967773,1.6070988178253174,1.613670825958252,1.62009596824646,1.62687087059021,1.6334729194641113,1.6399569511413574,1.6465909481048584,1.6533448696136475,1.659857988357544,1.6665818691253662,1.673172950744629,1.679731845855713,1.6864008903503418,1.693222999572754,1.699841022491455,1.7065229415893555,1.7132959365844727,1.7198538780212402,1.7265138626098633,1.7331628799438477,1.7398498058319092,1.7464230060577393,1.7531259059906006,1.7597730159759521,1.766446828842163,1.7730529308319092,1.7797307968139648,1.7862470149993896,1.7930548191070557,1.799548864364624,1.8062469959259033,1.8129990100860596,1.8195228576660156,1.8261539936065674,1.832791805267334,1.8393487930297852,1.8459138870239258,1.8526709079742432,1.859118938446045,1.865630865097046,1.8725638389587402,1.879023790359497,1.8855459690093994,1.8926060199737549,1.8989348411560059,1.9054639339447021,1.912362813949585,1.9189679622650146,1.925372838973999,1.9324009418487549,1.938844919204712,1.9453480243682861,1.9523518085479736,1.958678960800171,1.9650459289550781,1.972024917602539,1.9785239696502686,1.9850218296051025,1.9921479225158691,1.9983758926391602,2.004711866378784,2.0118918418884277,2.0181658267974854,2.0244898796081543,2.0317389965057373,2.0381319522857666,2.044409990310669,2.0516889095306396,2.0579488277435303,2.0642318725585938,2.0714399814605713,2.0779027938842773,2.084258794784546,2.091404914855957,2.097900867462158,2.1044118404388428,2.111663818359375,2.1184279918670654,2.1248679161071777,2.1321299076080322,2.1388158798217773,2.145528793334961,2.152369976043701,2.1592209339141846,2.1659998893737793,2.1727919578552246,2.179636001586914,2.1865320205688477,2.1933798789978027,2.200356960296631,2.2071259021759033,2.213765859603882,2.2206809520721436,2.2274458408355713,2.2345738410949707,2.2412049770355225,2.2482309341430664,2.2550690174102783,2.2618958950042725,2.268946886062622,2.2758638858795166,2.2827608585357666,2.2896668910980225,2.296834945678711,2.3040130138397217,2.3109848499298096,2.318100929260254,2.325218915939331,2.332209825515747,2.3393588066101074,2.3465359210968018,2.3536689281463623,2.360795021057129,2.3679749965667725,2.3754658699035645,2.382969856262207,2.390746831893921,2.398707866668701,2.406500816345215,2.4141058921813965,2.4219298362731934,2.4298198223114014,2.4376518726348877,2.44553279876709,2.4534459114074707,2.4610908031463623,2.469129800796509,2.4774749279022217,2.4854938983917236,2.493682861328125,2.5026848316192627,2.511169910430908,2.519984006881714,2.529772996902466,2.539444923400879,2.5493829250335693,2.5603909492492676,2.5714290142059326,2.582580804824829,2.5952517986297607,2.6071269512176514,2.6193809509277344,2.6328518390655518,2.6452839374542236,2.6575980186462402,2.6708168983459473,2.6824798583984375,2.6943578720092773,2.7073400020599365,2.7188777923583984,2.731334924697876,2.7453248500823975,2.7575278282165527,2.7696409225463867,2.7832839488983154,2.7955358028411865,2.808353900909424,2.8246920108795166,2.8392038345336914,2.854440927505493,2.8721508979797363,2.8877530097961426,2.903371810913086,2.9219279289245605,2.939079999923706,2.9563939571380615,2.975687026977539,2.9925589561462402,3.007098913192749,3.022195816040039,3.0357580184936523,3.048879861831665,3.0618388652801514,3.074445962905884,3.0868148803710938,3.0995328426361084,3.1123218536376953,3.1252918243408203,3.138394832611084,3.151871919631958,3.165678024291992,3.1796538829803467,3.1935110092163086,3.2081809043884277,3.223587989807129,3.2391879558563232,3.2558069229125977,3.273108959197998,3.2902748584747314,3.307081937789917,3.3239548206329346,3.341219902038574,3.358466863632202,3.3771908283233643,3.3955647945404053,3.4144208431243896,3.4352710247039795,3.455345869064331,3.4758098125457764,3.4971678256988525,3.5185489654541016,3.5408968925476074,3.5631449222564697,3.583432912826538,3.605090856552124,3.628587007522583,3.6541647911071777,3.681164026260376,3.706427812576294,3.731099843978882,3.7576990127563477,3.7862119674682617,3.8144609928131104,3.8419950008392334,3.8708670139312744,3.9050748348236084,3.938400983810425,3.971531867980957,4.000255823135376,4.029367923736572,4.065316915512085,4.097746849060059,4.128297805786133,4.1632750034332275,4.196368932723999,4.233593940734863,4.278127908706665,4.313946962356567,4.348776817321777,4.389985799789429,4.424476861953735,4.460826873779297,4.498454809188843,4.530470848083496,4.56803297996521,4.610265016555786,4.644085884094238,4.68225884437561,4.720282793045044,4.756372928619385,4.796541929244995,4.8364880084991455,4.871123790740967,4.906303882598877,4.943061828613281,4.975401878356934,5.003748893737793,5.036532878875732,5.062037944793701,5.088194847106934,5.119576930999756,5.146338939666748,5.1707518100738525,5.198544979095459,5.223164796829224,5.248153924942017,5.274846792221069,5.297891855239868,5.318544864654541,5.339109897613525,5.3575708866119385,5.374866962432861,5.392376899719238,5.408569812774658,5.422889947891235,5.436646938323975,5.449005842208862,5.4604198932647705,5.471151828765869,5.481123924255371,5.490301847457886,5.499140977859497,5.507459878921509,5.515631914138794,5.52370285987854,5.5310750007629395,5.53852391242981,5.545945882797241,5.5529139041900635,5.560001850128174,5.567004919052124,5.573845863342285,5.58060097694397,5.587576866149902,5.594326019287109,5.600769996643066,5.607790946960449,5.614489793777466,5.621145963668823,5.627799987792969,5.634299993515015,5.641007900238037,5.647722005844116,5.6543288230896,5.661098957061768,5.667691946029663,5.67437481880188,5.680872917175293,5.687490940093994,5.694007873535156,5.7007060050964355,5.707453012466431,5.713887929916382,5.7205328941345215,5.727303981781006,5.733860015869141,5.740454912185669,5.7473509311676025,5.753625869750977,5.760303974151611,5.767228841781616,5.773494005203247,5.7800328731536865,5.787022829055786,5.793548822402954,5.79980993270874,5.806823968887329,5.813292980194092,5.819770812988281,5.826725959777832,5.833115816116333,5.839469909667969,5.846575975418091,5.852764844894409,5.8592588901519775,5.866233825683594,5.872650861740112,5.879170894622803,5.886214971542358,5.8924078941345215,5.8988258838653564,5.905993938446045,5.912258863449097,5.918579816818237,5.9257588386535645,5.9320290088653564,5.938349008560181,5.945830821990967,5.952132940292358,5.958310842514038,5.965583801269531,5.972006797790527,5.978101968765259,5.985301971435547,5.991766929626465,5.998025894165039,6.0049660205841064,6.0115578174591064,6.017904996871948,6.0248048305511475,6.031324863433838,6.037815809249878,6.044550895690918,6.051172971725464,6.057705879211426,6.064267873764038,6.07087779045105,6.077699899673462,6.084300994873047,6.090834856033325,6.097294807434082,6.10391092300415,6.110460996627808,6.117136001586914,6.123853921890259,6.130319833755493,6.137022972106934,6.143805980682373,6.1502439975738525,6.157033920288086,6.1634299755096436,6.17012095451355,6.176671981811523,6.183470964431763,6.1900999546051025,6.196575880050659,6.203171968460083,6.209758996963501,6.216432809829712,6.2230308055877686,6.229683876037598,6.236257791519165,6.242955923080444,6.249486923217773,6.256285905838013,6.262942790985107,6.269629955291748,6.27608585357666,6.282922983169556,6.289399862289429,6.2959699630737305,6.3026769161224365,6.309165954589844,6.315790891647339,6.32253098487854,6.328943967819214,6.335647821426392,6.34244179725647,6.348953008651733,6.355432987213135,6.362476825714111,6.368724822998047,6.375237941741943,6.382182836532593,6.3886308670043945,6.3952319622039795,6.402094841003418,6.408601999282837,6.415072917938232,6.421998977661133,6.428452014923096,6.434927940368652,6.4419310092926025,6.4482269287109375,6.454746961593628,6.461725950241089,6.467996835708618,6.474552869796753,6.481582880020142,6.487879991531372,6.494347810745239,6.5015459060668945,6.507622957229614,6.513947010040283,6.521155834197998,6.527406930923462,6.533708810806274,6.541082859039307,6.547384023666382,6.553598880767822,6.560809850692749,6.567224979400635,6.573500871658325,6.580673933029175,6.587054967880249,6.593527793884277,6.600602865219116,6.607101917266846,6.613449811935425,6.620211839675903,6.626881837844849,6.633350849151611,6.639890909194946,6.646623849868774,6.6531288623809814,6.659852981567383,6.666482925415039,6.673156976699829,6.6797449588775635,6.686407804489136,6.692781925201416,6.6994428634643555,6.706053018569946,6.712548017501831,6.71930193901062,6.725787878036499,6.7324628829956055,6.739148855209351,6.745684862136841,6.752357006072998,6.75910496711731,6.765631914138794,6.772111892700195,6.7788708209991455,6.785627841949463,6.79212498664856,6.798913955688477,6.805544853210449,6.812146902084351,6.818641901016235,6.825244903564453,6.832000017166138,6.838699817657471,6.845353841781616,6.85202693939209,6.8586249351501465,6.86533784866333,6.871719837188721,6.87862491607666,6.885105848312378,6.891804933547974,6.898583889007568,6.905004024505615,6.911548852920532,6.918287992477417,6.924675941467285,6.931373834609985,6.9381208419799805,6.944566965103149,6.951059818267822,6.958082914352417,6.964507818222046,6.9709858894348145,6.977855920791626,6.9844138622283936,6.990783929824829,6.9976630210876465,7.004098892211914,7.010778903961182,7.017704963684082,7.024134874343872,7.030602931976318,7.037627935409546,7.043926000595093,7.0504539012908936,7.057245969772339,7.063642978668213,7.070119857788086,7.077232837677002,7.08345890045166,7.089934825897217,7.097121953964233,7.10334587097168,7.109810829162598,7.116963863372803,7.123076915740967,7.129419803619385,7.1367199420928955,7.1430089473724365,7.1493239402771,7.156550884246826,7.162954807281494,7.169327974319458,7.176249980926514,7.182711839675903,7.189107894897461,7.196139812469482,7.2026448249816895,7.209100961685181,7.216024875640869,7.222447872161865,7.2288830280303955,7.235538005828857,7.242133855819702,7.2488110065460205,7.255548000335693,7.262130975723267,7.2688000202178955,7.275298833847046,7.281937837600708,7.288457870483398,7.295060873031616,7.301585912704468,7.308383941650391,7.315126895904541,7.321508884429932,7.328136920928955,7.3348000049591064,7.3413708209991455,7.348062992095947,7.35466194152832,7.361219882965088,7.367806911468506,7.374605894088745,7.3814380168914795,7.3878419399261475,7.394755840301514,7.401335954666138,7.4080259799957275,7.4144628047943115,7.421332836151123,7.427797794342041,7.43451189994812,7.441137790679932,7.447862863540649,7.454554796218872,7.461205959320068,7.467805862426758,7.47455096244812,7.48098087310791,7.4876549243927,7.494431972503662,7.500771999359131,7.5075600147247314,7.514282941818237,7.520681858062744,7.52724289894104,7.534013986587524,7.540426015853882,7.54689884185791,7.553815841674805,7.560235977172852,7.566734790802002,7.5736308097839355,7.580096960067749,7.586619853973389,7.593508958816528,7.600135803222656,7.606580972671509,7.613386869430542,7.619882822036743,7.626274824142456,7.6334547996521,7.639750957489014,7.646261930465698,7.653151988983154,7.659447908401489,7.6659369468688965,7.67325496673584,7.679457902908325,7.685904026031494,7.693081855773926,7.69933295249939,7.70554780960083,7.712853908538818,7.719028949737549,7.725430011749268,7.732846021652222,7.738917827606201,7.7451558113098145,7.752378940582275,7.758771896362305,7.765065908432007,7.772079944610596,7.778566837310791,7.7848968505859375,7.791918992996216,7.798555850982666,7.804956912994385,7.811828851699829,7.818533897399902,7.82499885559082,7.831626892089844,7.838258981704712,7.844648838043213,7.851493835449219,7.857977867126465,7.864784002304077,7.871381998062134,7.878006935119629,7.884524822235107,7.891161918640137,7.897684812545776,7.904335021972656,7.911080837249756,7.91755485534668,7.924207925796509,7.930882930755615,7.937461853027344,7.943993806838989,7.9505839347839355,7.957085847854614,7.963656902313232,7.9704248905181885,7.977092981338501,7.983618974685669,7.990537881851196,7.997006893157959,8.003661870956421,8.010366916656494,8.017076969146729,8.023607969284058,8.030323028564453,8.036961793899536,8.043635845184326,8.050253868103027,8.056906938552856,8.063555002212524,8.070206880569458,8.076689004898071,8.083280801773071,8.090133905410767,8.096606969833374,8.10322880744934,8.11001181602478,8.11645793914795,8.1231369972229,8.129939794540405,8.136384963989258,8.142854928970337,8.149693012237549,8.156100988388062,8.162604808807373,8.169487953186035,8.175940990447998,8.182399988174438,8.189414978027344,8.195942878723145,8.202308893203735,8.209359884262085,8.215762853622437,8.222265005111694,8.229245901107788,8.235569953918457,8.241947889328003,8.248912811279297,8.255155801773071,8.261862993240356,8.268824815750122,8.27518892288208,8.281659841537476,8.288856983184814,8.295077800750732,8.301461935043335,8.308588981628418,8.314857959747314,8.3212308883667,8.328629970550537,8.334929943084717,8.34126091003418,8.348382949829102,8.354921817779541,8.361303806304932,8.368479013442993,8.375127792358398,8.381603956222534,8.388849973678589,8.395667791366577,8.40224289894104,8.409498929977417,8.416327953338623,8.423151969909668,8.430166006088257,8.437323808670044,8.444234848022461,8.451406955718994,8.4585599899292,8.465709924697876,8.472811937332153,8.480007886886597,8.487182855606079,8.494446992874146,8.501507997512817,8.509055852890015,8.516607999801636,8.523960828781128,8.531588792800903,8.539358854293823,8.547000885009766,8.555039882659912,8.563321828842163,8.571754932403564,8.580521821975708,8.589977979660034,8.599419832229614,8.608873844146729,8.618915796279907,8.629040002822876,8.639311790466309,8.649966955184937,8.660959005355835,8.672241926193237,8.684288024902344,8.69648289680481,8.709086894989014,8.721930980682373,8.73496699333191,8.748235940933228,8.762208938598633,8.775842905044556,8.790534019470215,8.805948972702026,8.821292877197266,8.838213920593262,8.856230020523071,8.873957872390747,8.893391847610474,8.913817882537842,8.933691024780273,8.954299926757812,8.976724863052368,8.998132944107056,9.019940853118896,9.043617010116577,9.067288875579834,9.091332912445068,9.11690902709961,9.141069889068604,9.164429903030396,9.19136095046997,9.215934991836548,9.243215799331665,9.274649858474731,9.303247928619385,9.33275580406189,9.368659973144531,9.400593996047974,9.435827016830444,9.476166009902954,9.510595798492432,9.546103954315186,9.588368892669678,9.627792835235596,9.66738486289978,9.715049982070923,9.756363868713379,9.799775838851929,9.854965925216675,9.899693965911865,9.944792985916138,9.998670816421509,10.045383930206299,10.093946933746338,10.094298839569092,10.096505880355835,10.096966981887817,10.09822392463684,10.161588907241821,10.212029933929443,10.257465839385986,10.300582885742188,10.340282917022705,10.377943992614746,10.420713901519775,10.461591005325317,10.50302791595459,10.547516822814941,10.596218824386597,10.64120602607727,10.64150595664978,10.642833948135376,10.643296003341675,10.645200967788696,10.698477983474731,10.741660833358765,10.782924890518188,10.822453022003174,10.862027883529663,10.899765968322754,10.900057792663574,10.901196956634521,10.950381994247437,10.992883920669556,11.0362229347229,11.078991889953613,11.12061595916748,11.163479804992676,11.208472967147827,11.253244876861572,11.300379991531372,11.347470998764038,11.398646831512451,11.44824481010437,11.448514938354492,11.450613975524902,11.451068878173828,11.452534914016724,11.515647888183594,11.566449880599976,11.61496090888977,11.663486003875732,11.711262941360474,11.762578964233398,11.763039827346802,11.765744924545288,11.766171932220459,11.767072916030884,11.830931901931763,11.881633996963501,11.931787014007568,11.98114800453186,12.028347969055176,12.080078840255737,12.080434799194336,12.083024024963379,12.083459854125977,12.084431886672974,12.14428186416626,12.196527004241943,12.247220993041992,12.30315899848938,12.358467817306519,12.412250995635986,12.412719011306763,12.414772987365723,12.415215015411377,12.416481018066406,12.482053995132446,12.538079023361206,12.59171986579895,12.646981000900269,12.702958822250366,12.754916906356812,12.75527286529541,12.757676839828491,12.758141994476318,12.759162902832031,12.821674823760986,12.869568824768066,12.912715911865234,12.95603084564209,12.993791818618774,13.028774976730347,13.0657958984375,13.09769582748413,13.130971908569336,13.165180921554565,13.194890022277832,13.223198890686035,13.2531259059906,13.279253959655762,13.304081916809082,13.328638792037964,13.348764896392822,13.36931586265564,13.390870809555054,13.4095299243927,13.428664922714233,13.448768854141235,13.46546983718872,13.481987953186035,13.500329971313477,13.515347957611084,13.530251026153564,13.54697299003601,13.561132907867432,13.574666023254395,13.58943796157837,13.601358890533447,13.61238980293274,13.625010013580322,13.636170864105225,13.646960020065308,13.658943891525269,13.669699907302856,13.679893970489502,13.690631866455078,13.700469017028809,13.709612846374512,13.719266891479492,13.728152990341187,13.736832857131958,13.74584698677063,13.754731893539429,13.763692855834961,13.772783994674683,13.782046794891357,13.79122281074524,13.80032992362976,13.809614896774292,13.818454027175903,13.827181816101074,13.835685014724731,13.844263792037964,13.852843999862671,13.860986948013306,13.86934494972229,13.877784013748169,13.88606595993042,13.89449691772461,13.903132915496826,13.911504983901978,13.920368909835815,13.929348945617676,13.93809986114502,13.946574926376343,13.95533299446106,13.963666915893555,13.972083806991577,13.980315923690796,13.98862600326538,13.996704816818237,14.004910945892334,14.01293683052063,14.021046876907349,14.029011964797974,14.037038803100586,14.045040845870972,14.053215980529785,14.061121940612793,14.069141864776611,14.077553987503052,14.085507869720459,14.093951940536499,14.102636814117432,14.1108980178833,14.119755983352661,14.128813028335571,14.137511968612671,14.146458864212036,14.15636396408081,14.165679931640625,14.17560601234436,14.186846017837524,14.1980459690094,14.21020793914795,14.225214004516602,14.24179482460022,14.261245012283325,14.28722095489502,14.32102084159851,14.370962858200073,14.46898102760315,14.46943998336792,14.473644971847534,14.805154800415039,14.806666851043701,14.811623811721802,14.81440281867981,14.819073915481567,14.82167100906372,14.826589822769165,14.829116821289062,14.834189891815186,14.836620807647705,14.841839790344238,14.844088792800903,14.84951901435852,14.851564884185791,14.857273817062378,14.859043836593628,14.865072011947632,14.866737842559814,14.872893810272217,14.874522924423218,14.88064980506897,14.882323980331421,14.888439893722534,14.89014482498169,14.896224021911621,14.898018836975098,14.903965950012207,14.906044006347656,14.91164493560791,14.913991928100586,14.919296979904175,14.921716928482056,14.926837921142578,14.929638862609863,14.934338808059692,14.937445878982544,14.941725969314575,14.944994926452637,14.948959827423096,14.952595949172974,14.956102848052979,14.960065841674805,14.962836980819702,14.967259883880615,14.969738960266113,14.97330379486084,14.97621488571167,15.108070850372314,15.108452796936035,15.111862897872925,15.112200021743774,15.113107919692993,15.170463800430298,15.196595907211304,15.223369836807251,15.251835823059082,15.275004863739014,15.296971797943115,15.318060874938965,15.333287954330444,15.346905946731567,15.360292911529541,15.370478868484497,15.380203008651733,15.390576839447021,15.398783922195435,15.406667947769165,15.415400981903076,15.422902822494507,15.430053949356079,15.437855958938599,15.444792985916138,15.451666831970215,15.45907187461853,15.465991020202637,15.47259783744812,15.47971487045288,15.486366987228394,15.492990016937256,15.499668836593628,15.506236791610718,15.512919902801514,15.519648790359497,15.526126861572266,15.532858848571777,15.539455890655518,15.546051979064941,15.552589893341064,15.559159994125366,15.565682888031006,15.572396993637085,15.579033851623535,15.585656881332397,15.592309951782227,15.598980903625488,15.605577945709229,15.61217999458313,15.618767976760864,15.625293970108032,15.631826877593994,15.638616800308228,15.645224809646606,15.651700019836426,15.658476829528809,15.664952993392944,15.671550989151001,15.678107023239136,15.684847831726074,15.691401958465576,15.698099851608276,15.704600811004639,15.71142292022705,15.717739820480347,15.724426984786987,15.730969905853271,15.737679958343506,15.744102954864502,15.750768899917603,15.757516860961914,15.76393985748291,15.770571947097778,15.777402877807617,15.783751964569092,15.790580987930298,15.797356843948364,15.80364990234375,15.810263872146606,15.81715202331543,15.82357382774353,15.829939842224121,15.83688998222351,15.843352794647217,15.849776983261108,15.85662579536438,15.863093852996826,15.869601964950562,15.876449823379517,15.882869005203247,15.889238834381104,15.896299839019775,15.902601957321167,15.909044027328491,15.916019916534424,15.922327995300293,15.928637981414795,15.935740947723389,15.942011833190918,15.948484897613525,15.95563292503357,15.961856842041016,15.968145847320557,15.975385904312134,15.981634855270386,15.987962007522583,15.995376825332642,16.001627922058105,16.00782799720764,16.015055894851685,16.02146291732788,16.027743816375732,16.034745931625366,16.041225910186768,16.04741883277893,16.054256916046143,16.061075925827026,16.067396879196167,16.07429790496826,16.080850839614868,16.087246894836426,16.09393000602722,16.100476026535034,16.10686683654785,16.11355686187744,16.120163917541504,16.12683391571045,16.1334547996521,16.13996195793152,16.146554946899414,16.153084993362427,16.159586906433105,16.166236877441406,16.172956943511963,16.179410934448242,16.18612790107727,16.192768812179565,16.19945192337036,16.205950021743774,16.21264886856079,16.219110012054443,16.22557282447815,16.232611894607544,16.239040851593018,16.245551824569702,16.25228786468506,16.25883197784424,16.265416860580444,16.27203392982483,16.278644800186157,16.285213947296143,16.291884899139404,16.29853081703186,16.30525779724121,16.311827898025513,16.318475008010864,16.325177907943726,16.331780910491943,16.338233947753906,16.34489893913269,16.351651906967163,16.358096837997437,16.364702939987183,16.371450901031494,16.37787699699402,16.384614944458008,16.391421794891357,16.39780902862549,16.40434980392456,16.411311864852905,16.417742013931274,16.42410397529602,16.431082010269165,16.4375159740448,16.443969011306763,16.450845956802368,16.45732879638672,16.46380090713501,16.47063684463501,16.477027893066406,16.483598947525024,16.49059796333313,16.496851921081543,16.503326892852783,16.51032781600952,16.51663088798523,16.52312994003296,16.530234813690186,16.536425828933716,16.542762994766235,16.549876928329468,16.556129932403564,16.56241202354431,16.569561004638672,16.575846910476685,16.582173824310303,16.589653968811035,16.595824003219604,16.602003812789917,16.60930299758911,16.615527868270874,16.621960878372192,16.628976821899414,16.635421991348267,16.641613960266113,16.648698806762695,16.655285835266113,16.661608934402466,16.66849994659424,16.6750009059906,16.681318998336792,16.688076972961426,16.694674015045166,16.701177835464478,16.707849979400635,16.71445393562317,16.720993995666504,16.727612018585205,16.734325885772705,16.74084496498108,16.747264862060547,16.753718852996826,16.760416984558105,16.767059803009033,16.773499011993408,16.78012180328369,16.786836862564087,16.793439865112305,16.80008888244629,16.806732892990112,16.81326198577881,16.81983995437622,16.826584815979004,16.833204984664917,16.839700937271118,16.84631586074829,16.852885007858276,16.85970401763916,16.866280794143677,16.872925996780396,16.879501819610596,16.886205911636353,16.892632007598877,16.89948582649231,16.90607786178589,16.912705898284912,16.919298887252808,16.925997972488403,16.932453870773315,16.93912386894226,16.945772886276245,16.95218586921692,16.958810806274414,16.965523958206177,16.971942901611328,16.978582859039307,16.985330820083618,16.991761922836304,16.998310804367065,17.005151987075806,17.011658906936646,17.01826286315918,17.025096893310547,17.031582832336426,17.0377779006958,17.044758796691895,17.051349878311157,17.057793855667114,17.06465196609497,17.07108497619629,17.077651977539062,17.084568977355957,17.0908420085907,17.097314834594727,17.10428786277771,17.110697984695435,17.117095947265625,17.124326944351196,17.130533933639526,17.137008905410767,17.14417791366577,17.15033197402954,17.156571865081787,17.163697004318237,17.169922828674316,17.176241874694824,17.1835618019104,17.18981695175171,17.196064949035645,17.20326590538025,17.20969295501709,17.215940952301025,17.22307801246643,17.229533910751343,17.23583698272705,17.24283480644226,17.249454021453857,17.255798816680908,17.26267385482788,17.26919984817505,17.2756769657135,17.282212018966675,17.288908004760742,17.29540491104126,17.302103996276855,17.30870294570923,17.315374851226807,17.321985960006714,17.32842993736267,17.335105895996094,17.341683864593506,17.348076820373535,17.35469698905945,17.361495971679688,17.367801904678345,17.374472856521606,17.381150007247925,17.387666940689087,17.394336938858032,17.40090584754944,17.407464027404785,17.414039850234985,17.42081880569458,17.427419900894165,17.43401789665222,17.440837860107422,17.447371006011963,17.453959941864014,17.46058201789856,17.4672110080719,17.47377300262451,17.48049283027649,17.48699402809143,17.493762016296387,17.5002019405365,17.506977796554565,17.51353693008423,17.520236015319824,17.526683807373047,17.533363819122314,17.54014301300049,17.546630859375,17.55317497253418,17.55992889404297,17.566192865371704,17.5728600025177,17.579604864120483,17.586017847061157,17.592494010925293,17.599411010742188,17.605835914611816,17.612318992614746,17.619266986846924,17.625705003738403,17.63226580619812,17.639110803604126,17.6456139087677,17.651949882507324,17.65898084640503,17.665429830551147,17.67188787460327,17.67888593673706,17.685175895690918,17.691659927368164,17.698656797409058,17.704936027526855,17.71143102645874,17.718536853790283,17.724756002426147,17.73110580444336,17.738350868225098,17.744606971740723,17.750903844833374,17.758051872253418,17.764312982559204,17.770424842834473,17.777776956558228,17.784026861190796,17.79026699066162,17.79743981361389,17.8038649559021,17.810115814208984,17.81731081008911,17.823673009872437,17.83006191253662,17.83706784248352,17.843655824661255,17.850008964538574,17.856894969940186,17.863435983657837,17.869786977767944,17.87648582458496,17.883105993270874,17.88960599899292,17.896281003952026,17.902911901474,17.909608840942383,17.916111946105957,17.92276096343994,17.929279804229736,17.935855865478516,17.94238591194153,17.94900679588318,17.955732822418213,17.962191820144653,17.968838930130005,17.975394010543823,17.981925010681152,17.98857593536377,17.99516487121582,18.001712799072266,18.008282899856567,18.015070915222168,18.021795988082886,18.02828097343445,18.035030841827393,18.041741847991943,18.048365831375122,18.054955005645752,18.061609983444214,18.06817889213562,18.074880838394165,18.081480979919434,18.088154792785645,18.09471082687378,18.101361989974976,18.107934951782227,18.11459183692932,18.12088179588318,18.127725839614868,18.134485006332397,18.14089584350586,18.147614002227783,18.154305934906006,18.160539865493774,18.167250871658325,18.17416000366211,18.180426836013794,18.186877012252808,18.19380283355713,18.200215816497803,18.20669198036194,18.213581800460815,18.2200288772583,18.226460933685303,18.23349380493164,18.23989701271057,18.24639892578125,18.253225803375244,18.259857892990112,18.266305923461914,18.273279905319214,18.279608964920044,18.286062955856323,18.293033838272095,18.299348831176758,18.305830001831055,18.312768936157227,18.3191339969635,18.32560682296753,18.33266282081604,18.33901286125183,18.345319986343384,18.352374792099,18.358757972717285,18.36490797996521,18.37222981452942,18.378489017486572,18.384732007980347,18.39194679260254,18.398358821868896,18.40465998649597,18.41165280342102,18.418237924575806,18.424505949020386,18.431607961654663,18.438037872314453,18.44446587562561,18.451385021209717,18.457875967025757,18.46420979499817,18.47095799446106,18.477614879608154,18.483977794647217,18.490755796432495,18.497153997421265,18.503827810287476,18.5106098651886,18.51716685295105,18.523597955703735,18.53014588356018,18.536670923233032,18.543311834335327,18.549997806549072,18.55649495124817,18.563093900680542,18.56974697113037,18.57626700401306,18.58299493789673,18.589481830596924,18.596050024032593,18.602600812911987,18.609347820281982,18.61598491668701,18.622458934783936,18.629161834716797,18.63579297065735,18.642333984375,18.648998975753784,18.655619859695435,18.662293910980225,18.6689670085907,18.675595998764038,18.682215929031372,18.68869686126709,18.69524884223938,18.701810836791992,18.708525896072388,18.714972972869873,18.721648931503296,18.728420972824097,18.734993934631348,18.741503953933716,18.748225927352905,18.75464701652527,18.761225938796997,18.768069982528687,18.77451992034912,18.78102397918701,18.787976026535034,18.794317960739136,18.80077886581421,18.807655811309814,18.81411099433899,18.820567846298218,18.827436923980713,18.83393096923828,18.840466022491455,18.847373008728027,18.853796005249023,18.86037302017212,18.867244958877563,18.873710870742798,18.880082845687866,18.88714289665222,18.89357900619507,18.900221824645996,18.90759801864624,18.914098024368286,18.92091393470764,18.928761959075928,18.935661792755127,18.943193912506104,18.95218586921692,18.960518836975098,18.96930980682373,18.97988200187683,18.989107847213745,18.998833894729614,19.011072874069214,19.024482011795044,19.04168391227722,19.06683897972107,19.095980882644653,19.252887964248657,19.300489902496338,19.350088834762573,19.458300828933716,19.550038814544678,19.616288900375366,19.67446279525757,19.732770919799805,19.802145957946777,19.8715078830719,19.97664999961853,20.01389193534851,20.036201000213623,20.05020785331726,20.062297821044922,20.07467293739319,20.084529876708984,20.093552827835083,20.10311985015869,20.11126685142517,20.11891794204712,20.127146005630493,20.134639978408813,20.141754865646362,20.149170875549316,20.15621781349182,20.163066864013672,20.169989824295044,20.17675280570984,20.183480978012085,20.19028902053833,20.196985006332397,20.203744888305664,20.210426807403564,20.217063903808594,20.223649978637695,20.230448961257935,20.23678994178772,20.243542909622192,20.25038194656372,20.25674080848694,20.263383865356445,20.270105838775635,20.27665686607361,20.28333282470703,20.28990888595581,20.2964129447937,20.303151845932007,20.309894800186157,20.31652283668518,20.323022842407227,20.329766988754272,20.33632493019104,20.342832803726196,20.349551916122437,20.3561909198761,20.36264181137085,20.369241952896118,20.375837802886963,20.382511854171753,20.38906693458557,20.395713806152344,20.402288913726807,20.408944845199585,20.415413856506348,20.422109842300415,20.4289448261261,20.435484886169434,20.4419949054718,20.44887900352478,20.455278873443604,20.461957931518555,20.468724966049194,20.4751718044281,20.48165488243103,20.488520860671997,20.494913816452026,20.501494884490967,20.5083749294281,20.51471185684204,20.521260976791382,20.52812385559082,20.534621953964233,20.54095983505249,20.547858953475952,20.55428695678711,20.56072998046875,20.56787395477295,20.5741229057312,20.580444812774658,20.587432861328125,20.59370493888855,20.60016393661499,20.607265949249268,20.613454818725586,20.619903802871704,20.627059936523438,20.633298873901367,20.639675855636597,20.64686393737793,20.653100967407227,20.659523010253906,20.666852951049805,20.67312979698181,20.679258823394775,20.68649387359619,20.692880868911743,20.699265956878662,20.706272840499878,20.712639808654785,20.719016790390015,20.725905895233154,20.73262882232666,20.738862991333008,20.745730876922607,20.752201795578003,20.758795022964478,20.76541781425476,20.771996021270752,20.77834391593933,20.785173892974854,20.791795015335083,20.79831099510193,20.804826974868774,20.811450958251953,20.817957878112793,20.824512004852295,20.831034898757935,20.83770489692688,20.84444284439087,20.850878953933716,20.85760498046875,20.8643159866333,20.87084197998047,20.877696990966797,20.88426685333252,20.890820026397705,20.897400856018066,20.904148817062378,20.910830974578857,20.917308807373047,20.924098014831543,20.93066692352295,20.937299966812134,20.94387197494507,20.950522899627686,20.95709991455078,20.96377682685852,20.970371961593628,20.97702193260193,20.98365092277527,20.99024796485901,20.9967257976532,21.00331687927246,21.009811878204346,21.01651883125305,21.02323293685913,21.029680013656616,21.03631591796875,21.043056964874268,21.049422025680542,21.056281805038452,21.06296396255493,21.0693039894104,21.07597780227661,21.08287787437439,21.089303016662598,21.095775842666626,21.102656841278076,21.10902500152588,21.115538835525513,21.122421979904175,21.128878831863403,21.135321855545044,21.142138957977295,21.148573875427246,21.15500783920288,21.161986827850342,21.16837191581726,21.17485284805298,21.181829929351807,21.188119888305664,21.194477796554565,21.201642990112305,21.20779299736023,21.214216947555542,21.22146987915039,21.22760796546936,21.233932971954346,21.241086959838867,21.247368812561035,21.253686904907227,21.261085987091064,21.267350912094116,21.27367901802063,21.280850887298584,21.287304878234863,21.293401956558228,21.300537824630737,21.306998014450073,21.313187837600708,21.32030200958252,21.32669186592102,21.3332200050354,21.340096950531006,21.346630811691284,21.35290002822876,21.359591007232666,21.36612582206726,21.372594833374023,21.379297971725464,21.38589096069336,21.392582893371582,21.3991539478302,21.40582299232483,21.412338972091675,21.418866872787476,21.42537784576416,21.432037830352783,21.4387309551239,21.445177793502808,21.451854944229126,21.458603858947754,21.465178966522217,21.47191286087036,21.47851586341858,21.48506498336792,21.491511821746826,21.498270988464355,21.50499987602234,21.511475801467896,21.518114805221558,21.52466082572937,21.53126096725464,21.537861824035645,21.54451084136963,21.551059007644653,21.557758808135986,21.564337015151978,21.57103395462036,21.577608823776245,21.58427882194519,21.590858936309814,21.59753394126892,21.604009866714478,21.61070990562439,21.617488861083984,21.623852968215942,21.630497932434082,21.637265920639038,21.64366388320923,21.650346994400024,21.657135009765625,21.663558959960938,21.670037984848022,21.67703080177307,21.683501958847046,21.690008878707886,21.696882963180542,21.70333480834961,21.70967984199524,21.716656923294067,21.723132848739624,21.72962498664856,21.73648500442505,21.74276900291443,21.749351978302002,21.75632381439209,21.762634992599487,21.769105911254883,21.77607798576355,21.782325983047485,21.788888931274414,21.795889854431152,21.802169799804688,21.808658838272095,21.815823793411255,21.821913957595825,21.82820987701416,21.835357904434204,21.841633796691895,21.84794783592224,21.855264902114868,21.861511945724487,21.867726802825928,21.8751118183136,21.881364822387695,21.887637853622437,21.89478087425232,21.9012348651886,21.90748381614685,21.91448402404785,21.921082973480225,21.92743992805481,21.934327840805054,21.9408278465271,21.947280883789062,21.95390486717224,21.96050786972046,21.967023849487305,21.973706007003784,21.980307817459106,21.98685598373413,21.993536949157715,21.999977827072144,22.00670599937439,22.013279914855957,22.019774913787842,22.026247024536133,22.032941818237305,22.039490938186646,22.046088933944702,22.052734851837158,22.059273958206177,22.065943956375122,22.07249093055725,22.079051971435547,22.08568286895752,22.092432975769043,22.099032878875732,22.105531930923462,22.11226201057434,22.11871099472046,22.125415802001953,22.131995916366577,22.138652801513672,22.14520502090454,22.151700019836426,22.15847897529602,22.165043830871582,22.171701908111572,22.178351879119873,22.18476891517639,22.191612005233765,22.19805884361267,22.204768896102905,22.2115159034729,22.217967987060547,22.22461700439453,22.231205940246582,22.237619876861572,22.244252920150757,22.251036882400513,22.257494926452637,22.26394486427307,22.270811796188354,22.277338981628418,22.28378701210022,22.290692806243896,22.2972149848938,22.303637981414795,22.310516834259033,22.316882848739624,22.3233540058136,22.330269813537598,22.336824893951416,22.343324899673462,22.350282907485962,22.356631994247437,22.36294984817505,22.36990189552307,22.37618398666382,22.382677793502808,22.389832019805908,22.396013021469116,22.4026358127594,22.40980887413025,22.416005849838257,22.4222629070282,22.42951488494873,22.435630798339844,22.441914796829224,22.449275016784668,22.455533981323242,22.46176290512085,22.468973875045776,22.47541379928589,22.48177695274353,22.48868989944458,22.49523687362671,22.50152087211609,22.50854182243347,22.515138864517212,22.521392822265625,22.528405904769897,22.534902811050415,22.541385889053345,22.547899961471558,22.55451798439026,22.56101393699646,22.56780481338501,22.574326992034912,22.581020832061768,22.587678909301758,22.594305992126465,22.600847959518433,22.607404947280884,22.61397099494934,22.620560884475708,22.62728190422058,22.633774995803833,22.640244960784912,22.646885871887207,22.653496026992798,22.66011381149292,22.666610956192017,22.673167943954468,22.679768800735474,22.68654179573059,22.693240880966187,22.699639797210693,22.70637583732605,22.71303701400757,22.719682931900024,22.726234912872314,22.73291802406311,22.739487886428833,22.746009826660156,22.752607822418213,22.75945281982422,22.766028881072998,22.772581815719604,22.77925992012024,22.785959005355835,22.792226791381836,22.799084901809692,22.805831909179688,22.812172889709473,22.818792819976807,22.825565814971924,22.832084894180298,22.838740825653076,22.845395803451538,22.85178780555725,22.858279943466187,22.86519479751587,22.87161898612976,22.87809181213379,22.884959936141968,22.89143991470337,22.89789390563965,22.904833793640137,22.911430835723877,22.917927026748657,22.924818992614746,22.931265830993652,22.937724828720093,22.94473099708557,22.95102882385254,22.957509994506836,22.964486837387085,22.97078585624695,22.977137804031372,22.984226942062378,22.99045181274414,22.997135877609253,23.004262924194336,23.01050901412964,23.016836881637573,23.0240159034729,23.030032873153687,23.03639793395996,23.043926000595093,23.049996852874756,23.05618381500244,23.06339192390442,23.069798946380615,23.076048851013184,23.083042860031128,23.08956480026245,23.09596300125122,23.102856874465942,23.109612941741943,23.115907907485962,23.12278699874878,23.129228830337524,23.135669946670532,23.142408847808838,23.149037837982178,23.155514001846313,23.16221284866333,23.168867826461792,23.175378799438477,23.18193292617798,23.18854284286499,23.195065021514893,23.201648950576782,23.208338022232056,23.21498990058899,23.22173285484314,23.22800302505493,23.23464584350586,23.241317987442017,23.247891902923584,23.254594802856445,23.261151790618896,23.26767897605896,23.274242877960205,23.281018018722534,23.2876558303833,23.29419183731079,23.300976991653442,23.307593822479248,23.314358949661255,23.32080388069153,23.327632904052734,23.33420991897583,23.340806007385254,23.347530841827393,23.354076862335205,23.360670804977417,23.36725687980652,23.373840808868408,23.380548000335693,23.3869788646698,23.393834829330444,23.40063190460205,23.406904935836792,23.413522958755493,23.420292854309082,23.4266939163208,23.433315992355347,23.44011902809143,23.44654679298401,23.453025817871094,23.45992088317871,23.466328859329224,23.472779989242554,23.479641914367676,23.486117839813232,23.492532968521118,23.499429941177368,23.505913019180298,23.51242685317993,23.51944088935852,23.525710821151733,23.53236985206604,23.53934097290039,23.545650959014893,23.552117824554443,23.559088945388794,23.565287828445435,23.57187581062317,23.57901883125305,23.585084915161133,23.591646909713745,23.59883189201355,23.604939937591553,23.611366987228394,23.618409872055054,23.62461495399475,23.631061792373657,23.638413906097412,23.64466691017151,23.65091300010681,23.657956838607788,23.6643488407135,23.670580863952637,23.67758083343506,23.684019804000854,23.690322875976562,23.697325944900513,23.703950881958008,23.710434913635254,23.717267990112305,23.723663806915283,23.730315923690796,23.736840963363647,23.743554830551147,23.750082969665527,23.756760835647583,23.76335883140564,23.77001690864563,23.77646780014038,23.78319501876831,23.789631843566895,23.79631781578064,23.80268883705139,23.80925679206848,23.81616187095642,23.822635889053345,23.829237937927246,23.835933923721313,23.84251379966736,23.849068880081177,23.85559582710266,23.86226797103882,23.868674993515015,23.875396966934204,23.882036924362183,23.88850498199463,23.895301818847656,23.90184497833252,23.908512830734253,23.915138006210327,23.921727895736694,23.928452014923096,23.935122966766357,23.941619873046875,23.948354959487915,23.954989910125732,23.961618900299072,23.96821093559265,23.97489094734192,23.981342792510986,23.98801279067993,23.99477195739746,24.001006841659546,24.00771999359131,24.01456880569458,24.02099299430847,24.02749991416931,24.03427791595459,24.040743827819824,24.047287940979004,24.05421280860901,24.06055498123169,24.06702184677124,24.073871850967407,24.080309867858887,24.08675193786621,24.09364891052246,24.100106954574585,24.10655188560486,24.11348581314087,24.119972944259644,24.126344919204712,24.133502960205078,24.139769792556763,24.14624786376953,24.153217792510986,24.159515857696533,24.165875911712646,24.172995805740356,24.179252862930298,24.185715913772583,24.1928129196167,24.199187994003296,24.20535898208618,24.212721824645996,24.218942880630493,24.225101947784424,24.232563972473145,24.23865795135498,24.244951009750366,24.252280950546265,24.258696794509888,24.264922857284546,24.27199387550354,24.27830195426941,24.2845618724823,24.291647911071777,24.29822587966919,24.30454993247986,24.311489820480347,24.31798481941223,24.324440956115723,24.33102583885193,24.337567806243896,24.34424901008606,24.350945949554443,24.35754895210266,24.364239931106567,24.37061882019043,24.37721085548401,24.38386082649231,24.390429973602295,24.397015810012817,24.40369200706482,24.410420894622803,24.41686987876892,24.42354393005371,24.430102825164795,24.436790943145752,24.443461894989014,24.450037002563477,24.456642866134644,24.463167905807495,24.469929933547974,24.4765408039093,24.482926845550537,24.48966383934021,24.496213912963867,24.50285792350769,24.509455919265747,24.516098022460938,24.522673845291138,24.529407024383545,24.53599786758423,24.54270887374878,24.54941201210022,24.55606198310852,24.562668800354004,24.569336891174316,24.5756938457489,24.582491874694824,24.589212894439697,24.59567093849182,24.602272987365723,24.608886003494263,24.615500926971436,24.621932983398438,24.628742933273315,24.635337829589844,24.641819953918457,24.648759841918945,24.65518879890442,24.661491870880127,24.6683988571167,24.674906969070435,24.68132781982422,24.688175916671753,24.69463801383972,24.70108985900879,24.7080078125,24.71445083618164,24.72088098526001,24.727869987487793,24.734123945236206,24.7407009601593,24.74766993522644,24.75394892692566,24.76045298576355,24.767687797546387,24.773873805999756,24.780321836471558,24.787386894226074,24.793636798858643,24.7999529838562,24.807222843170166,24.813491821289062,24.81981897354126,24.827142000198364,24.833420991897583,24.839667797088623,24.84673285484314,24.853176832199097,24.859452962875366,24.866525888442993,24.872952938079834,24.87922692298889,24.886252880096436,24.892825841903687,24.89911198616028,24.906036853790283,24.91252589225769,24.918975830078125,24.925606966018677,24.932206869125366,24.938766956329346,24.945377826690674,24.95203995704651,24.958865880966187,24.96537184715271,24.97197389602661,24.97854995727539,24.985123872756958,24.9916729927063,24.998092889785767,25.004859924316406,25.011445999145508,25.01809287071228,25.024747848510742,25.031317949295044,25.037866830825806,25.044466018676758,25.05112600326538,25.057670831680298,25.064334869384766,25.0709547996521,25.07754683494568,25.084342002868652,25.090868949890137,25.097355842590332,25.10389494895935,25.110549926757812,25.117105960845947,25.12378191947937,25.13038396835327,25.137054920196533,25.143662929534912,25.150457859039307,25.156880855560303,25.16370391845703,25.170180797576904,25.176853895187378,25.1836519241333,25.19006896018982,25.19651985168457,25.20346689224243,25.209877014160156,25.21655297279358,25.223342895507812,25.229665994644165,25.23615598678589,25.243170022964478,25.24967098236084,25.25609588623047,25.262858867645264,25.269306898117065,25.27572989463806,25.2826030254364,25.28903079032898,25.295668840408325,25.302506923675537,25.308867931365967,25.315298795700073,25.322309017181396,25.328579902648926,25.335054874420166,25.34202790260315,25.348299980163574,25.354899883270264,25.36210584640503,25.36812400817871,25.374591827392578,25.381814002990723,25.38801598548889,25.39431881904602,25.401489973068237,25.407795906066895,25.414063930511475,25.42147994041443,25.427693843841553,25.433915853500366,25.441115856170654,25.447566986083984,25.45381498336792,25.460838794708252,25.4672908782959,25.4736008644104,25.480620861053467,25.487170934677124,25.49352502822876,25.500449895858765,25.506896018981934,25.513370990753174,25.52000379562378,25.52657198905945,25.533069849014282,25.539774894714355,25.546369791030884,25.553020000457764,25.559595823287964,25.566223859786987,25.572958946228027,25.579526901245117,25.58603000640869,25.592777967453003,25.59941291809082,25.605860948562622,25.61250901222229,25.619127988815308,25.625770807266235,25.632436990737915,25.63904881477356,25.6454598903656,25.65204882621765,25.658803939819336,25.66553497314453,25.6720027923584,25.678778886795044,25.685333013534546,25.69195795059204,25.69855785369873,25.705057859420776,25.711602926254272,25.718243837356567,25.724864959716797,25.73150086402893,25.738104820251465,25.74474287033081,25.751327991485596,25.758033990859985,25.764467000961304,25.7712140083313,25.778088808059692,25.784531831741333,25.79115581512451,25.79790687561035,25.80433702468872,25.81095790863037,25.81773281097412,25.824281930923462,25.830673933029175,25.837653875350952,25.844106912612915,25.850652933120728,25.8573899269104,25.863905906677246,25.870356798171997,25.877245903015137,25.883702993392944,25.89016079902649,25.897082805633545,25.903494834899902,25.909838914871216,25.91680598258972,25.923065900802612,25.92954182624817,25.936505794525146,25.94280481338501,25.949328899383545,25.956445932388306,25.962617874145508,25.96913194656372,25.976354837417603,25.98259687423706,25.988873958587646,25.996212005615234,26.00236201286316,26.00878596305847,26.016013860702515,26.022411823272705,26.028565883636475,26.03583002090454,26.04226279258728,26.048537015914917,26.05555486679077,26.062007904052734,26.068307876586914,26.07528281211853,26.081784963607788,26.088128805160522,26.09510588645935,26.10162901878357,26.107990980148315,26.11467981338501,26.12114691734314,26.127640962600708,26.13436198234558,26.14095687866211,26.147652864456177,26.154167890548706,26.160807847976685,26.167418003082275,26.174158811569214,26.180466890335083,26.18730592727661,26.19386887550354,26.200568914413452,26.20720386505127,26.213879823684692,26.220458984375,26.22716999053955,26.23373794555664,26.240206003189087,26.246853828430176,26.253516912460327,26.260236024856567,26.26676082611084,26.27348780632019,26.28007984161377,26.286633014678955,26.293295860290527,26.299880981445312,26.306456804275513,26.313187837600708,26.319769859313965,26.326278924942017,26.332841873168945,26.339493989944458,26.34607481956482,26.3527729511261,26.359251022338867,26.365952014923096,26.372776985168457,26.379222869873047,26.38587999343872,26.392735958099365,26.39914584159851,26.405727863311768,26.41261386871338,26.41901683807373,26.425530910491943,26.43242383003235,26.438884019851685,26.445214986801147,26.45213484764099,26.45865797996521,26.46498990058899,26.471860885620117,26.478501796722412,26.484936952590942,26.491856813430786,26.498291969299316,26.504734992980957,26.511739015579224,26.51805281639099,26.524411916732788,26.531352996826172,26.537660837173462,26.544185876846313,26.551312923431396,26.557504892349243,26.56396484375,26.571133852005005,26.577401876449585,26.583748817443848,26.590898990631104,26.59724187850952,26.6036159992218,26.610930919647217,26.617164850234985,26.623260974884033,26.63061285018921,26.63699197769165,26.643248796463013,26.650288820266724,26.656744956970215,26.663031816482544,26.669890880584717,26.67653179168701,26.68293285369873,26.689833879470825,26.69636297225952,26.70279097557068,26.709417819976807,26.715850830078125,26.72251582145691,26.729211807250977,26.735649824142456,26.74235701560974,26.748942852020264,26.755558013916016,26.762115001678467,26.768698930740356,26.77515196800232,26.781864881515503,26.788524866104126,26.795148849487305,26.80177092552185,26.80846381187439,26.81503701210022,26.8216609954834,26.828215837478638,26.834741830825806,26.8412868976593,26.848060846328735,26.85466694831848,26.86114192008972,26.86788296699524,26.874270915985107,26.88108801841736,26.887633800506592,26.89428400993347,26.900859832763672,26.907468795776367,26.914084911346436,26.920843839645386,26.92718482017517,26.933990001678467,26.94051194190979,26.94709801673889,26.953547954559326,26.9602370262146,26.966983795166016,26.97345280647278,26.980060815811157,26.98680090904236,26.993250846862793,27.000043869018555,27.006703853607178,27.013137817382812,27.019690990447998,27.026610851287842,27.033020973205566,27.03949785232544,27.046414852142334,27.052801847457886,27.059377908706665,27.066359996795654,27.073006868362427,27.07948589324951,27.086814880371094,27.09341788291931,27.100396871566772,27.107969999313354,27.114861011505127,27.121891021728516,27.129397869110107,27.136505842208862,27.14362382888794,27.15166997909546,27.158790826797485,27.166210889816284,27.17455792427063,27.181870937347412,27.1893630027771,27.198011875152588,27.205604791641235,27.2134690284729,27.222620964050293,27.230490922927856,27.23844599723816,27.247654914855957,27.25614881515503,27.264344930648804,27.273936986923218,27.28278684616089,27.29150700569153,27.301416873931885,27.310914993286133,27.320080995559692,27.330400943756104,27.340375900268555,27.35024881362915,27.36084294319153,27.371529817581177,27.38236689567566,27.39382290840149,27.405430793762207,27.417548894882202,27.429919958114624,27.442670822143555,27.455777883529663,27.469652891159058,27.483789920806885,27.499030828475952,27.515313863754272,27.531908988952637,27.550062894821167,27.569942951202393,27.5914409160614,27.616195917129517,27.644924879074097,27.681782960891724,27.74915385246277]

# %% [markdown]
# ## Case 2 ###

# %%
buf = [4.202237606048584, 6, 127, 127, 0.7137387990951538, 5, 127, 126, -1.2045060396194458, 4, 126, 127, -1.6808949708938599, 3, 128, 127, -1.97883141040802, 2, 128, 127, -2.0493102073669434, 1, 127, 127, 2.382160186767578, 6, 127, 128, 2.518512725830078, 5, 127, 127, -2.397430181503296, 4, 127, 127, -2.485044002532959, 3, 128, 128, -2.5704405307769775, 2, 127, 127, -2.382160186767578, 1, 127, 127, 2.428565740585327, 6, 128, 127, 2.4444386959075928, 5, 127, 127, -2.239515542984009, 4, 127, 126, -2.2195794582366943, 3, 127, 127, -2.187129259109497, 2, 127, 127, -1.9581104516983032, 1, 127, 126, 1.8514807224273682, 6, 128, 127, 1.571424961090088, 5, 127, 127, -1.1385058164596558, 4, 127, 127, 0.16563290357589722, 5, 127, 127, 0.7003728747367859, 6, 127, 126, 1.2742730379104614, 1, 127, 128, 1.58139169216156, 2, 127, 127, 1.7395308017730713, 3, 126, 127, 2.027095317840576, 4, 127, 127, 2.124994993209839, 5, 127, 127, 2.1744134426116943, 6, 128, 127, 2.397430181503296, 1, 127, 128, 2.397430181503296, 2, 127, 127, 2.352195978164673, 3, 127, 126, 2.485044002532959, 4, 126, 127, 2.4051389694213867, 5, 127, 128, 2.352195978164673, 6, 127, 127, 2.485044002532959, 1, 126, 128, 2.452453136444092, 2, 127, 127, 2.2874562740325928, 3, 127, 127, 2.436476469039917, 4, 127, 127, 2.382160186767578, 5, 126, 126, 2.1618447303771973, 6, 127, 127, 2.2735507488250732, 1, 127, 128, 2.20648455619812, 2, 127, 127, 1.9632501602172852, 3, 127, 127, 2.0107479095458984, 4, 127, 127, 1.908158779144287, 5, 127, 127, 1.601709246635437, 6, 127, 127, 1.5141664743423462, 1, 128, 127, 0.8667418956756592, 2, 127, 128, 0.8069021105766296, 3, 166, 166, 4.58894681930542, 4, 128, 163, 5.7538323402404785, 5, 93, 129, 6.285699844360352, 6, 94, 92, 7.957428455352783, 1, 127, 95, 8.311092376708984, 2, 163, 127, 8.21976089477539, 3, 164, 162, 9.973310470581055, 4, 127, 152, 9.973310470581055, 5, 107, 127, 9.234545707702637, 6, 105, 107, 10.840554237365723, 1, 126, 112, 10.840554237365723, 2, 138, 128, 9.842082023620605, 3, 141, 139, 11.333307266235352, 4, 126, 138, 11.333307266235352, 5, 119, 127, 9.714262962341309, 6, 116, 117, 11.687472343444824, 1, 126, 117, 11.687472343444824, 2, 137, 127, 10.246551513671875, 3, 138, 136, 11.333307266235352, 4, 127, 135, 11.687472343444824, 5, 117, 128, 10.535186767578125, 6, 119, 119, 11.333307266235352, 1, 126, 117, 11.687472343444824, 2, 136, 127, 10.535186767578125, 3, 135, 136, 11.333307266235352, 4, 128, 134, 11.687472343444824, 5, 118, 128, 10.840554237365723, 6, 118, 117, 11.333307266235352, 1, 127, 117, 11.507664680480957, 2, 135, 128, 11.164153099060059, 3, 135, 133, 11.164153099060059, 4, 128, 135, 11.333307266235352, 5, 119, 128, 11.164153099060059, 6, 119, 119, 11.164153099060059, 1, 126, 118, 11.164153099060059, 2, 133, 128, 11.333307266235352, 3, 136, 136, 11.333307266235352, 4, 127, 135, 11.333307266235352, 5, 120, 127, 11.164153099060059, 6, 120, 119, 11.507664680480957, 1, 126, 118, 11.164153099060059, 2, 134, 127, 10.999974250793457, 3, 136, 136, 11.507664680480957, 4, 127, 134, 11.164153099060059, 5, 119, 128, 11.164153099060059, 6, 121, 121, 11.333307266235352, 1, 127, 119, 11.164153099060059, 2, 134, 126, 11.164153099060059, 3, 134, 133, 11.507664680480957, 4, 127, 133, 11.333307266235352, 5, 119, 128, 10.999974250793457, 6, 120, 118, 11.164153099060059, 1, 127, 119, 11.507664680480957, 2, 134, 127, 10.999974250793457, 3, 134, 134, 11.333307266235352, 4, 128, 136, 11.164153099060059, 5, 119, 128, 11.333307266235352, 6, 123, 122, 11.164153099060059, 1, 127, 119, 11.333307266235352, 2, 133, 127, 10.999974250793457, 3, 135, 134, 11.333307266235352, 4, 127, 136, 10.999974250793457, 5, 120, 129, 11.333307266235352, 6, 121, 120, 11.164153099060059, 1, 126, 121, 11.333307266235352, 2, 135, 126, 10.999974250793457, 3, 136, 136, 11.507664680480957, 4, 126, 134, 11.164153099060059, 5, 119, 127, 10.999974250793457, 6, 121, 120, 11.507664680480957, 1, 126, 120, 11.164153099060059, 2, 134, 127, 10.999974250793457, 3, 135, 133, 11.507664680480957, 4, 127, 133, 11.164153099060059, 5, 121, 127, 10.999974250793457, 6, 121, 122, 11.507664680480957, 1, 126, 119, 11.507664680480957, 2, 132, 127, 10.685688972473145, 3, 134, 133, 11.507664680480957, 4, 127, 132, 11.507664680480957, 5, 118, 127, 10.840554237365723, 6, 119, 119, 11.507664680480957, 1, 126, 118, 11.507664680480957, 2, 134, 127, 10.840554237365723, 3, 135, 133, 11.333307266235352, 4, 127, 133, 11.507664680480957, 5, 121, 128, 10.685688972473145, 6, 121, 120, 11.687472343444824, 1, 126, 121, 11.507664680480957, 2, 133, 127, 10.685688972473145, 3, 136, 134, 11.872987747192383, 4, 127, 134, 11.333307266235352, 5, 120, 128, 10.685688972473145, 6, 118, 118, 11.872987747192383, 1, 126, 121, 11.507664680480957, 2, 134, 128, 10.388864517211914, 3, 135, 136, 12.064488410949707, 4, 127, 132, 11.507664680480957, 5, 118, 128, 10.388864517211914, 6, 120, 120, 12.064488410949707, 1, 127, 117, 11.687472343444824, 2, 135, 127, 10.388864517211914, 3, 136, 135, 11.872987747192383, 4, 127, 136, 11.687472343444824, 5, 118, 127, 10.108084678649902, 6, 119, 118, 11.872987747192383, 1, 126, 118, 12.064488410949707, 2, 133, 127, 10.388864517211914, 3, 135, 135, 11.507664680480957, 4, 127, 134, 11.872987747192383, 5, 118, 127, 10.535186767578125, 6, 119, 119, 11.507664680480957, 1, 127, 119, 11.872987747192383, 2, 134, 128, 10.535186767578125, 3, 133, 133, 11.333307266235352, 4, 127, 134, 11.687472343444824, 5, 120, 129, 10.685688972473145, 6, 118, 118, 11.333307266235352, 1, 127, 117, 11.507664680480957, 2, 135, 127, 11.164153099060059, 3, 136, 135, 11.333307266235352, 4, 128, 135, 11.333307266235352, 5, 118, 127, 11.164153099060059, 6, 121, 120, 11.164153099060059, 1, 126, 119, 11.164153099060059, 2, 134, 127, 11.333307266235352, 3, 136, 135, 11.164153099060059, 4, 129, 135, 11.333307266235352, 5, 117, 127, 11.333307266235352, 6, 119, 117, 11.333307266235352, 1, 127, 117, 11.164153099060059, 2, 134, 126, 10.999974250793457, 3, 134, 134, 11.687472343444824, 4, 127, 134, 11.164153099060059, 5, 116, 127, 11.164153099060059, 6, 119, 119, 11.333307266235352, 1, 126, 119, 10.999974250793457, 2, 135, 126, 11.333307266235352, 3, 135, 134, 11.333307266235352, 4, 126, 135, 11.333307266235352, 5, 119, 127, 10.840554237365723, 6, 118, 118, 11.164153099060059, 1, 126, 118, 11.333307266235352, 2, 136, 126, 10.999974250793457, 3, 135, 134, 11.333307266235352, 4, 127, 133, 11.164153099060059, 5, 118, 127, 11.164153099060059, 6, 121, 120, 11.164153099060059, 1, 127, 118, 11.333307266235352, 2, 136, 127, 10.999974250793457, 3, 135, 135, 11.164153099060059, 4, 127, 138, 11.164153099060059, 5, 121, 128, 11.333307266235352, 6, 118, 119, 11.164153099060059, 1, 126, 119, 11.164153099060059, 2, 134, 128, 11.164153099060059, 3, 136, 134, 11.507664680480957, 4, 127, 134, 10.999974250793457, 5, 119, 128, 10.999974250793457, 6, 118, 119, 11.687472343444824, 1, 126, 121, 11.333307266235352, 2, 133, 128, 10.999974250793457, 3, 135, 134, 11.507664680480957, 4, 127, 134, 11.164153099060059, 5, 119, 128, 10.999974250793457, 6, 121, 121, 11.507664680480957, 1, 127, 119, 11.507664680480957, 2, 133, 127, 10.840554237365723, 3, 135, 135, 11.507664680480957, 4, 128, 136, 11.507664680480957, 5, 120, 128, 10.685688972473145, 6, 121, 121, 11.507664680480957, 1, 127, 120, 11.507664680480957, 2, 135, 126, 10.840554237365723, 3, 135, 134, 11.507664680480957, 4, 126, 133, 11.333307266235352, 5, 117, 127, 10.840554237365723, 6, 122, 121, 11.507664680480957, 1, 127, 119, 11.507664680480957, 2, 134, 127, 10.535186767578125, 3, 135, 135, 11.872987747192383, 4, 127, 134, 11.333307266235352, 5, 121, 129, 10.685688972473145, 6, 118, 117, 11.872987747192383, 1, 127, 120, 11.333307266235352, 2, 135, 127, 10.388864517211914, 3, 136, 138, 12.064488410949707, 4, 128, 134, 11.507664680480957, 5, 120, 129, 10.388864517211914, 6, 119, 119, 11.872987747192383, 1, 127, 118, 11.687472343444824, 2, 134, 126, 10.388864517211914, 3, 136, 136, 11.872987747192383, 4, 127, 136, 11.687472343444824, 5, 122, 127, 10.108084678649902, 6, 117, 118, 11.872987747192383, 1, 127, 117, 12.064488410949707, 2, 133, 126, 10.246551513671875, 3, 135, 135, 11.507664680480957, 4, 126, 136, 11.872987747192383, 5, 119, 127, 10.535186767578125, 6, 119, 119, 11.507664680480957, 1, 125, 119, 11.872987747192383, 2, 135, 127, 10.535186767578125, 3, 138, 135, 11.333307266235352, 4, 127, 135, 11.687472343444824, 5, 120, 129, 10.685688972473145, 6, 117, 117, 11.507664680480957, 1, 126, 119, 11.507664680480957, 2, 137, 128, 11.164153099060059, 3, 136, 134, 11.164153099060059, 4, 127, 135, 11.507664680480957, 5, 119, 128, 10.999974250793457, 6, 119, 118, 11.333307266235352, 1, 126, 120, 11.164153099060059, 2, 135, 127, 11.333307266235352, 3, 136, 134, 11.164153099060059, 4, 127, 137, 11.333307266235352, 5, 120, 128, 11.333307266235352, 6, 120, 120, 11.333307266235352, 1, 126, 118, 11.333307266235352, 2, 134, 127, 11.164153099060059, 3, 134, 134, 11.507664680480957, 4, 126, 136, 11.164153099060059, 5, 121, 128, 11.164153099060059, 6, 119, 120, 11.333307266235352, 1, 125, 119, 11.164153099060059, 2, 136, 127, 11.164153099060059, 3, 136, 136, 11.507664680480957, 4, 128, 137, 11.333307266235352, 5, 122, 128, 10.999974250793457, 6, 120, 121, 11.333307266235352, 1, 125, 118, 11.333307266235352, 2, 135, 127, 10.999974250793457, 3, 134, 134, 11.333307266235352, 4, 127, 136, 11.164153099060059, 5, 121, 128, 11.333307266235352, 6, 119, 118, 11.164153099060059, 1, 127, 118, 11.333307266235352, 2, 136, 126, 11.164153099060059, 3, 135, 133, 11.164153099060059, 4, 127, 136, 11.164153099060059, 5, 120, 129, 11.333307266235352, 6, 120, 122, 11.164153099060059, 1, 125, 120, 11.164153099060059, 2, 134, 126, 11.164153099060059, 3, 134, 133, 11.507664680480957, 4, 127, 133, 11.164153099060059, 5, 121, 128, 10.999974250793457, 6, 120, 119, 11.687472343444824, 1, 127, 117, 11.164153099060059, 2, 133, 128, 10.999974250793457, 3, 134, 133, 11.507664680480957, 4, 126, 136, 11.164153099060059, 5, 120, 128, 10.999974250793457, 6, 121, 121, 11.507664680480957, 1, 126, 120, 11.507664680480957, 2, 132, 128, 10.685688972473145, 3, 133, 134, 11.507664680480957, 4, 126, 134, 11.507664680480957, 5, 120, 127, 10.840554237365723, 6, 120, 121, 11.507664680480957, 1, 127, 120, 11.507664680480957, 2, 133, 127, 10.840554237365723, 3, 133, 133, 11.333307266235352, 4, 128, 134, 11.507664680480957, 5, 120, 127, 10.685688972473145, 6, 117, 118, 11.687472343444824, 1, 125, 121, 11.507664680480957, 2, 132, 127, 10.535186767578125, 3, 136, 134, 11.872987747192383, 4, 126, 132, 11.507664680480957, 5, 119, 128, 10.535186767578125, 6, 119, 119, 11.872987747192383, 1, 125, 122, 11.507664680480957, 2, 133, 127, 10.388864517211914, 3, 137, 136, 11.872987747192383, 4, 126, 134, 11.507664680480957, 5, 121, 127, 10.388864517211914, 6, 119, 118, 11.872987747192383, 1, 126, 119, 11.872987747192383, 2, 134, 127, 10.388864517211914, 3, 136, 133, 11.872987747192383, 4, 127, 135, 11.687472343444824, 5, 121, 127, 10.108084678649902, 6, 118, 119, 11.872987747192383, 1, 127, 117, 11.872987747192383, 2, 132, 128, 10.388864517211914, 3, 135, 134, 11.507664680480957, 4, 129, 135, 11.872987747192383, 5, 119, 128, 10.535186767578125, 6, 117, 119, 11.507664680480957, 1, 126, 118, 11.872987747192383, 2, 134, 128, 10.535186767578125, 3, 134, 132, 11.333307266235352, 4, 127, 138, 11.687472343444824, 5, 119, 128, 10.685688972473145, 6, 120, 121, 11.507664680480957, 1, 126, 119, 11.507664680480957, 2, 135, 127, 11.164153099060059, 3, 136, 135, 11.164153099060059, 4, 127, 134, 11.507664680480957, 5, 120, 129, 10.999974250793457, 6, 118, 120, 11.333307266235352, 1, 125, 121, 11.164153099060059, 2, 136, 127, 11.333307266235352, 3, 135, 136, 11.164153099060059, 4, 127, 134, 11.333307266235352, 5, 119, 126, 11.333307266235352, 6, 119, 119, 11.333307266235352, 1, 126, 120, 11.164153099060059, 2, 135, 127, 11.164153099060059, 3, 134, 135, 11.507664680480957, 4, 127, 136, 11.164153099060059, 5, 120, 128, 10.999974250793457, 6, 118, 118, 11.333307266235352, 1, 127, 117, 11.164153099060059, 2, 134, 127, 11.333307266235352, 3, 133, 133, 11.333307266235352, 4, 128, 135, 11.333307266235352, 5, 119, 128, 10.999974250793457, 6, 120, 122, 11.164153099060059, 1, 126, 118, 11.333307266235352, 2, 136, 128, 10.999974250793457, 3, 134, 134, 11.333307266235352, 4, 128, 136, 11.164153099060059, 5, 117, 128, 11.333307266235352, 6, 120, 120, 11.164153099060059, 1, 127, 119, 11.333307266235352, 2, 137, 127, 10.999974250793457, 3, 134, 133, 11.333307266235352, 4, 127, 135, 11.164153099060059, 5, 119, 129, 11.333307266235352, 6, 121, 120, 11.164153099060059, 1, 125, 119, 11.164153099060059, 2, 134, 127, 11.164153099060059, 3, 134, 135, 11.507664680480957, 4, 127, 134, 11.164153099060059, 5, 121, 128, 10.840554237365723, 6, 119, 119, 11.687472343444824, 1, 127, 118, 11.164153099060059, 2, 135, 126, 10.999974250793457, 3, 137, 135, 11.507664680480957, 4, 127, 135, 11.164153099060059, 5, 122, 129, 10.840554237365723, 6, 119, 120, 11.687472343444824, 1, 127, 119, 11.333307266235352, 2, 133, 129, 10.840554237365723, 3, 135, 135, 11.687472343444824, 4, 128, 133, 11.333307266235352, 5, 121, 128, 10.840554237365723, 6, 121, 120, 11.507664680480957, 1, 126, 119, 11.507664680480957, 2, 135, 128, 10.840554237365723, 3, 135, 136, 11.507664680480957, 4, 127, 133, 11.333307266235352, 5, 121, 128, 10.840554237365723, 6, 119, 118, 11.507664680480957, 1, 126, 122, 11.507664680480957, 2, 132, 127, 10.685688972473145, 3, 134, 134, 11.687472343444824, 4, 127, 132, 11.507664680480957, 5, 119, 128, 10.685688972473145, 6, 120, 119, 11.872987747192383, 1, 126, 122, 11.507664680480957, 2, 133, 127, 10.388864517211914, 3, 137, 136, 12.064488410949707, 4, 128, 132, 11.507664680480957, 5, 119, 128, 10.388864517211914, 6, 120, 118, 11.872987747192383, 1, 127, 119, 11.687472343444824, 2, 135, 126, 10.388864517211914, 3, 136, 133, 11.872987747192383, 4, 126, 135, 11.687472343444824, 5, 120, 128, 10.108084678649902, 6, 120, 119, 11.872987747192383, 1, 126, 120, 11.872987747192383, 2, 133, 126, 10.388864517211914, 3, 135, 136, 11.507664680480957, 4, 128, 135, 11.872987747192383, 5, 119, 128, 10.535186767578125, 6, 119, 120, 11.507664680480957, 1, 126, 118, 11.872987747192383, 2, 136, 128, 10.535186767578125, 3, 135, 134, 11.333307266235352, 4, 127, 134, 11.687472343444824, 5, 119, 128, 10.840554237365723, 6, 120, 119, 11.507664680480957, 1, 126, 119, 11.507664680480957, 2, 136, 128, 11.164153099060059, 3, 136, 135, 11.333307266235352, 4, 127, 135, 11.507664680480957, 5, 118, 127, 11.164153099060059, 6, 119, 119, 11.333307266235352, 1, 127, 119, 11.164153099060059, 2, 137, 127, 11.164153099060059, 3, 136, 135, 11.333307266235352, 4, 128, 135, 11.333307266235352, 5, 118, 128, 11.333307266235352, 6, 116, 118, 11.333307266235352, 1, 125, 119, 11.164153099060059, 2, 134, 127, 11.164153099060059, 3, 137, 135, 11.507664680480957, 4, 127, 136, 11.164153099060059, 5, 120, 129, 11.164153099060059, 6, 121, 122, 11.333307266235352, 1, 126, 118, 10.999974250793457, 2, 134, 127, 11.333307266235352, 3, 134, 133, 11.333307266235352, 4, 126, 135, 11.507664680480957, 5, 119, 128, 10.999974250793457, 6, 120, 121, 11.333307266235352, 1, 127, 117, 11.507664680480957, 2, 135, 127, 10.840554237365723, 3, 135, 134, 11.507664680480957, 4, 129, 134, 11.333307266235352, 5, 118, 128, 11.333307266235352, 6, 120, 119, 11.164153099060059, 1, 127, 118, 11.333307266235352, 2, 133, 127, 11.164153099060059, 3, 137, 135, 11.164153099060059, 4, 127, 134, 11.164153099060059, 5, 120, 129, 11.333307266235352, 6, 119, 120, 11.164153099060059, 1, 127, 119, 11.333307266235352, 2, 135, 128, 11.164153099060059, 3, 135, 134, 11.507664680480957, 4, 127, 132, 11.164153099060059, 5, 120, 129, 10.999974250793457, 6, 118, 118, 11.507664680480957, 1, 126, 120, 11.164153099060059, 2, 133, 127, 10.999974250793457, 3, 135, 133, 11.687472343444824, 4, 126, 132, 11.164153099060059, 5, 121, 128, 10.999974250793457, 6, 121, 119, 11.507664680480957, 1, 126, 119, 11.507664680480957, 2, 136, 127, 10.685688972473145, 3, 134, 133, 11.507664680480957, 4, 128, 134, 11.507664680480957, 5, 121, 128, 10.840554237365723, 6, 121, 122, 11.507664680480957, 1, 126, 119, 11.507664680480957, 2, 134, 127, 10.685688972473145, 3, 134, 133, 11.507664680480957, 4, 128, 133, 11.507664680480957, 5, 119, 127, 10.685688972473145, 6, 121, 119, 11.687472343444824, 1, 126, 119, 11.507664680480957, 2, 132, 127, 10.535186767578125, 3, 135, 133, 11.872987747192383, 4, 128, 132, 11.507664680480957, 5, 121, 129, 10.685688972473145, 6, 118, 118, 11.687472343444824, 1, 126, 122, 11.507664680480957, 2, 134, 128, 10.388864517211914, 3, 137, 137, 12.064488410949707, 4, 127, 133, 11.507664680480957, 5, 118, 128, 10.246551513671875, 6, 120, 120, 12.064488410949707, 1, 127, 117, 11.687472343444824, 2, 134, 126, 10.388864517211914, 3, 135, 135, 11.872987747192383, 4, 127, 134, 11.687472343444824, 5, 122, 129, 10.108084678649902, 6, 120, 119, 11.872987747192383, 1, 126, 120, 11.872987747192383, 2, 135, 127, 10.388864517211914, 3, 136, 138, 11.687472343444824, 4, 128, 136, 11.872987747192383, 5, 121, 128, 10.535186767578125, 6, 119, 121, 11.507664680480957, 1, 127, 118, 11.872987747192383, 2, 133, 126, 10.535186767578125, 3, 134, 133, 11.333307266235352, 4, 127, 135, 11.687472343444824, 5, 119, 128, 10.840554237365723, 6, 119, 118, 11.507664680480957, 1, 126, 120, 11.507664680480957, 2, 134, 127, 11.333307266235352, 3, 134, 135, 11.333307266235352, 4, 127, 134, 11.507664680480957, 5, 120, 129, 10.999974250793457, 6, 119, 118, 11.333307266235352, 1, 126, 120, 11.164153099060059, 2, 135, 127, 11.333307266235352, 3, 135, 133, 11.333307266235352, 4, 127, 135, 11.333307266235352, 5, 120, 127, 11.333307266235352, 6, 119, 119, 11.333307266235352, 1, 125, 120, 11.164153099060059, 2, 135, 128, 10.999974250793457, 3, 135, 134, 11.507664680480957, 4, 128, 135, 11.164153099060059, 5, 117, 127, 11.164153099060059, 6, 117, 118, 11.333307266235352, 1, 127, 116, 11.164153099060059, 2, 134, 127, 11.333307266235352, 3, 135, 136, 11.333307266235352, 4, 128, 135, 11.164153099060059, 5, 118, 128, 10.999974250793457, 6, 120, 120, 11.164153099060059, 1, 126, 118, 11.507664680480957, 2, 137, 127, 10.999974250793457, 3, 135, 134, 11.333307266235352, 4, 126, 136, 11.333307266235352, 5, 121, 128, 11.164153099060059, 6, 119, 119, 11.164153099060059, 1, 126, 120, 11.333307266235352, 2, 138, 127, 11.164153099060059, 3, 135, 133, 11.333307266235352, 4, 127, 136, 10.999974250793457, 5, 120, 128, 11.333307266235352, 6, 120, 119, 11.164153099060059, 1, 126, 119, 11.333307266235352, 2, 135, 126, 11.164153099060059, 3, 134, 135, 11.687472343444824, 4, 127, 132, 11.164153099060059, 5, 120, 128, 10.999974250793457, 6, 120, 120, 11.507664680480957, 1, 127, 118, 11.164153099060059, 2, 135, 128, 10.999974250793457, 3, 136, 134, 11.687472343444824, 4, 126, 134, 11.164153099060059, 5, 119, 128, 10.999974250793457, 6, 121, 120, 11.507664680480957, 1, 127, 119, 11.507664680480957, 2, 134, 128, 10.685688972473145, 3, 134, 134, 11.507664680480957, 4, 127, 134, 11.507664680480957, 5, 121, 128, 10.840554237365723, 6, 121, 122, 11.507664680480957, 1, 127, 121, 11.507664680480957, 2, 134, 127, 10.840554237365723, 3, 136, 134, 11.507664680480957, 4, 127, 134, 11.507664680480957, 5, 121, 128, 10.685688972473145, 6, 121, 120, 11.507664680480957, 1, 126, 120, 11.507664680480957, 2, 133, 128, 10.685688972473145, 3, 135, 135, 11.872987747192383, 4, 126, 135, 11.507664680480957, 5, 121, 127, 10.535186767578125, 6, 120, 120, 11.872987747192383, 1, 125, 120, 11.333307266235352, 2, 135, 128, 10.535186767578125, 3, 136, 135, 11.872987747192383, 4, 127, 133, 11.507664680480957, 5, 122, 129, 10.388864517211914, 6, 119, 119, 11.872987747192383, 1, 125, 121, 11.687472343444824, 2, 134, 127, 10.108084678649902, 3, 138, 138, 11.164153099060059, 4, 127, 140, 10.535186767578125, 5, 109, 127, 8.499979972839355, 6, 100, 100, 8.904741287231445, 1, 127, 89, 8.21976089477539, 2, 171, 128, 6.1818037033081055, 3, 187, 187, 5.666653633117676, 4, 127, 199, 4.426025390625, 5, 42, 128, 2.7499935626983643, 6, 31, 30, 1.9428526163101196, 1, 127, 16, 249.33273315429688, 6, 191, 126, 21.37137794494629, 1, 128, 27, 0.8529056906700134, 2, 238, 126, 1.1651062965393066, 3, 234, 235, 1.5172377824783325, 4, 127, 236, 0.3702961504459381, 5, 18, 128, -373.9991149902344, 4, 47, 87, 16.260831832885742, 5, 19, 128, -249.33273315429688, 4, 61, 67, 13.851819038391113, 5, 21, 129, 0.6964601874351501, 6, 17, 15, 0.8529056906700134, 1, 127, 14, 249.33273315429688, 6, 180, 105, 17.80948257446289, 1, 128, 21, 0.7276247143745422, 2, 239, 127, 0.6041988730430603, 3, 240, 239, -249.33273315429688, 2, 151, 204, 16.260831832885742, 3, 232, 233, 0.2340419888496399, 4, 127, 238, -35.61896514892578, 3, 34, 128, 16.99995994567871, 4, 127, 236, 0.23374946415424347, 5, 18, 128, -373.9991149902344, 4, 46, 89, 15.914856910705566, 5, 20, 129, -249.33273315429688, 4, 57, 75, 13.599967956542969, 5, 17, 128, -249.33273315429688, 4, 61, 64, 12.896520614624023, 5, 19, 129, -25.793041229248047, 4, 26, 24, 15.914856910705566, 5, 23, 128, -249.33273315429688, 4, 67, 66, 12.064488410949707, 5, 20, 128, -31.16659164428711, 4, 32, 30, 14.113173484802246, 5, 24, 128, -249.33273315429688, 4, 66, 67, 11.507664680480957, 5, 20, 128, -186.9995574951172, 4, 63, 64, 11.507664680480957, 5, 22, 128, -249.33273315429688, 4, 64, 66, 11.333307266235352, 5, 21, 127, -249.33273315429688, 4, 65, 65, 11.507664680480957, 5, 20, 127, -186.9995574951172, 4, 65, 65, 11.333307266235352, 5, 22, 128, -249.33273315429688, 4, 63, 67, 11.333307266235352, 5, 22, 128, -186.9995574951172, 4, 66, 66, 11.507664680480957, 5, 20, 128, -186.9995574951172, 4, 65, 65, 11.507664680480957, 5, 22, 127, -186.9995574951172, 4, 66, 66, 11.507664680480957, 5, 21, 127, -33.99991989135742, 4, 31, 32, 13.851819038391113, 5, 24, 128, -35.61896514892578, 4, 32, 32, 13.851819038391113, 5, 24, 128, -32.521663665771484, 4, 34, 33, 14.113173484802246, 5, 24, 128, -32.521663665771484, 4, 30, 29, 14.384581565856934, 5, 25, 128, -29.919931411743164, 4, 29, 30, 14.959965705871582, 5, 24, 127, -28.769163131713867, 4, 26, 26, 15.265270233154297, 5, 23, 128, -26.714223861694336, 4, 25, 26, 16.260831832885742, 5, 23, 128, -25.793041229248047, 4, 24, 24, 16.62218475341797, 5, 25, 128, -24.128976821899414, 4, 24, 22, 17.395307540893555, 5, 24, 127, -22.666614532470703, 4, 21, 20, 18.699954986572266, 5, 24, 128, -186.9995574951172, 4, 67, 66, 14.113173484802246, 5, 19, 129, 1.0840554237365723, 6, 30, 29, 3.354252338409424, 1, 128, 43, 4.533322811126709, 2, 200, 128, 5.7538323402404785, 3, 187, 185, 6.678555965423584, 4, 127, 181, 7.555537700653076, 5, 83, 128, 8.130415916442871, 6, 89, 89, 8.697653770446777, 1, 126, 94, 8.799979209899902, 2, 158, 127, 9.121930122375488, 3, 157, 155, 9.714262962341309, 4, 128, 151, 9.714262962341309, 5, 106, 127, 9.842082023620605, 6, 108, 108, 10.388864517211914, 1, 126, 110, 10.246551513671875, 2, 143, 127, 10.535186767578125, 3, 141, 140, 10.840554237365723, 4, 127, 140, 10.840554237365723, 5, 116, 127, 10.388864517211914, 6, 116, 116, 10.999974250793457, 1, 127, 116, 11.164153099060059, 2, 137, 128, 10.685688972473145, 3, 138, 138, 11.164153099060059, 4, 128, 135, 10.999974250793457, 5, 119, 128, 11.164153099060059, 6, 121, 121, 11.164153099060059, 1, 127, 119, 11.333307266235352, 2, 136, 127, 10.999974250793457, 3, 136, 135, 11.333307266235352, 4, 128, 136, 11.164153099060059, 5, 119, 128, 11.164153099060059, 6, 122, 121, 11.164153099060059, 1, 125, 120, 11.333307266235352, 2, 132, 127, 11.164153099060059, 3, 134, 134, 11.507664680480957, 4, 127, 135, 10.999974250793457, 5, 119, 127, 10.999974250793457, 6, 118, 117, 11.687472343444824, 1, 127, 120, 11.164153099060059, 2, 133, 127, 10.999974250793457, 3, 136, 135, 11.507664680480957, 4, 127, 136, 11.164153099060059, 5, 120, 128, 10.999974250793457, 6, 120, 120, 11.687472343444824, 1, 125, 121, 11.507664680480957, 2, 134, 127, 10.685688972473145, 3, 135, 134, 11.507664680480957, 4, 127, 134, 11.507664680480957, 5, 121, 129, 10.840554237365723, 6, 119, 120, 11.507664680480957, 1, 126, 121, 11.687472343444824, 2, 135, 127, 10.840554237365723, 3, 134, 134, 11.507664680480957, 4, 127, 135, 11.507664680480957, 5, 122, 128, 10.685688972473145, 6, 118, 118, 11.687472343444824, 1, 127, 120, 11.507664680480957, 2, 135, 128, 10.535186767578125, 3, 135, 134, 11.872987747192383, 4, 127, 131, 11.507664680480957, 5, 122, 128, 10.685688972473145, 6, 118, 119, 11.872987747192383, 1, 128, 122, 11.333307266235352, 2, 135, 126, 10.535186767578125, 3, 135, 135, 11.872987747192383, 4, 127, 134, 11.507664680480957, 5, 120, 128, 10.388864517211914, 6, 120, 120, 12.064488410949707, 1, 127, 118, 11.872987747192383, 2, 132, 127, 10.388864517211914, 3, 135, 135, 11.872987747192383, 4, 127, 134, 11.687472343444824, 5, 119, 129, 10.246551513671875, 6, 117, 117, 11.872987747192383, 1, 126, 120, 11.872987747192383, 2, 135, 128, 10.388864517211914, 3, 135, 134, 11.687472343444824, 4, 127, 134, 11.872987747192383, 5, 121, 128, 10.535186767578125, 6, 118, 117, 11.507664680480957, 1, 126, 118, 11.872987747192383, 2, 135, 127, 10.685688972473145, 3, 134, 134, 11.164153099060059, 4, 127, 135, 11.872987747192383, 5, 120, 128, 10.685688972473145, 6, 119, 119, 11.507664680480957, 1, 126, 119, 11.507664680480957, 2, 139, 127, 11.164153099060059, 3, 136, 135, 11.333307266235352, 4, 127, 136, 11.333307266235352, 5, 121, 129, 11.164153099060059, 6, 119, 119, 11.333307266235352, 1, 126, 121, 11.164153099060059, 2, 138, 128, 11.333307266235352, 3, 138, 138, 11.333307266235352, 4, 127, 135, 11.333307266235352, 5, 120, 129, 11.333307266235352, 6, 120, 121, 11.333307266235352, 1, 125, 119, 11.164153099060059, 2, 133, 127, 11.164153099060059, 3, 135, 136, 11.507664680480957, 4, 127, 134, 11.164153099060059, 5, 121, 130, 11.164153099060059, 6, 120, 119, 11.333307266235352, 1, 128, 117, 10.999974250793457, 2, 135, 127, 11.333307266235352, 3, 136, 135, 11.507664680480957, 4, 127, 135, 11.333307266235352, 5, 120, 127, 10.999974250793457, 6, 120, 119, 11.164153099060059, 1, 126, 119, 11.507664680480957, 2, 135, 126, 10.999974250793457, 3, 134, 133, 11.333307266235352, 4, 127, 134, 11.333307266235352, 5, 120, 128, 11.164153099060059, 6, 122, 121, 11.333307266235352, 1, 127, 120, 11.164153099060059, 2, 134, 127, 11.164153099060059, 3, 136, 137, 11.333307266235352, 4, 127, 135, 11.164153099060059, 5, 121, 128, 11.164153099060059, 6, 122, 120, 11.333307266235352, 1, 127, 120, 11.333307266235352, 2, 133, 127, 11.164153099060059, 3, 135, 133, 11.507664680480957, 4, 127, 132, 10.999974250793457, 5, 119, 128, 11.164153099060059, 6, 119, 117, 11.687472343444824, 1, 125, 121, 11.164153099060059, 2, 134, 127, 10.999974250793457, 3, 136, 135, 11.687472343444824, 4, 128, 134, 11.164153099060059, 5, 120, 128, 10.840554237365723, 6, 120, 121, 11.687472343444824, 1, 126, 121, 11.507664680480957, 2, 135, 127, 10.685688972473145, 3, 135, 133, 11.507664680480957, 4, 127, 133, 11.687472343444824, 5, 122, 128, 10.685688972473145, 6, 121, 121, 11.687472343444824, 1, 127, 121, 11.687472343444824, 2, 134, 127, 10.840554237365723, 3, 134, 133, 11.507664680480957, 4, 127, 134, 11.507664680480957, 5, 121, 128, 10.685688972473145, 6, 121, 121, 11.507664680480957, 1, 127, 118, 11.507664680480957, 2, 135, 127, 10.685688972473145, 3, 135, 135, 11.872987747192383, 4, 129, 131, 11.507664680480957, 5, 118, 127, 10.535186767578125, 6, 120, 119, 11.872987747192383, 1, 125, 121, 11.507664680480957, 2, 133, 127, 10.388864517211914, 3, 136, 137, 12.064488410949707, 4, 126, 136, 11.507664680480957, 5, 120, 127, 10.388864517211914, 6, 119, 118, 12.064488410949707, 1, 127, 119, 11.687472343444824, 2, 132, 127, 10.388864517211914, 3, 135, 136, 11.872987747192383, 4, 127, 135, 11.687472343444824, 5, 121, 128, 10.246551513671875, 6, 118, 118, 11.872987747192383, 1, 127, 116, 11.872987747192383, 2, 134, 126, 10.388864517211914, 3, 134, 133, 11.507664680480957, 4, 128, 134, 11.872987747192383, 5, 121, 128, 10.685688972473145, 6, 120, 119, 11.507664680480957, 1, 127, 117, 11.872987747192383, 2, 134, 127, 10.535186767578125, 3, 137, 136, 11.333307266235352, 4, 127, 136, 11.687472343444824, 5, 119, 126, 10.840554237365723, 6, 116, 118, 11.507664680480957, 1, 126, 120, 11.507664680480957, 2, 135, 127, 11.164153099060059, 3, 136, 137, 11.333307266235352, 4, 128, 134, 11.333307266235352, 5, 117, 128, 11.164153099060059, 6, 118, 119, 11.333307266235352, 1, 125, 120, 11.164153099060059, 2, 135, 128, 11.333307266235352, 3, 136, 137, 11.333307266235352, 4, 127, 135, 11.333307266235352, 5, 120, 129, 11.333307266235352, 6, 120, 120, 11.333307266235352, 1, 127, 118, 11.333307266235352, 2, 135, 127, 10.999974250793457, 3, 136, 134, 11.507664680480957, 4, 127, 137, 11.164153099060059, 5, 121, 130, 11.164153099060059, 6, 120, 118, 11.333307266235352, 1, 126, 120, 11.164153099060059, 2, 133, 125, 11.333307266235352, 3, 134, 133, 11.507664680480957, 4, 126, 135, 11.333307266235352, 5, 117, 127, 10.999974250793457, 6, 120, 122, 11.164153099060059, 1, 126, 118, 11.507664680480957, 2, 133, 127, 10.999974250793457, 3, 135, 133, 11.333307266235352, 4, 128, 135, 11.164153099060059, 5, 117, 127, 11.333307266235352, 6, 120, 120, 11.164153099060059, 1, 126, 118, 11.333307266235352, 2, 136, 127, 10.999974250793457, 3, 136, 134, 11.333307266235352, 4, 127, 137, 11.164153099060059, 5, 119, 127, 11.333307266235352, 6, 120, 120, 11.164153099060059, 1, 126, 119, 11.164153099060059, 2, 134, 126, 11.164153099060059, 3, 135, 134, 11.507664680480957, 4, 127, 133, 11.164153099060059, 5, 119, 129, 10.999974250793457, 6, 120, 121, 11.507664680480957, 1, 127, 120, 11.164153099060059, 2, 134, 127, 10.999974250793457, 3, 137, 136, 11.687472343444824, 4, 127, 135, 11.164153099060059, 5, 120, 127, 10.999974250793457, 6, 119, 119, 11.507664680480957, 1, 125, 120, 11.507664680480957, 2, 133, 127, 10.685688972473145, 3, 134, 136, 11.687472343444824, 4, 128, 134, 11.507664680480957, 5, 120, 128, 10.685688972473145, 6, 120, 120, 11.687472343444824, 1, 126, 121, 11.507664680480957, 2, 134, 128, 10.840554237365723, 3, 136, 135, 11.507664680480957, 4, 127, 134, 11.507664680480957, 5, 121, 128, 10.685688972473145, 6, 122, 122, 11.507664680480957, 1, 126, 119, 11.507664680480957, 2, 134, 127, 10.685688972473145, 3, 134, 133, 11.872987747192383, 4, 128, 134, 11.333307266235352, 5, 120, 127, 10.685688972473145, 6, 120, 121, 11.872987747192383, 1, 127, 119, 11.507664680480957, 2, 134, 128, 10.388864517211914, 3, 136, 136, 12.064488410949707, 4, 127, 136, 11.507664680480957, 5, 119, 127, 10.388864517211914, 6, 119, 119, 12.064488410949707, 1, 126, 121, 11.687472343444824, 2, 133, 127, 10.388864517211914, 3, 135, 134, 11.872987747192383, 4, 129, 134, 11.687472343444824, 5, 121, 129, 10.246551513671875, 6, 119, 118, 11.872987747192383, 1, 126, 117, 11.872987747192383, 2, 133, 127, 10.388864517211914, 3, 137, 136, 11.507664680480957, 4, 127, 135, 11.872987747192383, 5, 120, 128, 10.685688972473145, 6, 117, 119, 11.507664680480957, 1, 127, 117, 11.687472343444824, 2, 134, 127, 10.685688972473145, 3, 137, 135, 11.164153099060059, 4, 127, 136, 11.687472343444824, 5, 118, 128, 10.685688972473145, 6, 117, 117, 11.333307266235352, 1, 126, 120, 11.507664680480957, 2, 134, 127, 11.164153099060059, 3, 136, 134, 10.999974250793457, 4, 127, 136, 11.333307266235352, 5, 117, 129, 10.840554237365723, 6, 117, 117, 10.999974250793457, 1, 127, 118, 10.840554237365723, 2, 136, 127, 10.999974250793457, 3, 138, 137, 10.840554237365723, 4, 128, 140, 10.840554237365723, 5, 115, 128, 10.840554237365723, 6, 115, 114, 10.840554237365723, 1, 126, 113, 10.685688972473145, 2, 139, 128, 10.388864517211914, 3, 142, 142, 10.840554237365723, 4, 127, 142, 10.388864517211914, 5, 110, 126, 10.108084678649902, 6, 111, 110, 10.388864517211914, 1, 126, 111, 9.973310470581055, 2, 145, 127, 10.108084678649902, 3, 146, 145, 10.108084678649902, 4, 127, 148, 9.842082023620605, 5, 104, 127, 9.349977493286133, 6, 103, 103, 9.349977493286133, 1, 127, 101, 9.121930122375488, 2, 157, 128, 8.21976089477539, 3, 165, 162, 7.957428455352783, 4, 128, 172, 7.333316802978516, 5, 78, 128, 7.123793125152588, 6, 77, 77, 6.925909519195557, 1, 127, 75, 7.056586742401123, 2, 181, 127, 6.862370014190674, 3, 178, 179, 6.990638256072998, 4, 127, 180, 6.738722324371338, 5, 73, 129, 6.448260307312012, 6, 69, 69, 6.285699844360352, 1, 127, 69, 6.081286430358887, 2, 190, 127, 5.62404727935791, 3, 191, 192, 5.62404727935791, 4, 126, 195, 5.020122528076172, 5, 56, 128, 4.1787614822387695, 6, 45, 43, 3.7399914264678955, 1, 127, 39, 3.053054094314575, 2, 221, 126, 2.5355873107910156, 3, 224, 224, 2.1371378898620605, 4, 128, 231, 1.719536304473877, 5, 24, 127, -249.33273315429688, 4, 66, 67, 35.61896514892578, 5, 43, 128, -249.33273315429688, 4, 72, 78, 46.7498893737793, 5, 55, 127, 1.3550692796707153, 6, 20, 19, 1.2963573932647705, 1, 128, 19, 186.9995574951172, 6, 192, 126, 21.37137794494629, 1, 127, 27, 0.8404474854469299, 2, 240, 127, 0.1289207637310028, 3, 236, 236, -373.9991149902344, 2, 161, 205, 14.666633605957031, 3, 235, 235, -37.39990997314453, 2, 127, 221, 14.384581565856934, 3, 230, 231, -33.99991989135742, 2, 127, 222, 14.384581565856934, 3, 230, 230, -35.61896514892578, 2, 127, 221, 13.599967956542969, 3, 230, 231, -41.555458068847656, 2, 127, 218, 12.896520614624023, 3, 229, 229, -49.86655044555664, 2, 127, 213, 11.872987747192383, 3, 231, 231, -249.33273315429688, 2, 127, 190, 10.535186767578125, 3, 232, 232, -249.33273315429688, 2, 131, 193, 10.535186767578125, 3, 232, 232, -249.33273315429688, 2, 133, 192, 10.685688972473145, 3, 230, 231, -186.9995574951172, 2, 131, 193, 10.840554237365723, 3, 231, 231, -62.33318328857422, 2, 126, 210, 11.872987747192383, 3, 229, 230, -46.7498893737793, 2, 128, 215, 12.677935600280762, 3, 229, 229, -37.39990997314453, 2, 126, 220, 13.599967956542969, 3, 226, 228, -31.16659164428711, 2, 128, 226, 14.959965705871582, 3, 229, 230, -25.793041229248047, 2, 127, 229, 16.99995994567871, 3, 229, 229, -20.216169357299805, 2, 127, 236, 21.999948501586914, 3, 228, 229, 1.1282024383544922, 4, 127, 230, 2.4444386959075928, 5, 34, 127, 2.8769161701202393, 6, 37, 36, 3.684720516204834, 1, 127, 40, 3.777768850326538, 2, 212, 127, 3.545015573501587, 3, 211, 211, 3.7399914264678955, 4, 128, 213, 4.1787614822387695, 5, 48, 129, 4.298840522766113, 6, 52, 51, 5.342844486236572, 1, 126, 61, 5.540727615356445, 2, 190, 127, 5.381282329559326, 3, 190, 188, 6.23331880569458, 4, 127, 188, 6.338967800140381, 5, 71, 129, 6.131133079528809, 6, 71, 71, 7.192290782928467, 1, 127, 73, 7.192290782928467, 2, 175, 127, 6.862370014190674, 3, 175, 175, 8.311092376708984, 4, 127, 169, 8.311092376708984, 5, 89, 128, 7.711322784423828, 6, 89, 88, 9.349977493286133, 1, 127, 96, 9.589720726013184, 2, 153, 127, 8.597681045532227, 3, 153, 153, 10.246551513671875, 4, 127, 149, 10.388864517211914, 5, 110, 127, 9.121930122375488, 6, 108, 107, 10.999974250793457, 1, 125, 110, 10.999974250793457, 2, 141, 128, 9.842082023620605, 3, 141, 140, 10.999974250793457, 4, 127, 141, 11.333307266235352, 5, 119, 127, 10.246551513671875, 6, 117, 117, 11.333307266235352, 1, 126, 116, 11.507664680480957, 2, 136, 127, 10.388864517211914, 3, 138, 135, 11.164153099060059, 4, 127, 136, 11.687472343444824, 5, 119, 128, 10.685688972473145, 6, 119, 119, 11.333307266235352, 1, 125, 120, 11.507664680480957, 2, 136, 127, 11.164153099060059, 3, 137, 136, 11.333307266235352, 4, 126, 135, 11.333307266235352, 5, 120, 128, 11.164153099060059, 6, 118, 118, 11.164153099060059, 1, 127, 120, 11.164153099060059, 2, 134, 128, 11.333307266235352, 3, 136, 134, 11.333307266235352, 4, 127, 134, 11.333307266235352, 5, 118, 127, 11.333307266235352, 6, 120, 121, 11.507664680480957, 1, 127, 118, 11.164153099060059, 2, 134, 128, 10.999974250793457, 3, 136, 135, 11.507664680480957, 4, 128, 138, 11.333307266235352, 5, 119, 127, 10.999974250793457, 6, 120, 120, 11.333307266235352, 1, 126, 118, 11.164153099060059, 2, 135, 127, 11.333307266235352, 3, 137, 137, 11.507664680480957, 4, 127, 137, 11.333307266235352, 5, 121, 128, 10.999974250793457, 6, 120, 119, 11.164153099060059, 1, 127, 117, 11.507664680480957, 2, 136, 127, 10.999974250793457, 3, 136, 135, 11.333307266235352, 4, 127, 132, 11.164153099060059, 5, 119, 129, 11.333307266235352, 6, 118, 121, 11.164153099060059, 1, 127, 118, 11.333307266235352, 2, 135, 128, 11.164153099060059, 3, 136, 138, 11.333307266235352, 4, 128, 135, 11.164153099060059, 5, 119, 129, 11.333307266235352, 6, 119, 117, 11.333307266235352, 1, 126, 121, 11.333307266235352, 2, 134, 126, 11.164153099060059, 3, 135, 136, 11.507664680480957, 4, 126, 133, 11.164153099060059, 5, 119, 127, 10.999974250793457, 6, 120, 121, 11.507664680480957, 1, 127, 119, 11.333307266235352, 2, 132, 128, 10.999974250793457, 3, 135, 134, 11.507664680480957, 4, 127, 135, 11.164153099060059, 5, 121, 129, 10.999974250793457, 6, 121, 121, 11.507664680480957, 1, 127, 120, 11.507664680480957, 2, 134, 128, 10.840554237365723, 3, 134, 132, 11.507664680480957, 4, 127, 136, 11.507664680480957, 5, 120, 129, 10.840554237365723, 6, 120, 119, 11.687472343444824, 1, 127, 121, 11.507664680480957, 2, 133, 128, 10.840554237365723, 3, 135, 133, 11.507664680480957, 4, 128, 134, 11.507664680480957, 5, 120, 127, 10.685688972473145, 6, 120, 121, 11.687472343444824, 1, 125, 122, 11.507664680480957, 2, 132, 127, 10.535186767578125, 3, 136, 137, 11.872987747192383, 4, 126, 134, 11.507664680480957, 5, 119, 127, 10.685688972473145, 6, 119, 119, 11.872987747192383, 1, 127, 122, 11.333307266235352, 2, 135, 128, 10.535186767578125, 3, 136, 135, 12.064488410949707, 4, 127, 133, 11.507664680480957, 5, 123, 128, 10.388864517211914, 6, 118, 117, 11.872987747192383, 1, 128, 118, 11.872987747192383, 2, 133, 128, 10.388864517211914, 3, 135, 134, 11.872987747192383, 4, 127, 135, 11.872987747192383, 5, 118, 128, 10.108084678649902, 6, 118, 118, 11.872987747192383, 1, 126, 119, 11.872987747192383, 2, 132, 127, 10.388864517211914, 3, 136, 133, 11.687472343444824, 4, 127, 135, 11.872987747192383, 5, 120, 128, 10.685688972473145, 6, 120, 119, 11.507664680480957, 1, 128, 117, 11.872987747192383, 2, 134, 127, 10.535186767578125, 3, 137, 136, 11.333307266235352, 4, 128, 135, 11.687472343444824, 5, 119, 126, 10.840554237365723, 6, 115, 117, 11.507664680480957, 1, 127, 119, 11.507664680480957, 2, 135, 127, 11.164153099060059, 3, 135, 134, 11.333307266235352, 4, 128, 133, 11.507664680480957, 5, 118, 128, 11.164153099060059, 6, 120, 119, 11.164153099060059, 1, 127, 120, 11.164153099060059, 2, 134, 126, 11.333307266235352, 3, 136, 135, 11.333307266235352, 4, 128, 134, 11.333307266235352, 5, 120, 128, 11.333307266235352, 6, 120, 121, 11.507664680480957, 1, 128, 117, 11.164153099060059, 2, 136, 127, 10.999974250793457, 3, 137, 136, 11.687472343444824, 4, 127, 134, 11.164153099060059, 5, 121, 128, 11.164153099060059, 6, 118, 118, 11.333307266235352, 1, 127, 119, 11.164153099060059, 2, 135, 127, 11.333307266235352, 3, 135, 133, 11.507664680480957, 4, 128, 135, 11.333307266235352, 5, 121, 129, 10.999974250793457, 6, 121, 121, 11.164153099060059, 1, 127, 117, 11.507664680480957, 2, 135, 128, 10.999974250793457, 3, 135, 135, 11.333307266235352, 4, 127, 135, 11.333307266235352, 5, 119, 128, 11.333307266235352, 6, 120, 120, 11.333307266235352, 1, 126, 121, 11.333307266235352, 2, 135, 127, 11.164153099060059, 3, 135, 134, 11.333307266235352, 4, 128, 133, 11.164153099060059, 5, 121, 128, 11.333307266235352, 6, 119, 120, 11.164153099060059, 1, 127, 119, 11.333307266235352, 2, 133, 126, 11.164153099060059, 3, 135, 135, 11.507664680480957, 4, 127, 132, 11.164153099060059, 5, 119, 128, 10.999974250793457, 6, 120, 120, 11.507664680480957, 1, 128, 119, 11.333307266235352, 2, 133, 127, 10.999974250793457, 3, 136, 134, 11.687472343444824, 4, 128, 134, 11.333307266235352, 5, 121, 128, 10.999974250793457, 6, 120, 121, 11.687472343444824, 1, 126, 118, 11.333307266235352, 2, 134, 127, 10.840554237365723, 3, 133, 132, 11.507664680480957, 4, 127, 135, 11.507664680480957, 5, 120, 127, 10.840554237365723, 6, 121, 120, 11.507664680480957, 1, 128, 119, 11.507664680480957, 2, 134, 126, 10.840554237365723, 3, 136, 133, 11.507664680480957, 4, 128, 135, 11.507664680480957, 5, 120, 128, 10.685688972473145, 6, 120, 121, 11.687472343444824, 1, 126, 120, 11.507664680480957, 2, 133, 126, 10.685688972473145, 3, 135, 135, 11.872987747192383, 4, 127, 134, 11.507664680480957, 5, 122, 129, 10.685688972473145, 6, 117, 118, 11.872987747192383, 1, 126, 120, 11.507664680480957, 2, 133, 126, 10.535186767578125, 3, 136, 137, 11.872987747192383, 4, 128, 133, 11.507664680480957, 5, 123, 128, 10.388864517211914, 6, 117, 115, 11.872987747192383, 1, 128, 119, 11.872987747192383, 2, 135, 127, 10.388864517211914, 3, 138, 136, 11.872987747192383, 4, 127, 134, 11.687472343444824, 5, 121, 128, 10.246551513671875, 6, 119, 120, 11.872987747192383, 1, 126, 118, 11.872987747192383, 2, 133, 127, 10.388864517211914, 3, 137, 135, 11.507664680480957, 4, 127, 136, 11.872987747192383, 5, 118, 129, 10.685688972473145, 6, 119, 118, 11.507664680480957, 1, 127, 117, 11.687472343444824, 2, 135, 128, 10.685688972473145, 3, 137, 137, 11.333307266235352, 4, 127, 137, 11.687472343444824, 5, 118, 126, 10.840554237365723, 6, 117, 116, 11.507664680480957, 1, 125, 119, 11.507664680480957, 2, 135, 126, 11.333307266235352, 3, 135, 134, 11.333307266235352, 4, 127, 133, 11.507664680480957, 5, 118, 129, 11.164153099060059, 6, 120, 121, 11.333307266235352, 1, 127, 119, 11.164153099060059, 2, 138, 127, 11.333307266235352, 3, 135, 133, 11.164153099060059, 4, 127, 136, 11.507664680480957, 5, 118, 128, 11.333307266235352, 6, 120, 119, 11.507664680480957, 1, 126, 119, 11.164153099060059, 2, 135, 127, 11.164153099060059, 3, 135, 133, 11.507664680480957, 4, 128, 137, 11.164153099060059, 5, 119, 129, 11.164153099060059, 6, 119, 120, 11.333307266235352, 1, 126, 118, 11.164153099060059, 2, 135, 127, 11.333307266235352, 3, 134, 134, 11.333307266235352, 4, 128, 135, 11.333307266235352, 5, 117, 128, 10.999974250793457, 6, 119, 119, 11.164153099060059, 1, 125, 118, 11.507664680480957, 2, 134, 127, 10.999974250793457, 3, 135, 134, 11.333307266235352, 4, 127, 136, 11.333307266235352, 5, 119, 129, 11.164153099060059, 6, 121, 121, 11.164153099060059, 1, 126, 121, 11.333307266235352, 2, 136, 128, 11.164153099060059, 3, 134, 134, 11.333307266235352, 4, 128, 133, 11.164153099060059, 5, 116, 126, 11.333307266235352, 6, 121, 122, 11.164153099060059, 1, 126, 121, 11.333307266235352, 2, 133, 127, 11.164153099060059, 3, 136, 136, 11.687472343444824, 4, 126, 135, 10.999974250793457, 5, 120, 128, 11.164153099060059, 6, 119, 119, 11.687472343444824, 1, 127, 119, 11.164153099060059, 2, 133, 127, 10.999974250793457, 3, 136, 135, 11.687472343444824, 4, 127, 136, 11.164153099060059, 5, 121, 128, 10.840554237365723, 6, 121, 120, 11.687472343444824, 1, 127, 119, 11.333307266235352, 2, 133, 128, 10.840554237365723, 3, 135, 136, 11.507664680480957, 4, 128, 134, 11.507664680480957, 5, 121, 127, 10.840554237365723, 6, 120, 120, 11.507664680480957, 1, 127, 120, 11.507664680480957, 2, 133, 127, 10.840554237365723, 3, 134, 134, 11.507664680480957, 4, 127, 136, 11.507664680480957, 5, 118, 127, 10.685688972473145, 6, 119, 120, 11.687472343444824, 1, 126, 121, 11.507664680480957, 2, 133, 127, 10.535186767578125, 3, 135, 134, 11.872987747192383, 4, 127, 131, 11.507664680480957, 5, 121, 127, 10.685688972473145, 6, 119, 119, 11.872987747192383, 1, 127, 120, 11.333307266235352, 2, 134, 128, 10.535186767578125, 3, 137, 136, 12.064488410949707, 4, 127, 133, 11.507664680480957, 5, 123, 129, 10.246551513671875, 6, 118, 118, 12.064488410949707, 1, 127, 118, 11.687472343444824, 2, 133, 127, 10.388864517211914, 3, 137, 135, 11.872987747192383, 4, 128, 135, 11.872987747192383, 5, 122, 127, 10.108084678649902, 6, 120, 120, 11.872987747192383, 1, 127, 120, 11.872987747192383, 2, 132, 127, 10.388864517211914, 3, 133, 133, 11.507664680480957, 4, 127, 132, 11.687472343444824, 5, 125, 127, 10.535186767578125, 6, 125, 124, 11.333307266235352, 1, 126, 125, 11.507664680480957, 2, 129, 128, 10.108084678649902, 3, 130, 127, 10.685688972473145, 4, 127, 129, 10.999974250793457, 5, 127, 128, 10.108084678649902, 6, 125, 125, 10.685688972473145, 1, 127, 124, 10.685688972473145, 2, 128, 127, 10.246551513671875, 3, 129, 127, 10.246551513671875, 4, 127, 127, 10.246551513671875, 5, 125, 128, 9.973310470581055, 6, 127, 125, 9.973310470581055, 1, 126, 125, 9.842082023620605, 2, 128, 127, 9.714262962341309, 3, 130, 127, 9.589720726013184, 4, 127, 129, 9.589720726013184, 5, 127, 129, 9.349977493286133, 6, 127, 126, 9.468331336975098, 1, 126, 126, 9.0120267868042, 2, 128, 128, 8.799979209899902, 3, 129, 130, 9.121930122375488, 4, 127, 127, 8.697653770446777, 5, 125, 128, 8.404475212097168, 6, 127, 126, 8.499979972839355, 1, 126, 125, 8.21976089477539, 2, 126, 127, 8.21976089477539, 3, 129, 128, 8.042991638183594, 4, 127, 129, 7.957428455352783, 5, 126, 128, 7.479982852935791, 6, 127, 127, 7.479982852935791, 1, 126, 127, 7.479982852935791, 2, 127, 128, 6.990638256072998, 3, 128, 128, 7.056586742401123, 4, 127, 126, 6.799983978271484, 5, 125, 127, 6.619453430175781, 6, 127, 128, 6.448260307312012, 1, 126, 126, 6.285699844360352, 2, 127, 127, 5.936493873596191, 3, 129, 128, 5.843736171722412, 4, 126, 127, 5.540727615356445, 5, 126, 128, 5.342844486236572, 6, 128, 128, 5.088423252105713, 1, 128, 127, 4.857131481170654, 2, 128, 127, 4.479031085968018, 3, 127, 127, 4.298840522766113, 4, 127, 128, 3.8958239555358887, 5, 128, 127, 3.4469964504241943, 6, 128, 126, 3.2380876541137695, 1, 128, 127, 2.7101385593414307, 2, 127, 127, 2.0893807411193848, 3, 127, 127, 1.4724375009536743, 4, 126, 128]
time = [0.0, 0.10493016242980957, 0.1669301986694336, 0.21140003204345703, 0.24919414520263672, 0.2858271598815918, 0.3172171115875244, 0.3469521999359131, 0.3781089782714844, 0.4082620143890381, 0.4372429847717285, 0.4685831069946289, 0.49957704544067383, 0.5300161838531494, 0.5634970664978027, 0.597318172454834, 0.6313309669494629, 0.6694910526275635, 0.7099010944366455, 0.75760817527771, 0.8232619762420654, 2.275182008743286, 2.3819780349731445, 2.440704107284546, 2.487790107727051, 2.530771017074585, 2.567923069000244, 2.60315203666687, 2.637533187866211, 2.6686580181121826, 2.699817180633545, 2.7316250801086426, 2.761850118637085, 2.792992115020752, 2.8248331546783447, 2.8549461364746094, 2.8853821754455566, 2.917971134185791, 2.9486911296844482, 2.9801530838012695, 3.014700174331665, 3.047725200653076, 3.0815911293029785, 3.1197052001953125, 3.1568210124969482, 3.19608998298645, 3.2428231239318848, 3.2922041416168213, 3.3784661293029785, 16.473464965820312, 16.489785194396973, 16.50274419784546, 16.514647006988525, 16.52399206161499, 16.53292417526245, 16.54216718673706, 16.549671173095703, 16.557172060012817, 16.56529402732849, 16.57219409942627, 16.57903504371643, 16.5866801738739, 16.593319177627563, 16.600004196166992, 16.607530117034912, 16.613919019699097, 16.620465993881226, 16.62783408164978, 16.634363174438477, 16.64078998565674, 16.647961139678955, 16.654486179351807, 16.660871028900146, 16.667940139770508, 16.674477100372314, 16.680912971496582, 16.687883138656616, 16.694404125213623, 16.700935125350952, 16.707621097564697, 16.71429204940796, 16.720893144607544, 16.72761297225952, 16.734284162521362, 16.741044998168945, 16.74771809577942, 16.75438618659973, 16.760998964309692, 16.767556190490723, 16.77429509162903, 16.781023025512695, 16.78774118423462, 16.794239044189453, 16.800958156585693, 16.807698011398315, 16.814126014709473, 16.821038007736206, 16.827632188796997, 16.834115028381348, 16.840818166732788, 16.847615003585815, 16.854290008544922, 16.860687017440796, 16.86750316619873, 16.874140977859497, 16.88084602355957, 16.88737916946411, 16.894105195999146, 16.900686025619507, 16.907426118850708, 16.914056062698364, 16.92080307006836, 16.92742419242859, 16.934121131896973, 16.940762996673584, 16.947484016418457, 16.95401096343994, 16.960803985595703, 16.967535972595215, 16.974034070968628, 16.980846166610718, 16.987601041793823, 16.99417805671692, 17.000914096832275, 17.00771999359131, 17.014191150665283, 17.02071213722229, 17.027695178985596, 17.034170150756836, 17.04053807258606, 17.04746699333191, 17.053965091705322, 17.060444116592407, 17.06736707687378, 17.074092149734497, 17.080615997314453, 17.087430000305176, 17.093849182128906, 17.10037899017334, 17.107429027557373, 17.11377501487732, 17.120301008224487, 17.127346992492676, 17.133697986602783, 17.140223026275635, 17.14744806289673, 17.15386199951172, 17.160232067108154, 17.167487144470215, 17.173870086669922, 17.18023419380188, 17.187434196472168, 17.193632125854492, 17.200109004974365, 17.207486152648926, 17.213667154312134, 17.22005796432495, 17.227308988571167, 17.23379111289978, 17.2400381565094, 17.247184991836548, 17.25369119644165, 17.26001501083374, 17.266961097717285, 17.27366614341736, 17.28014302253723, 17.287134170532227, 17.293670177459717, 17.30000901222229, 17.306761026382446, 17.313431978225708, 17.319969177246094, 17.326722145080566, 17.333352088928223, 17.340049982070923, 17.34674596786499, 17.35342001914978, 17.360018968582153, 17.36674404144287, 17.373303174972534, 17.380041122436523, 17.386789083480835, 17.39332413673401, 17.400009155273438, 17.40666103363037, 17.41338610649109, 17.42010807991028, 17.42676305770874, 17.433366060256958, 17.43998408317566, 17.446810007095337, 17.453536987304688, 17.460084199905396, 17.466965198516846, 17.473389148712158, 17.48026418685913, 17.486963033676147, 17.493637084960938, 17.500295162200928, 17.506883144378662, 17.513580083847046, 17.520305156707764, 17.526900053024292, 17.533658027648926, 17.54027509689331, 17.546993017196655, 17.55357003211975, 17.560288190841675, 17.567196130752563, 17.573543071746826, 17.580214977264404, 17.5871901512146, 17.5936381816864, 17.600280046463013, 17.607182025909424, 17.61369013786316, 17.620084047317505, 17.627094984054565, 17.63366413116455, 17.640189170837402, 17.64711308479309, 17.65351414680481, 17.6601140499115, 17.667060136795044, 17.6734881401062, 17.680111169815063, 17.687056064605713, 17.693456172943115, 17.700043201446533, 17.70713520050049, 17.713370084762573, 17.719842195510864, 17.726885080337524, 17.73320508003235, 17.739799976348877, 17.746912002563477, 17.75319814682007, 17.759741067886353, 17.766980171203613, 17.773367166519165, 17.77965998649597, 17.786834001541138, 17.793231964111328, 17.799633026123047, 17.807008981704712, 17.81330704689026, 17.81962299346924, 17.82684302330017, 17.833314180374146, 17.839663982391357, 17.846760034561157, 17.853109121322632, 17.85955810546875, 17.866641998291016, 17.873290061950684, 17.87957501411438, 17.88655400276184, 17.893190145492554, 17.89970898628235, 17.906386137008667, 17.912933111190796, 17.919406175613403, 17.92615818977356, 17.932828187942505, 17.93952202796936, 17.946096181869507, 17.952759981155396, 17.95939803123474, 17.966081142425537, 17.972557067871094, 17.979385137557983, 17.98618507385254, 17.99249815940857, 17.99941396713257, 18.00610113143921, 18.01256012916565, 18.019245147705078, 18.025878190994263, 18.032453060150146, 18.039108991622925, 18.046037197113037, 18.052584171295166, 18.059277057647705, 18.066087007522583, 18.07253098487854, 18.079177141189575, 18.08604907989502, 18.092684984207153, 18.099186182022095, 18.10584807395935, 18.112500190734863, 18.11927819252014, 18.125851154327393, 18.132529973983765, 18.139209985733032, 18.1459641456604, 18.152449131011963, 18.159198999404907, 18.165975093841553, 18.1724750995636, 18.1791570186615, 18.18609619140625, 18.192381143569946, 18.199303150177002, 18.206003189086914, 18.212568998336792, 18.219156980514526, 18.226063013076782, 18.232542037963867, 18.239070177078247, 18.245858192443848, 18.25234603881836, 18.2588210105896, 18.265793085098267, 18.27229404449463, 18.278818130493164, 18.285794973373413, 18.292464017868042, 18.298959970474243, 18.30584716796875, 18.31231117248535, 18.318833112716675, 18.325867176055908, 18.332000970840454, 18.338581085205078, 18.345831155776978, 18.352030038833618, 18.35853099822998, 18.365710973739624, 18.371968984603882, 18.37842106819153, 18.385619163513184, 18.391913175582886, 18.398386001586914, 18.405769109725952, 18.412108182907104, 18.41820502281189, 18.425453186035156, 18.4319269657135, 18.438277006149292, 18.445324182510376, 18.4518461227417, 18.458177089691162, 18.465252161026, 18.47189497947693, 18.478276014328003, 18.485252141952515, 18.491958141326904, 18.498435974121094, 18.50514006614685, 18.51160502433777, 18.518171072006226, 18.524906158447266, 18.531543970108032, 18.53825306892395, 18.544856071472168, 18.55158305168152, 18.558154106140137, 18.564828157424927, 18.57135796546936, 18.57802700996399, 18.58487606048584, 18.591297149658203, 18.598015069961548, 18.604870080947876, 18.611425161361694, 18.618200063705444, 18.6248140335083, 18.631417989730835, 18.638025045394897, 18.644737005233765, 18.6515371799469, 18.658087968826294, 18.66477918624878, 18.671507120132446, 18.67820715904236, 18.68474507331848, 18.691400051116943, 18.69796109199524, 18.704734086990356, 18.71142315864563, 18.71804714202881, 18.724847078323364, 18.731544971466064, 18.73817014694214, 18.74477219581604, 18.751298189163208, 18.758056163787842, 18.764852046966553, 18.771324157714844, 18.777996063232422, 18.78482413291931, 18.7913019657135, 18.798042058944702, 18.804994106292725, 18.81135606765747, 18.817991018295288, 18.82499408721924, 18.831459045410156, 18.83801817893982, 18.844873189926147, 18.851310968399048, 18.857959985733032, 18.8648681640625, 18.871256113052368, 18.877883195877075, 18.884865045547485, 18.891332149505615, 18.897839069366455, 18.90488910675049, 18.911060094833374, 18.917566061019897, 18.924658060073853, 18.931085109710693, 18.93764019012451, 18.9448561668396, 18.95085597038269, 18.95741605758667, 18.96463108062744, 18.970901012420654, 18.97727608680725, 18.984469175338745, 18.990838050842285, 18.997210025787354, 19.00458812713623, 19.011027097702026, 19.017218112945557, 19.024465084075928, 19.03091812133789, 19.037281036376953, 19.04432702064514, 19.05085015296936, 19.057258129119873, 19.064373016357422, 19.07097101211548, 19.077367067337036, 19.084185123443604, 19.090835094451904, 19.097368001937866, 19.104019165039062, 19.110661029815674, 19.117213010787964, 19.123959064483643, 19.130431175231934, 19.137127161026, 19.14379906654358, 19.15047597885132, 19.156978130340576, 19.16363215446472, 19.170175075531006, 19.176900148391724, 19.183667182922363, 19.190152168273926, 19.196842193603516, 19.203582048416138, 19.21020197868347, 19.216883182525635, 19.223679065704346, 19.230086088180542, 19.23677706718445, 19.243614196777344, 19.250166177749634, 19.25675106048584, 19.263554096221924, 19.270105123519897, 19.276893138885498, 19.283364057540894, 19.29018998146057, 19.2966570854187, 19.303361177444458, 19.310014009475708, 19.316835165023804, 19.323459148406982, 19.330039024353027, 19.336610078811646, 19.343485116958618, 19.34981107711792, 19.356564044952393, 19.363306045532227, 19.3698570728302, 19.376532077789307, 19.383326053619385, 19.389832019805908, 19.39650297164917, 19.40333318710327, 19.40977716445923, 19.416508197784424, 19.42327308654785, 19.42977809906006, 19.436475038528442, 19.443397045135498, 19.44995903968811, 19.456391096115112, 19.463335037231445, 19.469884157180786, 19.47639012336731, 19.483342170715332, 19.489813089370728, 19.496317148208618, 19.50323510169983, 19.509658098220825, 19.516189098358154, 19.52325201034546, 19.52956509590149, 19.53610897064209, 19.54326105117798, 19.549517154693604, 19.55603313446045, 19.563261032104492, 19.569355964660645, 19.575780153274536, 19.582942008972168, 19.58930206298828, 19.595649003982544, 19.603032112121582, 19.60937809944153, 19.615663051605225, 19.62292504310608, 19.629369020462036, 19.6357901096344, 19.64287304878235, 19.649237155914307, 19.655595064163208, 19.66278314590454, 19.669413089752197, 19.67578411102295, 19.682636976242065, 19.68928813934326, 19.695765018463135, 19.702439069747925, 19.709091186523438, 19.715635061264038, 19.722373008728027, 19.729010105133057, 19.73573613166809, 19.742343187332153, 19.748884201049805, 19.755619049072266, 19.762228965759277, 19.76869511604309, 19.775330066680908, 19.782158136367798, 19.788657188415527, 19.79538917541504, 19.802139043807983, 19.808703184127808, 19.815425157546997, 19.822077989578247, 19.8288471698761, 19.835363149642944, 19.84227204322815, 19.84881615638733, 19.855513095855713, 19.86232304573059, 19.868966102600098, 19.875550985336304, 19.8822660446167, 19.889018058776855, 19.895461082458496, 19.902167081832886, 19.908790111541748, 19.915510177612305, 19.922118186950684, 19.928858995437622, 19.93561315536499, 19.942362070083618, 19.948763132095337, 19.955501079559326, 19.962414026260376, 19.968959093093872, 19.97561001777649, 19.98223114013672, 19.988702058792114, 19.9954571723938, 20.002252101898193, 20.008726119995117, 20.015273094177246, 20.022189140319824, 20.028774976730347, 20.035263061523438, 20.042212963104248, 20.048696041107178, 20.055272102355957, 20.06221604347229, 20.06874108314514, 20.07523512840271, 20.08221197128296, 20.088685989379883, 20.095194101333618, 20.102213144302368, 20.108543157577515, 20.11495804786682, 20.122114181518555, 20.128437995910645, 20.1349880695343, 20.142157077789307, 20.148261070251465, 20.15488600730896, 20.16214609146118, 20.168418169021606, 20.174812078475952, 20.182082176208496, 20.188778162002563, 20.195959091186523, 20.204859018325806, 20.213109016418457, 20.222315073013306, 20.234438180923462, 20.247586965560913, 20.264418125152588, 20.291840076446533, 20.330278158187866, 20.330559968948364, 20.3340060710907, 20.421730041503906, 20.486013174057007, 20.535295963287354, 20.737367153167725, 20.73763418197632, 20.742032051086426, 20.742459058761597, 20.747721195220947, 20.855236053466797, 20.942782163619995, 20.943231105804443, 20.947326183319092, 21.050291061401367, 21.173983097076416, 21.174394130706787, 21.17886209487915, 21.498610973358154, 21.500508069992065, 21.505168199539185, 21.825114965438843, 21.82536005973816, 21.829878091812134, 21.830310106277466, 21.835678100585938, 21.836109161376953, 21.841962099075317, 21.844715118408203, 21.8495671749115, 21.849788188934326, 21.856091022491455, 21.858455181121826, 21.86359214782715, 21.86399006843567, 21.870423078536987, 21.870866060256958, 21.877283096313477, 21.877684116363525, 21.884226083755493, 21.88460898399353, 21.89118218421936, 21.891585111618042, 21.898240089416504, 21.898509979248047, 21.905163049697876, 21.90543508529663, 21.911911964416504, 21.912386178970337, 21.91878318786621, 21.91923999786377, 21.9256591796875, 21.92784810066223, 21.93329906463623, 21.935575008392334, 21.940848112106323, 21.943099975585938, 21.94852614402771, 21.950951099395752, 21.956030130386353, 21.95842719078064, 21.963376998901367, 21.966230154037476, 21.971024990081787, 21.973701000213623, 21.978382110595703, 21.981301069259644, 21.9857439994812, 21.988850116729736, 21.99312400817871, 21.9963800907135, 22.000434160232544, 22.000904083251953, 22.00618004798889, 22.0752010345459, 22.097687005996704, 22.114140033721924, 22.12711501121521, 22.13842010498047, 22.14823007583618, 22.157495975494385, 22.165961980819702, 22.174537181854248, 22.182789087295532, 22.190463066101074, 22.19818902015686, 22.205727100372314, 22.213021993637085, 22.220311164855957, 22.227537155151367, 22.234513998031616, 22.241413116455078, 22.248516082763672, 22.2552170753479, 22.262092113494873, 22.269071102142334, 22.27577304840088, 22.282360076904297, 22.28913402557373, 22.295786142349243, 22.30245804786682, 22.30920910835266, 22.315852165222168, 22.322575092315674, 22.329182147979736, 22.335941076278687, 22.34254813194275, 22.34940218925476, 22.355957984924316, 22.362653017044067, 22.36933398246765, 22.375962018966675, 22.382611989974976, 22.389398097991943, 22.395836114883423, 22.40243411064148, 22.40922999382019, 22.415699005126953, 22.422204971313477, 22.42925000190735, 22.43573808670044, 22.442239999771118, 22.449167013168335, 22.455636978149414, 22.462112188339233, 22.469017028808594, 22.47551417350769, 22.482046127319336, 22.48883605003357, 22.495265007019043, 22.50183415412903, 22.508828163146973, 22.515130043029785, 22.52160120010376, 22.52860403060913, 22.535094022750854, 22.541543006896973, 22.548721075057983, 22.555042028427124, 22.561549186706543, 22.56864619255066, 22.574926137924194, 22.581395149230957, 22.588531017303467, 22.59488797187805, 22.601142168045044, 22.60851001739502, 22.614968061447144, 22.621172189712524, 22.62839102745056, 22.63484811782837, 22.641144037246704, 22.648187160491943, 22.65469217300415, 22.660998106002808, 22.668068170547485, 22.674663066864014, 22.6810200214386, 22.68796420097351, 22.69438409805298, 22.700839042663574, 22.70748996734619, 22.714157104492188, 22.720699071884155, 22.727395057678223, 22.734049081802368, 22.74080514907837, 22.747449159622192, 22.754091024398804, 22.76080298423767, 22.76729917526245, 22.773985147476196, 22.780588150024414, 22.78743815422058, 22.79386305809021, 22.800515174865723, 22.807363986968994, 22.813964128494263, 22.820728063583374, 22.82718300819397, 22.833858013153076, 22.840415000915527, 22.847195148468018, 22.853737115859985, 22.860392093658447, 22.86719298362732, 22.873795986175537, 22.880462169647217, 22.887399196624756, 22.89364504814148, 22.900261163711548, 22.906947135925293, 22.9135639667511, 22.920351028442383, 22.926932096481323, 22.933610200881958, 22.940250158309937, 22.946962118148804, 22.953463077545166, 22.9602530002594, 22.96706509590149, 22.97364115715027, 22.98034405708313, 22.987008094787598, 22.993585109710693, 23.00026297569275, 23.00706696510315, 23.01340913772583, 23.019925117492676, 23.026904106140137, 23.033349990844727, 23.03988218307495, 23.046889066696167, 23.053393125534058, 23.05971598625183, 23.066763162612915, 23.073266983032227, 23.079634189605713, 23.08660912513733, 23.09318709373474, 23.0995671749115, 23.106585025787354, 23.11286997795105, 23.11938500404358, 23.12641215324402, 23.132780075073242, 23.13927698135376, 23.146449089050293, 23.1526939868927, 23.15919303894043, 23.166608095169067, 23.17278814315796, 23.179229021072388, 23.18642807006836, 23.19269299507141, 23.19898009300232, 23.206472158432007, 23.212749004364014, 23.218924045562744, 23.226246118545532, 23.23269510269165, 23.238922119140625, 23.24604606628418, 23.25254201889038, 23.258805990219116, 23.26599097251892, 23.27254605293274, 23.278966188430786, 23.28584599494934, 23.29222297668457, 23.29886817932129, 23.305540084838867, 23.312035083770752, 23.31856107711792, 23.325261116027832, 23.33190417289734, 23.33862614631653, 23.34521508216858, 23.351868152618408, 23.35847806930542, 23.365081071853638, 23.37169098854065, 23.37847900390625, 23.385250091552734, 23.39170002937317, 23.39840006828308, 23.4051251411438, 23.411609172821045, 23.418419122695923, 23.425018072128296, 23.431392192840576, 23.438167095184326, 23.444998025894165, 23.451637983322144, 23.458168983459473, 23.46497106552124, 23.47162103652954, 23.478113174438477, 23.48489809036255, 23.491594076156616, 23.498192071914673, 23.504971981048584, 23.511461973190308, 23.518160104751587, 23.524724006652832, 23.531414031982422, 23.53803300857544, 23.544777154922485, 23.551265001296997, 23.558068990707397, 23.565025091171265, 23.57134699821472, 23.578041076660156, 23.584935188293457, 23.591361045837402, 23.598067045211792, 23.604948043823242, 23.611345052719116, 23.617849111557007, 23.62483811378479, 23.63118815422058, 23.637680053710938, 23.64454698562622, 23.6512131690979, 23.657564163208008, 23.664425134658813, 23.671115159988403, 23.677616119384766, 23.684489965438843, 23.691050052642822, 23.697543144226074, 23.704440116882324, 23.71089220046997, 23.717437982559204, 23.72431516647339, 23.730624198913574, 23.737149000167847, 23.744312047958374, 23.750569105148315, 23.757090091705322, 23.764342069625854, 23.770567178726196, 23.777108192443848, 23.78424310684204, 23.790592193603516, 23.796955108642578, 23.80432105064392, 23.810621976852417, 23.816795110702515, 23.824113130569458, 23.830589056015015, 23.83687400817871, 23.843969106674194, 23.850418090820312, 23.856781005859375, 23.863816022872925, 23.87039613723755, 23.876896142959595, 23.883805990219116, 23.890493154525757, 23.897047996520996, 23.90366506576538, 23.9103901386261, 23.917031049728394, 23.923912048339844, 23.93071413040161, 23.937580108642578, 23.944399118423462, 23.951316118240356, 23.958192110061646, 23.96514105796814, 23.97203302383423, 23.979226112365723, 23.986430168151855, 23.993208169937134, 24.0006320476532, 24.00796604156494, 24.01521396636963, 24.022664070129395, 24.030097007751465, 24.03754210472107, 24.045138120651245, 24.05316400527954, 24.061190128326416, 24.06940507888794, 24.078516006469727, 24.087964057922363, 24.097920179367065, 24.108620166778564, 24.119343042373657, 24.130038022994995, 24.140789031982422, 24.15159296989441, 24.16263508796692, 24.174170970916748, 24.186140060424805, 24.198518991470337, 24.211878061294556, 24.225172996520996, 24.24007797241211, 24.258012056350708, 24.27797508239746, 24.302417993545532, 24.332030057907104, 24.3668429851532, 24.410309076309204, 24.410803079605103, 24.412779092788696, 24.413182020187378, 24.414729118347168, 24.470039129257202, 24.527721166610718, 24.528069019317627, 24.531496047973633, 24.62055516242981, 25.200754165649414, 25.201239109039307, 25.206055164337158, 25.208078145980835, 25.213263988494873, 25.215383052825928, 25.22067904472351, 25.222690105438232, 25.228233098983765, 25.23008418083191, 25.23587703704834, 25.237354040145874, 25.243746042251587, 25.244084119796753, 25.251058101654053, 25.251527070999146, 25.258601188659668, 25.258908987045288, 25.26585602760315, 25.266273975372314, 25.273102045059204, 25.274407148361206, 25.280631065368652, 25.282284021377563, 25.28810405731201, 25.2901771068573, 25.295631170272827, 25.298027992248535, 25.303080081939697, 25.30588412284851, 25.310383081436157, 25.314059019088745, 25.317528009414673, 25.383979082107544, 25.414371013641357, 25.44039297103882, 25.460848093032837, 25.4806911945343, 25.501825094223022, 25.521847009658813, 25.539715051651, 25.557054042816162, 25.571213006973267, 25.584705114364624, 25.59842801094055, 25.610692977905273, 25.622244119644165, 25.63447403907776, 25.64486002922058, 25.655225038528442, 25.66607403755188, 25.67529606819153, 25.684355974197388, 25.694030046463013, 25.701979160308838, 25.70983099937439, 25.718367099761963, 25.725816011428833, 25.732818126678467, 25.74121904373169, 25.748067140579224, 25.75469207763672, 25.7623291015625, 25.769132137298584, 25.77565312385559, 25.782894134521484, 25.78963017463684, 25.796005964279175, 25.803369998931885, 25.810094118118286, 25.816517114639282, 25.82352900505066, 25.82996416091919, 25.836440086364746, 25.843135118484497, 25.84978199005127, 25.856327056884766, 25.863044023513794, 25.869692087173462, 25.876474142074585, 25.88303518295288, 25.889763116836548, 25.8964581489563, 25.902947187423706, 25.909388065338135, 25.916123151779175, 25.922873973846436, 25.929309129714966, 25.936156034469604, 25.94288396835327, 25.949377059936523, 25.956207036972046, 25.96281599998474, 25.969216108322144, 25.975799083709717, 25.9826021194458, 25.98928213119507, 25.99596905708313, 26.002763986587524, 26.009188175201416, 26.016014099121094, 26.02266216278076, 26.029340982437134, 26.035840034484863, 26.042464017868042, 26.04910707473755, 26.055778980255127, 26.062389135360718, 26.069040060043335, 26.07566213607788, 26.08239507675171, 26.08895516395569, 26.095734119415283, 26.102428197860718, 26.10890007019043, 26.11558198928833, 26.122475147247314, 26.128957986831665, 26.135617971420288, 26.14241909980774, 26.14890718460083, 26.155416011810303, 26.162379026412964, 26.16887903213501, 26.17537808418274, 26.182298183441162, 26.188796043395996, 26.195242166519165, 26.202054977416992, 26.208647966384888, 26.215167999267578, 26.222154140472412, 26.22859501838684, 26.234946966171265, 26.24198818206787, 26.248239040374756, 26.254841089248657, 26.26182198524475, 26.26810598373413, 26.27470302581787, 26.281848192214966, 26.288045167922974, 26.294650077819824, 26.301851987838745, 26.308099031448364, 26.314494132995605, 26.32165217399597, 26.327957153320312, 26.334294080734253, 26.341506004333496, 26.348000049591064, 26.354093074798584, 26.361464977264404, 26.36796998977661, 26.37412714958191, 26.38127303123474, 26.387771129608154, 26.394102096557617, 26.40114712715149, 26.407801151275635, 26.414149045944214, 26.421045064926147, 26.42759108543396, 26.434099197387695, 26.4405460357666, 26.447237968444824, 26.453715085983276, 26.4604389667511, 26.4670569896698, 26.473777055740356, 26.48034405708313, 26.486972093582153, 26.493733167648315, 26.50024104118347, 26.5067720413208, 26.51338505744934, 26.52033019065857, 26.52681016921997, 26.53354811668396, 26.540213108062744, 26.546795129776, 26.553518056869507, 26.560118198394775, 26.566665172576904, 26.573273181915283, 26.580068111419678, 26.586740970611572, 26.593247175216675, 26.60007905960083, 26.60647201538086, 26.61331605911255, 26.62000012397766, 26.62659502029419, 26.633198976516724, 26.639896154403687, 26.646522998809814, 26.653090000152588, 26.659640073776245, 26.66631507873535, 26.672904014587402, 26.679622173309326, 26.686102151870728, 26.692790031433105, 26.699571132659912, 26.70608615875244, 26.71272110939026, 26.71957015991211, 26.726126194000244, 26.73284101486206, 26.739667177200317, 26.746126174926758, 26.752626180648804, 26.759464025497437, 26.76607608795166, 26.77259397506714, 26.779401063919067, 26.785993099212646, 26.792447090148926, 26.79939103126526, 26.80589509010315, 26.812405109405518, 26.819344997406006, 26.825801134109497, 26.832298040390015, 26.83932614326477, 26.845618963241577, 26.852013111114502, 26.858967065811157, 26.86528706550598, 26.87181305885315, 26.87894296646118, 26.885186195373535, 26.891715049743652, 26.89891004562378, 26.90532612800598, 26.91150212287903, 26.91883397102356, 26.925240993499756, 26.93146800994873, 26.938841104507446, 26.94506001472473, 26.95139503479004, 26.95860004425049, 26.965038061141968, 26.97136902809143, 26.978541135787964, 26.985047101974487, 26.991240978240967, 26.998250007629395, 27.004887104034424, 27.011237144470215, 27.01816701889038, 27.024782180786133, 27.031182050704956, 27.037906169891357, 27.044533014297485, 27.051042079925537, 27.057770013809204, 27.064347982406616, 27.0712251663208, 27.077707052230835, 27.084336042404175, 27.090906143188477, 27.097477197647095, 27.104087114334106, 27.11087918281555, 27.1175479888916, 27.12399911880493, 27.13070297241211, 27.137535095214844, 27.144131183624268, 27.15085196495056, 27.1574490070343, 27.16404914855957, 27.17051601409912, 27.17733407020569, 27.18396806716919, 27.190622091293335, 27.19731616973877, 27.204025983810425, 27.210673093795776, 27.217297077178955, 27.223843097686768, 27.23059606552124, 27.23730206489563, 27.243844985961914, 27.250550031661987, 27.257244110107422, 27.26396918296814, 27.270364999771118, 27.277141094207764, 27.283643007278442, 27.290362119674683, 27.297109127044678, 27.303584098815918, 27.31026601791382, 27.31710910797119, 27.323657035827637, 27.33024501800537, 27.337181091308594, 27.343541145324707, 27.350138187408447, 27.35710597038269, 27.363579988479614, 27.37008500099182, 27.377055168151855, 27.383435010910034, 27.389888048171997, 27.396974086761475, 27.40350103378296, 27.409877061843872, 27.41697406768799, 27.423370122909546, 27.429773092269897, 27.436902046203613, 27.44321608543396, 27.4497230052948, 27.456787109375, 27.463069200515747, 27.469531059265137, 27.47661304473877, 27.48281502723694, 27.489289045333862, 27.496505975723267, 27.502771139144897, 27.509132146835327, 27.51639199256897, 27.52263307571411, 27.52902102470398, 27.536524057388306, 27.54282307624817, 27.548976182937622, 27.556329011917114, 27.562843084335327, 27.569152116775513, 27.576344966888428, 27.58299708366394, 27.589441061019897, 27.596882104873657, 27.60388207435608, 27.610576152801514, 27.618149042129517, 27.62504005432129, 27.632055044174194, 27.63933300971985, 27.64663004875183, 27.653938055038452, 27.661484003067017, 27.668982982635498, 27.67666006088257, 27.68434500694275, 27.69209909439087, 27.69988703727722, 27.70786213874817, 27.715806007385254, 27.72406315803528, 27.732778072357178, 27.741034030914307, 27.749577045440674, 27.758424043655396, 27.767224073410034, 27.776308059692383, 27.785471200942993, 27.79472303390503, 27.80419611930847, 27.814016103744507, 27.823966026306152, 27.83415198326111, 27.844848155975342, 27.855446100234985, 27.8664071559906, 27.87760901451111, 27.88928198814392, 27.901129007339478, 27.9137179851532, 27.926525115966797, 27.940080165863037, 27.954254150390625, 27.969011068344116, 27.984522104263306, 28.00130009651184, 28.01864504814148, 28.037898063659668, 28.059625148773193, 28.082684993743896, 28.11010503768921, 28.145848989486694, 28.1968731880188]

# %%
hall_counter = []
speed = []
cur_u = []
cur_w = []
i=0
for x in buf:
    if i == 0:
        speed.append(x)
    if i == 1:
        hall_counter.append(x)
    if i == 2:
        cur_u.append(x)
    if i == 3:
        cur_w.append(x)
        
    i = i+1
    if i == 4:
        i = 0;

# %% [markdown]
# ## Filter

# %%
spin_list = []
spin_list.append(0)
d_fi = 0.074799825 #rad
speed_list = []
speeed = 0
speed_list.append(speeed)

dir_i = 0

prev_spin = 0;

for i,t in enumerate(time):
    if i == 0:
        time_prev = time[i]
        hall_prev = hall_counter[i]
    else:
        dt = time[i] - time_prev
        time_prev = time[i]
        #spin estimation
        if hall_prev == 6 and hall_counter[i] == 1:
            spin = 1
        elif hall_prev == 1 and hall_counter[i] == 6:
            spin = -1
        elif hall_prev < hall_counter[i]:
            spin = 1
        elif hall_prev > hall_counter[i]:
            spin = -1
        hall_prev = hall_counter[i]
        time_prev = time[i]
        
        #speed estimation
        if spin == prev_spin:
            speeed = d_fi/dt * spin
        
        prev_spin = spin
        ##debug
        spin_list.append(spin)
        speed_list.append(speeed)

# %%
plt.figure()
plt.plot(time, numpy.asarray(hall_counter)/6, '-o', label ='hall')
plt.plot(time, numpy.asarray(speed_list), label ='speed')
# Out:
# <img src="data:image/png;base64,..." width="999">

# %% [markdown]
# ## Print RAW data

# %%
plt.figure()
plt.plot(time, hall_counter, '-o', label = 'hall counter (step)')
plt.plot(time, speed, label ='speed (rad/sec)')
plt.grid()
#plt.plot(time, dt, label ='dt')
plt.xlabel('time (sec)')
plt.legend()

plt.figure()
plt.plot(time, numpy.array(cur_u), label ='cur u')
plt.plot(time, numpy.array(cur_w), label ='cur w')



plt.plot(time, numpy.asarray(hall_counter), label ='hall')



plt.grid()
plt.xlabel('time (sec)')
plt.legend()
# Out:
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="1108">

# %% [markdown]
# ## Regulator ##

# %%
omega_freq_max = 12.46663761138916
dt = 1.0 / 20
u_nominal = 24. / 4 #volt
k_motor = omega_freq_max / u_nominal

# %%
omega_target = 15.
omega_errorf = 0.
kp = 4
ki = 0.5
kd = 0.00

# %%
omega_real = []
omega_preasure = []
integral = 0
dif = 0
prev_omega_error = 0
u_dt = []
omega = 0
omega_pressure = []
u = 0.
Tm = 0.4 / 3

for i,t in enumerate(speed):
    if i > 160:
        #pressure_i = 1
        omega_target = -15
    else:
        pressure_i = 0
    omega -= pressure_i
    omega_real.append(omega)
    omega_pressure.append(pressure_i)
    
    omega_error = omega_target - omega;
    
    integral += omega_error * dt
    diff = (omega_error - prev_omega_error) / dt
    prev_omega_error = omega_error
    u_dt.append(u)
    u = kp*omega_error + kd*diff + ki*integral
    d_omega = (dt / Tm) * (k_motor * u - omega)
    omega += d_omega

# %%
plt.figure()
plt.plot(time, u_dt,label = "voltage")
plt.plot(time, omega_pressure*1,label = "pressure")
plt.plot(time, omega_real,label = "omega real")
plt.legend()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.figure()
plt.plot(time, numpy.asarray(u_dt)*96.25,label = "pwm")
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
k_motor
# Out:
# 2.077772935231527

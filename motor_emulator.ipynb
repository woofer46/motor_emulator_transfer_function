# %%
#%matplotlib notebook
#%matplotlib nbagg
import numpy
import matplotlib.pyplot as plt

# %%
omega_from_sensor = [0.10958076268434525, 4.021495819091797, 6.1818037033081055, 7.555537700653076, 8.697653770446777, 9.0120267868042, 9.589720726013184, 9.714262962341309, 10.246551513671875, 10.388864517211914, 10.535186767578125, 10.685688972473145, 10.999974250793457, 10.685688972473145, 10.685688972473145, 11.333307266235352, 10.999974250793457, 10.999974250793457, 11.164153099060059, 10.999974250793457, 11.164153099060059, 11.333307266235352, 11.164153099060059, 10.999974250793457, 11.164153099060059, 11.333307266235352, 10.999974250793457, 11.333307266235352, 11.333307266235352, 11.164153099060059, 11.164153099060059, 11.333307266235352, 10.999974250793457, 11.333307266235352, 11.164153099060059, 11.333307266235352, 11.164153099060059, 11.164153099060059, 11.164153099060059, 11.507664680480957, 11.164153099060059, 10.999974250793457, 11.507664680480957, 11.164153099060059, 10.999974250793457, 11.687472343444824, 10.999974250793457, 10.999974250793457, 11.507664680480957, 11.333307266235352, 10.685688972473145, 11.687472343444824, 11.333307266235352, 10.840554237365723, 11.507664680480957, 11.687472343444824, 10.685688972473145, 11.507664680480957, 11.507664680480957, 10.685688972473145, 11.507664680480957, 11.507664680480957, 10.535186767578125, 11.872987747192383, 11.507664680480957, 10.535186767578125, 11.872987747192383, 11.333307266235352, 10.388864517211914, 12.064488410949707, 11.507664680480957, 10.246551513671875, 11.872987747192383, 11.872987747192383, 10.388864517211914, 11.872987747192383, 11.687472343444824, 10.108084678649902, 11.872987747192383, 11.872987747192383, 10.246551513671875, 11.687472343444824, 11.872987747192383, 10.535186767578125, 11.507664680480957, 11.872987747192383, 10.535186767578125, 11.164153099060059, 11.687472343444824, 10.840554237365723, 11.333307266235352, 11.507664680480957, 11.164153099060059, 11.333307266235352, 11.333307266235352, 11.164153099060059, 11.164153099060059, 11.164153099060059, 11.164153099060059, 11.333307266235352, 11.164153099060059, 11.333307266235352, 11.333307266235352, 11.164153099060059, 10.999974250793457, 11.507664680480957, 11.164153099060059, 10.999974250793457, 11.333307266235352, 10.999974250793457, 11.333307266235352, 11.333307266235352, 11.164153099060059, 10.999974250793457, 11.164153099060059, 11.333307266235352, 10.999974250793457, 11.333307266235352, 11.164153099060059, 11.164153099060059, 11.164153099060059, 11.333307266235352, 10.999974250793457, 11.333307266235352, 10.999974250793457, 11.333307266235352, 11.164153099060059, 11.164153099060059, 11.164153099060059, 11.333307266235352, 11.164153099060059, 10.999974250793457, 11.507664680480957, 11.164153099060059, 10.840554237365723, 11.687472343444824, 10.999974250793457, 10.999974250793457, 11.507664680480957, 11.333307266235352, 10.840554237365723, 5.7538323402404785, 10.840554237365723, 11.507664680480957, 11.507664680480957, 10.685688972473145, 11.507664680480957, -11.333307266235352, 10.840554237365723, 11.507664680480957, 11.507664680480957, 10.535186767578125, 5.798436164855957, 10.685688972473145, 11.687472343444824, 11.507664680480957, 10.388864517211914, 11.872987747192383, 11.507664680480957, 10.246551513671875, 11.872987747192383, 11.687472343444824, 10.388864517211914, 11.872987747192383, 11.687472343444824, 10.108084678649902, 11.872987747192383, 11.872987747192383, 10.246551513671875, 11.687472343444824, 11.687472343444824, 10.685688972473145, 11.333307266235352, 11.872987747192383, 10.535186767578125, 11.333307266235352, 11.687472343444824, 10.685688972473145, 11.507664680480957, 11.333307266235352, 11.333307266235352, 11.164153099060059, -11.333307266235352, 11.164153099060059, 11.164153099060059, 10.999974250793457, 10.999974250793457, 10.840554237365723, 10.999974250793457, 10.840554237365723, 10.840554237365723, 10.535186767578125, 10.388864517211914, 10.685688972473145, 10.246551513671875, 10.108084678649902, 10.108084678649902, 9.973310470581055, 9.973310470581055, 9.842082023620605, 9.842082023620605, 9.349977493286133, 9.468331336975098, 9.468331336975098, 9.0120267868042, 9.234545707702637, 8.904741287231445, 8.904741287231445, 8.597681045532227, 8.697653770446777, 8.311092376708984, 8.311092376708984, 8.042991638183594, 7.957428455352783, 7.791647911071777, 7.711322784423828, 7.405922889709473, 7.555537700653076, 7.123793125152588, 6.862370014190674, 6.990638256072998, 6.619453430175781, 6.338967800140381, 6.448260307312012, 6.0322442054748535, 5.7099103927612305, 5.843736171722412, 5.540727615356445, 4.953630447387695, 5.088423252105713, 4.794860363006592, 4.225978374481201, 4.225978374481201, 3.8958239555358887, 3.3244364261627197, 3.1561107635498047, 2.7299206256866455, 2.027095317840576, 1.5020045042037964]

# %%
omega_from_sensor
# Out:
# [0.10958076268434525,
#  4.021495819091797,
#  6.1818037033081055,
#  7.555537700653076,
#  8.697653770446777,
#  9.0120267868042,
#  9.589720726013184,
#  9.714262962341309,
#  10.246551513671875,
#  10.388864517211914,
#  10.535186767578125,
#  10.685688972473145,
#  10.999974250793457,
#  10.685688972473145,
#  10.685688972473145,
#  11.333307266235352,
#  10.999974250793457,
#  10.999974250793457,
#  11.164153099060059,
#  10.999974250793457,
#  11.164153099060059,
#  11.333307266235352,
#  11.164153099060059,
#  10.999974250793457,
#  11.164153099060059,
#  11.333307266235352,
#  10.999974250793457,
#  11.333307266235352,
#  11.333307266235352,
#  11.164153099060059,
#  11.164153099060059,
#  11.333307266235352,
#  10.999974250793457,
#  11.333307266235352,
#  11.164153099060059,
#  11.333307266235352,
#  11.164153099060059,
#  11.164153099060059,
#  11.164153099060059,
#  11.507664680480957,
#  11.164153099060059,
#  10.999974250793457,
#  11.507664680480957,
# ...

# %%
omega_freq_max = 12.46663761138916
u_nominal = 24 / 4 #volt
k_motor = omega_freq_max / u_nominal

# %%
k_motor
# Out:
# 2.077772935231527

# %%
plt.plot(omega_from_sensor,label = "omega")

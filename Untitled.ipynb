# %%
import matplotlib as plt

# %%
import numpy

# %%
ar = numpy.arange(1495-400,1495+400,1)

# %%
ar
# Out:
# array([1095, 1096, 1097, 1098, 1099, 1100, 1101, 1102, 1103, 1104, 1105,
#        1106, 1107, 1108, 1109, 1110, 1111, 1112, 1113, 1114, 1115, 1116,
#        1117, 1118, 1119, 1120, 1121, 1122, 1123, 1124, 1125, 1126, 1127,
#        1128, 1129, 1130, 1131, 1132, 1133, 1134, 1135, 1136, 1137, 1138,
#        1139, 1140, 1141, 1142, 1143, 1144, 1145, 1146, 1147, 1148, 1149,
#        1150, 1151, 1152, 1153, 1154, 1155, 1156, 1157, 1158, 1159, 1160,
#        1161, 1162, 1163, 1164, 1165, 1166, 1167, 1168, 1169, 1170, 1171,
#        1172, 1173, 1174, 1175, 1176, 1177, 1178, 1179, 1180, 1181, 1182,
#        1183, 1184, 1185, 1186, 1187, 1188, 1189, 1190, 1191, 1192, 1193,
#        1194, 1195, 1196, 1197, 1198, 1199, 1200, 1201, 1202, 1203, 1204,
#        1205, 1206, 1207, 1208, 1209, 1210, 1211, 1212, 1213, 1214, 1215,
#        1216, 1217, 1218, 1219, 1220, 1221, 1222, 1223, 1224, 1225, 1226,
#        1227, 1228, 1229, 1230, 1231, 1232, 1233, 1234, 1235, 1236, 1237,
# ...

# %%
max_speed = 5
scale = max_speed / 400

# %%
scale
# Out:
# 0.0125

# %%
ar1 =  ar - 1495

# %%
ar2 = (ar1 / 400)*(ar1 / 400)*(ar1 / 400)

# %%
ar2 * 5
# Out:
# array([-5.00000000e+00, -4.96259367e+00, -4.92537438e+00, -4.88834164e+00,
#        -4.85149500e+00, -4.81483398e+00, -4.77835813e+00, -4.74206695e+00,
#        -4.70596000e+00, -4.67003680e+00, -4.63429687e+00, -4.59873977e+00,
#        -4.56336500e+00, -4.52817211e+00, -4.49316062e+00, -4.45833008e+00,
#        -4.42368000e+00, -4.38920992e+00, -4.35491937e+00, -4.32080789e+00,
#        -4.28687500e+00, -4.25312023e+00, -4.21954312e+00, -4.18614320e+00,
#        -4.15292000e+00, -4.11987305e+00, -4.08700188e+00, -4.05430602e+00,
#        -4.02178500e+00, -3.98943836e+00, -3.95726563e+00, -3.92526633e+00,
#        -3.89344000e+00, -3.86178617e+00, -3.83030438e+00, -3.79899414e+00,
#        -3.76785500e+00, -3.73688648e+00, -3.70608812e+00, -3.67545945e+00,
#        -3.64500000e+00, -3.61470930e+00, -3.58458687e+00, -3.55463227e+00,
#        -3.52484500e+00, -3.49522461e+00, -3.46577063e+00, -3.43648258e+00,
# ...

# %%
for a in ar2:
    print(a*5)
# Out:
# -5.0
# -4.962593671875001
# -4.9253743750000005
# -4.888341640625001
# -4.851495
# -4.814833984375
# -4.7783581250000005
# -4.742066953125001
# -4.705959999999999
# -4.670036796875
# -4.6342968749999995
# -4.598739765625001
# -4.563365
# -4.528172109375
# -4.493160625
# -4.458330078125001
# -4.42368
# -4.3892099218750005
# -4.354919375
# -4.320807890625
# -4.286874999999999
# -4.253120234375
# -4.2195431249999995
# -4.186143203125
# -4.152919999999999
# -4.119873046875
# -4.087001875000001
# -4.054306015625
# -4.021785
# -3.989438359375
# -3.9572656250000007
# -3.9252663281249998
# -3.89344
# -3.8617861718749995
# -3.8303043750000003
# -3.798994140625
# -3.7678550000000004
# -3.736886484375
# -3.706088125
# -3.6754594531249998
# -3.6450000000000005
# -3.614709296875
# -3.584586875
# -3.5546322656249996
# -3.5248450000000005
# -3.4952246093749997
# -3.465770625
# -3.4364825781249997
# -3.4073599999999997
# -3.3784024218749993
# -3.349609375
# -3.320980390625001
# -3.2925150000000003
# ...

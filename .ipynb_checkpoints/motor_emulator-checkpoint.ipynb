# %%
import numpy
import matplotlib.pyplot as plt

# %%
omega_from_sensor = [0.0022715486120432615,
 4.399989604949951,
 6.23331880569458,
 8.311092376708984,
 9.349977493286133,
 9.349977493286133,
 10.685688972473145,
 10.685688972473145,
 10.685688972473145,
 12.46663761138916,
 10.685688972473145,
 10.685688972473145,
 12.46663761138916,
 5.342844486236572,
 12.46663761138916,
 12.46663761138916,
 10.685688972473145,
 12.46663761138916,
 12.46663761138916,
 10.685688972473145,
 12.46663761138916,
 12.46663761138916,
 10.685688972473145,
 12.46663761138916,
 12.46663761138916,
 10.685688972473145,
 12.46663761138916,
 12.46663761138916,
 10.685688972473145,
 12.46663761138916,
 12.46663761138916,
 10.685688972473145,
 12.46663761138916,
 12.46663761138916,
 10.685688972473145,
 12.46663761138916,
 12.46663761138916,
 12.46663761138916,
 12.46663761138916,
 12.46663761138916,
 12.46663761138916,
 12.46663761138916,
 12.46663761138916,
 12.46663761138916,
 12.46663761138916,
 12.46663761138916,
 12.46663761138916,
 12.46663761138916,
 12.46663761138916,
 12.46663761138916,
 12.46663761138916,
 12.46663761138916,
 12.46663761138916,
 12.46663761138916,
 12.46663761138916,
 12.46663761138916,
 12.46663761138916,
 12.46663761138916,
 12.46663761138916,
 12.46663761138916,
 12.46663761138916,
 12.46663761138916,
 12.46663761138916,
 12.46663761138916,
 12.46663761138916,
 12.46663761138916,
 12.46663761138916,
 12.46663761138916,
 12.46663761138916,
 -12.46663761138916,
 12.46663761138916,
 12.46663761138916,
 12.46663761138916,
 5.7538323402404785,
 12.46663761138916,
 12.46663761138916,
 12.46663761138916,
 12.46663761138916,
 12.46663761138916,
 12.46663761138916,
 12.46663761138916,
 12.46663761138916,
 12.46663761138916,
 12.46663761138916,
 10.685688972473145,
 12.46663761138916,
 12.46663761138916,
 10.685688972473145,
 12.46663761138916,
 12.46663761138916,
 10.685688972473145,
 12.46663761138916,
 12.46663761138916,
 10.685688972473145,
 12.46663761138916,
 12.46663761138916,
 10.685688972473145,
 12.46663761138916,
 12.46663761138916,
 10.685688972473145,
 12.46663761138916,
 12.46663761138916,
 10.685688972473145,
 12.46663761138916,
 12.46663761138916,
 10.685688972473145,
 12.46663761138916,
 12.46663761138916,
 10.685688972473145,
 12.46663761138916,
 12.46663761138916,
 10.685688972473145,
 12.46663761138916,
 12.46663761138916,
 10.685688972473145,
 12.46663761138916,
 12.46663761138916,
 10.685688972473145,
 12.46663761138916,
 12.46663761138916,
 10.685688972473145,
 12.46663761138916,
 12.46663761138916,
 10.685688972473145,
 12.46663761138916,
 12.46663761138916,
 12.46663761138916,
 12.46663761138916,
 12.46663761138916,
 12.46663761138916,
 12.46663761138916,
 12.46663761138916,
 12.46663761138916,
 12.46663761138916,
 12.46663761138916,
 12.46663761138916,
 12.46663761138916,
 12.46663761138916,
 12.46663761138916,
 12.46663761138916,
 12.46663761138916,
 12.46663761138916,
 12.46663761138916,
 12.46663761138916,
 12.46663761138916,
 12.46663761138916,
 12.46663761138916,
 12.46663761138916,
 12.46663761138916,
 12.46663761138916,
 12.46663761138916,
 12.46663761138916,
 12.46663761138916,
 12.46663761138916,
 12.46663761138916,
 5.7538323402404785,
 12.46663761138916,
 12.46663761138916,
 12.46663761138916,
 12.46663761138916,
 12.46663761138916,
 12.46663761138916,
 12.46663761138916,
 12.46663761138916,
 12.46663761138916,
 12.46663761138916,
 12.46663761138916,
 12.46663761138916,
 12.46663761138916,
 12.46663761138916,
 12.46663761138916,
 12.46663761138916,
 12.46663761138916,
 10.685688972473145,
 12.46663761138916,
 12.46663761138916,
 10.685688972473145,
 12.46663761138916,
 12.46663761138916,
 10.685688972473145,
 12.46663761138916,
 12.46663761138916,
 10.685688972473145,
 12.46663761138916,
 12.46663761138916,
 10.685688972473145,
 12.46663761138916,
 12.46663761138916,
 10.685688972473145,
 12.46663761138916,
 12.46663761138916,
 10.685688972473145,
 12.46663761138916,
 12.46663761138916,
 10.685688972473145,
 12.46663761138916,
 12.46663761138916,
 10.685688972473145,
 12.46663761138916,
 12.46663761138916,
 10.685688972473145,
 12.46663761138916,
 12.46663761138916,
 10.685688972473145,
 12.46663761138916,
 12.46663761138916,
 10.685688972473145,
 12.46663761138916,
 12.46663761138916,
 10.685688972473145,
 12.46663761138916,
 12.46663761138916,
 10.685688972473145,
 12.46663761138916,
 12.46663761138916,
 12.46663761138916,
 12.46663761138916,
 12.46663761138916,
 12.46663761138916,
 12.46663761138916,
 12.46663761138916,
 12.46663761138916,
 12.46663761138916,
 12.46663761138916,
 12.46663761138916,
 12.46663761138916,
 12.46663761138916,
 12.46663761138916,
 12.46663761138916,
 12.46663761138916,
 12.46663761138916,
 12.46663761138916,
 12.46663761138916,
 12.46663761138916,
 12.46663761138916,
 12.46663761138916,
 12.46663761138916,
 12.46663761138916,
 12.46663761138916,
 12.46663761138916,
 12.46663761138916,
 12.46663761138916,
 12.46663761138916,
 12.46663761138916,
 12.46663761138916,
 12.46663761138916,
 12.46663761138916,
 12.46663761138916,
 12.46663761138916,
 12.46663761138916,
 12.46663761138916,
 12.46663761138916,
 12.46663761138916,
 12.46663761138916,
 12.46663761138916,
 12.46663761138916,
 12.46663761138916,
 12.46663761138916,
 12.46663761138916,
 12.46663761138916,
 12.46663761138916,
 12.46663761138916,
 12.46663761138916,
 10.685688972473145,
 12.46663761138916,
 12.46663761138916,
 10.685688972473145,
 12.46663761138916,
 12.46663761138916,
 10.685688972473145,
 12.46663761138916,
 12.46663761138916,
 10.685688972473145,
 12.46663761138916,
 12.46663761138916,
 10.685688972473145,
 12.46663761138916,
 12.46663761138916,
 10.685688972473145,
 12.46663761138916,
 12.46663761138916,
 10.685688972473145,
 12.46663761138916,
 12.46663761138916,
 10.685688972473145,
 12.46663761138916,
 12.46663761138916,
 10.685688972473145,
 12.46663761138916,
 12.46663761138916,
 10.685688972473145,
 12.46663761138916,
 12.46663761138916,
 10.685688972473145,
 12.46663761138916,
 12.46663761138916,
 10.685688972473145,
 12.46663761138916,
 12.46663761138916,
 10.685688972473145,
 12.46663761138916,
 12.46663761138916,
 10.685688972473145,
 12.46663761138916,
 12.46663761138916,
 12.46663761138916,
 12.46663761138916,
 -12.46663761138916,
 12.46663761138916,
 12.46663761138916,
 12.46663761138916,
 12.46663761138916,
 12.46663761138916,
 12.46663761138916,
 12.46663761138916,
 12.46663761138916,
 12.46663761138916,
 12.46663761138916,
 12.46663761138916,
 12.46663761138916,
 12.46663761138916,
 12.46663761138916,
 12.46663761138916,
 12.46663761138916,
 12.46663761138916,
 12.46663761138916,
 12.46663761138916,
 12.46663761138916,
 12.46663761138916,
 12.46663761138916,
 12.46663761138916,
 12.46663761138916,
 10.685688972473145,
 10.685688972473145,
 10.685688972473145,
 10.685688972473145,
 10.685688972473145,
 10.685688972473145,
 10.685688972473145,
 10.685688972473145,
 10.685688972473145,
 10.685688972473145,
 10.685688972473145,
 10.685688972473145,
 9.349977493286133,
 10.685688972473145,
 9.349977493286133,
 9.349977493286133,
 9.349977493286133,
 9.349977493286133,
 9.349977493286133,
 9.349977493286133,
 9.349977493286133,
 8.311092376708984,
 9.349977493286133,
 8.311092376708984,
 8.311092376708984,
 8.311092376708984,
 8.311092376708984,
 7.479982852935791,
 7.479982852935791,
 7.479982852935791,
 6.799983978271484,
 7.479982852935791,
 7.479982852935791,
 6.23331880569458,
 6.799983978271484,
 6.799983978271484,
 5.7538323402404785,
 6.23331880569458,
 5.7538323402404785,
 4.986655235290527,
 5.7538323402404785,
 5.342844486236572,
 4.399989604949951,
 4.674988746643066,
 4.399989604949951,
 3.561896562576294,
 3.7399914264678955,
 3.252166271209717,
 2.337494373321533,
 2.1999948024749756,
 1.4666632413864136]

# %%
omega_from_sensor
# Out:
# [0.0022715486120432615,
#  4.399989604949951,
#  6.23331880569458,
#  8.311092376708984,
#  9.349977493286133,
#  9.349977493286133,
#  10.685688972473145,
#  10.685688972473145,
#  10.685688972473145,
#  12.46663761138916,
#  10.685688972473145,
#  10.685688972473145,
#  12.46663761138916,
#  5.342844486236572,
#  12.46663761138916,
#  12.46663761138916,
#  10.685688972473145,
#  12.46663761138916,
#  12.46663761138916,
#  10.685688972473145,
#  12.46663761138916,
#  12.46663761138916,
#  10.685688972473145,
#  12.46663761138916,
#  12.46663761138916,
#  10.685688972473145,
#  12.46663761138916,
#  12.46663761138916,
#  10.685688972473145,
#  12.46663761138916,
#  12.46663761138916,
#  10.685688972473145,
#  12.46663761138916,
#  12.46663761138916,
#  10.685688972473145,
#  12.46663761138916,
#  12.46663761138916,
#  12.46663761138916,
#  12.46663761138916,
#  12.46663761138916,
#  12.46663761138916,
#  12.46663761138916,
#  12.46663761138916,
#  12.46663761138916,
# ...
